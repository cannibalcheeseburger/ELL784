# %%
from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score,classification_report
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tqdm.notebook as tqdm
from sklearn.utils import shuffle

# %%
from NeuralNetwork.dense import Dense
from NeuralNetwork.activations import Sigmoid,Softmax,ReLU
from NeuralNetwork.losses import categorical_crossentropy, categorical_crossentropy_derive,mse,mse_derive,binary_crossentropy,binary_crossentropy_derive
from NeuralNetwork.network import predict

# %%
mnist = fetch_openml('mnist_784')

# %%
X = mnist.data/255.0
labels = np.array( mnist.target).astype(int)

# %%
#y = np.squeeze(np.eye(10)[labels])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,labels,test_size=0.2,shuffle=True)

# %%
X_val, y_val = X_train.iloc[:5000],y_train[:5000]
X_train, y_train = X_train.iloc[5000:],y_train[5000:]

# %%
EPOCH = 20
ALPHA = 0.08

# %%
def encode(z):
    if z>=0.5:
        return 1
    return 0

# %%
def train(NN, loss, loss_derive, X, Y, X_val,Y_val, epoch=EPOCH, alpha=ALPHA, verbose = True):
    error_TS = []
    acc_TS = []
    val_acc_TS = []
    val_error_TS = []
    for e in range(epoch):
        errors = 0
        acc = 0
        val_acc = 0
        val_error = 0
        for x, y in zip(X, Y):
            out = predict(NN, x)
            if y==encode(out):
                acc+=1
            errors += loss(y, out)
            gradient = loss_derive(y, out)
            for layer in reversed(NN):
                gradient = layer.backward(gradient, alpha)

        for x, y in zip(X_val, Y_val):
            output = predict(NN, x)
            if y==encode(output):
                val_acc+=1
            val_error += loss(y, output)

        errors /= len(X)
        acc /=len(X)
        val_error /= len(X_val)
        val_acc /=len(X_val)
        if verbose:
            print(f"{e + 1}/{epoch}, error={round(errors,4)}, accuracy={round(acc,4)}, val_error={round(val_error,4)}, val_accuracy={round(val_acc,4)}")
        error_TS.append(errors)
        acc_TS.append(acc)
        val_error_TS.append(val_error)
        val_acc_TS.append(val_acc)
    return [error_TS,acc_TS,val_error_TS,val_acc_TS]

class TreeNN():
    def __init__(self,depth=1,max_depth=3,parent_node = None):
        self.parent_node = parent_node
        self.NN = [
            Dense(784,1),
            Sigmoid()
        ]
        self.depth = depth
        self.max_depth = max_depth
        self.children = []
    
    def get_augemented(self,X,Y):
        Xa_train = []
        Xb_train = []
        for x, y in zip(X, Y):
            output = encode(predict(self.NN, x))
            if y!=output:
                if output==0 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
                if output==1 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

            else:
                if output==0 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

                if output==1 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
        return Xa_train,Xb_train
    
    def plot(self,metrics):
        metrics_names = ['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy']
        for i in range(len(metrics_names)):
            plt.plot(metrics[i])
            plt.xlabel("Epochs")
            plt.ylabel(metrics_names[i])
            plt.savefig("./graph/MNIST_{}_{}.png".format(metrics_names[i],self.depth))
            plt.clf()


    
    def train_tree(self,X,Y,X_val,Y_val):
        print("Layers :",self.depth)
        X_train = np.reshape(X,X.shape +(1,))
        Y_train = np.reshape(Y,Y.shape +(1,))
        X_val_in =np.reshape(X_val,X_val.shape +(1,))
        Y_val_in =np.reshape(Y_val,Y_val.shape +(1,))
        metrics = train(self.NN,binary_crossentropy,binary_crossentropy_derive,X_train,Y_train,X_val_in,Y_val_in)
        self.plot(metrics)
        if self.max_depth>self.depth+1:
            ## Adding Layers
            Na = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            Nb = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            self.children.append(Na)
            self.children.append(Nb)
            #Retrain with extra feature
            Xa_train,Xb_train = self.get_augemented(X_train,Y_train)
            X_retrain = np.column_stack((X, Xa_train))
            X_retrain = np.column_stack((X_retrain, Xb_train))
            X_retrain = np.reshape(X_retrain,X_retrain.shape+(1,))
            Xa,Xb = self.get_augemented(X_val_in,Y_val_in)
            X_reval = np.column_stack((X_val, Xa))
            X_reval = np.column_stack((X_reval, Xb))
            X_reval = np.reshape(X_reval,X_reval.shape+(1,))
            self.NN = [Dense(786,1),Sigmoid()]
            metrics = train(self.NN,mse,mse_derive,X_retrain,Y_train,X_reval,Y_val_in)
            self.plot(metrics)
            #Na
            self.children[0].train_tree(X,np.asanyarray(Xa_train),X_val,np.asanyarray(Xa))
            #Nb
            self.children[1].train_tree(X,np.asanyarray(Xb_train),X_val,np.asanyarray(Xb))

    def predict(self,X):
        if self.depth>self.max_depth:
            return  None  
        predictions = []

        if self.children == []:
            X_train = np.reshape(X,X.shape +(1,))
        else:
            Xa = self.children[0].predict(X)
            Xb = self.children[1].predict(X)
            Xa_encode = []
            Xb_encode = []
            for xa,xb in zip(Xa,Xb):
                Xa_encode.append(encode(xa))
                Xb_encode.append(encode(xb))
            X_train = np.column_stack((X, Xa_encode))
            X_train = np.column_stack((X_train, Xb_encode))
            X_train = np.reshape(X_train,X_train.shape+(1,))
        for x in X_train:
            output = predict(self.NN,x)
            predictions.append(output)

        return predictions
        # check for more probability

# %%
def oversample(X_train,Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    max_samples = max(len(class_0), len(class_1))
    class_0_upsampled = class_0.sample(max_samples, replace=True, random_state=42) if len(class_0) < max_samples else class_0
    class_1_upsampled = class_1.sample(max_samples, replace=True, random_state=42) if len(class_1) < max_samples else class_1
    X_train_balanced = pd.concat([class_0_upsampled, class_1_upsampled])
    Y_train_balanced = pd.Series([0] * max_samples + [1] * max_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced,Y_train_balanced

def undersample(X_train, Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    
    # Separate classes
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    
    # Determine minimum sample size
    min_samples = min(len(class_0), len(class_1))
    
    # Downsample both classes to match the smaller class
    class_0_downsampled = class_0.sample(min_samples, random_state=42)
    class_1_downsampled = class_1.sample(min_samples, random_state=42)
    
    # Combine downsampled classes and shuffle
    X_train_balanced = pd.concat([class_0_downsampled, class_1_downsampled])
    Y_train_balanced = pd.Series([0] * min_samples + [1] * min_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    
    # Convert to numpy arrays
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    
    print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced, Y_train_balanced

# %%
def get_XY(X_train,y_train,X_val,y_val,y_test,class_):
    y_in = np.where(y_train == class_, 1, 0)
    y_v = np.where(y_val == class_, 1, 0)
    y_t = np.where(y_test == class_, 1, 0)
    X_in,y_in= undersample(X_train,y_in)
    X_v,y_v= undersample(X_val,y_v)
    return X_in,y_in,X_v,y_v,y_t

# %%
tree_classifier = []
for classifier in tqdm.tqdm(range(10)):
    root = TreeNN(max_depth=3,parent_node=None)
    X_in,y_in,X_v,y_v,y_t = get_XY(X_train,y_train,X_val,y_val,y_test,classifier)
    root.train_tree(X_in,y_in,X_v,y_v)
    tree_classifier.append(root)
    pred = root.predict(X_test)
    acc = 0
    error = 0
    for p,t in zip(pred,y_t):
        if encode(p)==t:
            acc+=1
        error+=mse(p,t)
    print("Test Accuracy = ",acc/len(y_t))
    print("Test Loss = ",error/len(y_t))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Balanced dataset shape: (10114, 784), (10114,)
# Balanced dataset shape: (1004, 784), (1004,)
# Layers : 1
# 1/20, error=0.1612, accuracy=0.9648, val_error=0.0876, val_accuracy=0.9801
# 2/20, error=0.0969, accuracy=0.9781, val_error=0.0758, val_accuracy=0.9781
# 3/20, error=0.0836, accuracy=0.9802, val_error=0.0738, val_accuracy=0.9791
# 4/20, error=0.0755, accuracy=0.981, val_error=0.0735, val_accuracy=0.9791
# 5/20, error=0.0708, accuracy=0.9818, val_error=0.0731, val_accuracy=0.9791
# 6/20, error=0.0674, accuracy=0.9826, val_error=0.0753, val_accuracy=0.9791
# 7/20, error=0.0645, accuracy=0.9828, val_error=0.0791, val_accuracy=0.9771
# 8/20, error=0.0621, accuracy=0.9833, val_error=0.082, val_accuracy=0.9771
# 9/20, error=0.0601, accuracy=0.9838, val_error=0.084, val_accuracy=0.9771
# 10/20, error=0.0583, accuracy=0.9841, val_error=0.0859, val_accuracy=0.9771
# 11/20, error=0.0567, accuracy=0.9849, val_error=0.0877, val_accuracy=0.9771
# 12/20, error=0.0553, accuracy=0.9848, val_error=0.0895, val_accuracy=0.9771
# 13/20, error=0.0541, accuracy=0.9851, val_error=0.0914, val_accuracy=0.9781
# 14/20, error=0.053, accuracy=0.9856, val_error=0.0937, val_accuracy=0.9781
# 15/20, error=0.0519, accuracy=0.9859, val_error=0.0965, val_accuracy=0.9781
# 16/20, error=0.051, accuracy=0.9862, val_error=0.0996, val_accuracy=0.9771
# 17/20, error=0.0501, accuracy=0.9862, val_error=0.1029, val_accuracy=0.9761
# 18/20, error=0.0492, accuracy=0.9863, val_error=0.1062, val_accuracy=0.9761
# 19/20, error=0.0484, accuracy=0.9863, val_error=0.1094, val_accuracy=0.9761
# 20/20, error=0.0476, accuracy=0.9868, val_error=0.1124, val_accuracy=0.9771
# 1/20, error=0.0437, accuracy=0.948, val_error=0.0098, val_accuracy=0.989
# 2/20, error=0.0085, accuracy=0.9892, val_error=0.0064, val_accuracy=0.991
# 3/20, error=0.0051, accuracy=0.9935, val_error=0.0041, val_accuracy=0.995
# 4/20, error=0.0032, accuracy=0.9961, val_error=0.0026, val_accuracy=0.998
# 5/20, error=0.0021, accuracy=0.9974, val_error=0.0024, val_accuracy=0.998
# 6/20, error=0.0015, accuracy=0.9983, val_error=0.002, val_accuracy=0.998
# 7/20, error=0.0011, accuracy=0.9987, val_error=0.0017, val_accuracy=0.998
# 8/20, error=0.0009, accuracy=0.9992, val_error=0.0015, val_accuracy=0.998
# 9/20, error=0.0008, accuracy=0.9992, val_error=0.0016, val_accuracy=0.998
# 10/20, error=0.0007, accuracy=0.9993, val_error=0.0016, val_accuracy=0.998
# 11/20, error=0.0006, accuracy=0.9994, val_error=0.0014, val_accuracy=0.998
# 12/20, error=0.0005, accuracy=0.9994, val_error=0.0012, val_accuracy=0.999
# 13/20, error=0.0004, accuracy=0.9997, val_error=0.0011, val_accuracy=0.999
# 14/20, error=0.0003, accuracy=0.9997, val_error=0.001, val_accuracy=0.999
# 15/20, error=0.0002, accuracy=0.9998, val_error=0.0009, val_accuracy=0.999
# 16/20, error=0.0001, accuracy=0.9999, val_error=0.0009, val_accuracy=0.999
# 17/20, error=0.0001, accuracy=1.0, val_error=0.0009, val_accuracy=0.999
# 18/20, error=0.0001, accuracy=1.0, val_error=0.0009, val_accuracy=0.999
# 19/20, error=0.0, accuracy=1.0, val_error=0.0009, val_accuracy=0.999
# 20/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.999
# Layers : 2
# 1/20, error=0.1689, accuracy=0.9615, val_error=0.1123, val_accuracy=0.9741
# 2/20, error=0.1025, accuracy=0.9768, val_error=0.0991, val_accuracy=0.9771
# 3/20, error=0.0873, accuracy=0.9789, val_error=0.0906, val_accuracy=0.9781
# 4/20, error=0.0809, accuracy=0.9806, val_error=0.089, val_accuracy=0.9781
# 5/20, error=0.0761, accuracy=0.982, val_error=0.0869, val_accuracy=0.9781
# 6/20, error=0.0724, accuracy=0.9822, val_error=0.0838, val_accuracy=0.9761
# 7/20, error=0.0696, accuracy=0.9824, val_error=0.0816, val_accuracy=0.9781
# 8/20, error=0.0668, accuracy=0.9834, val_error=0.0802, val_accuracy=0.9791
# 9/20, error=0.0644, accuracy=0.9837, val_error=0.0795, val_accuracy=0.9791
# 10/20, error=0.0623, accuracy=0.9842, val_error=0.0795, val_accuracy=0.9761
# 11/20, error=0.0604, accuracy=0.9845, val_error=0.0798, val_accuracy=0.9781
# 12/20, error=0.0586, accuracy=0.985, val_error=0.0804, val_accuracy=0.9781
# 13/20, error=0.0571, accuracy=0.985, val_error=0.0815, val_accuracy=0.9781
# 14/20, error=0.0557, accuracy=0.9857, val_error=0.0833, val_accuracy=0.9801
# 15/20, error=0.0545, accuracy=0.9861, val_error=0.0857, val_accuracy=0.9791
# 16/20, error=0.0535, accuracy=0.9864, val_error=0.0883, val_accuracy=0.9791
# 17/20, error=0.0525, accuracy=0.9868, val_error=0.0911, val_accuracy=0.9791
# 18/20, error=0.0516, accuracy=0.987, val_error=0.0938, val_accuracy=0.9781
# 19/20, error=0.0507, accuracy=0.9873, val_error=0.0965, val_accuracy=0.9781
# 20/20, error=0.0499, accuracy=0.9874, val_error=0.0991, val_accuracy=0.9771
# Layers : 2
# 1/20, error=0.1865, accuracy=0.9617, val_error=0.1585, val_accuracy=0.9622
# 2/20, error=0.1031, accuracy=0.9777, val_error=0.1298, val_accuracy=0.9681
# 3/20, error=0.089, accuracy=0.9788, val_error=0.1218, val_accuracy=0.9691
# 4/20, error=0.0811, accuracy=0.9802, val_error=0.1096, val_accuracy=0.9731
# 5/20, error=0.0758, accuracy=0.9816, val_error=0.0996, val_accuracy=0.9781
# 6/20, error=0.0715, accuracy=0.9828, val_error=0.0923, val_accuracy=0.9771
# 7/20, error=0.0678, accuracy=0.9833, val_error=0.0863, val_accuracy=0.9771
# 8/20, error=0.065, accuracy=0.9833, val_error=0.0832, val_accuracy=0.9791
# 9/20, error=0.0625, accuracy=0.9844, val_error=0.0815, val_accuracy=0.9801
# 10/20, error=0.0603, accuracy=0.985, val_error=0.0802, val_accuracy=0.9801
# 11/20, error=0.0583, accuracy=0.9851, val_error=0.079, val_accuracy=0.9831
# 12/20, error=0.0566, accuracy=0.985, val_error=0.0782, val_accuracy=0.9831
# 13/20, error=0.055, accuracy=0.9854, val_error=0.0783, val_accuracy=0.9831
# 14/20, error=0.0536, accuracy=0.9858, val_error=0.0792, val_accuracy=0.9831
# 15/20, error=0.0524, accuracy=0.986, val_error=0.081, val_accuracy=0.9811
# 16/20, error=0.0513, accuracy=0.9862, val_error=0.0832, val_accuracy=0.9811
# 17/20, error=0.0504, accuracy=0.987, val_error=0.0858, val_accuracy=0.9811
# 18/20, error=0.0495, accuracy=0.9873, val_error=0.0886, val_accuracy=0.9811
# 19/20, error=0.0488, accuracy=0.9873, val_error=0.0913, val_accuracy=0.9811
# 20/20, error=0.048, accuracy=0.9882, val_error=0.094, val_accuracy=0.9811
# Test Accuracy =  0.96
# Test Loss =  0.03839128008790276
# Balanced dataset shape: (11510, 784), (11510,)
# Balanced dataset shape: (1014, 784), (1014,)
# Layers : 1
# 1/20, error=0.1463, accuracy=0.966, val_error=0.1229, val_accuracy=0.9734
# 2/20, error=0.0885, accuracy=0.9769, val_error=0.1096, val_accuracy=0.9783
# 3/20, error=0.075, accuracy=0.9797, val_error=0.1097, val_accuracy=0.9783
# 4/20, error=0.0671, accuracy=0.9811, val_error=0.1115, val_accuracy=0.9793
# 5/20, error=0.0614, accuracy=0.9826, val_error=0.1117, val_accuracy=0.9773
# 6/20, error=0.0573, accuracy=0.9833, val_error=0.1116, val_accuracy=0.9773
# 7/20, error=0.0542, accuracy=0.9842, val_error=0.1124, val_accuracy=0.9773
# 8/20, error=0.0517, accuracy=0.9845, val_error=0.114, val_accuracy=0.9753
# 9/20, error=0.0498, accuracy=0.9852, val_error=0.1158, val_accuracy=0.9763
# 10/20, error=0.0482, accuracy=0.9857, val_error=0.1175, val_accuracy=0.9763
# 11/20, error=0.0468, accuracy=0.986, val_error=0.1188, val_accuracy=0.9763
# 12/20, error=0.0456, accuracy=0.9865, val_error=0.1198, val_accuracy=0.9753
# 13/20, error=0.0446, accuracy=0.9868, val_error=0.1206, val_accuracy=0.9753
# 14/20, error=0.0437, accuracy=0.987, val_error=0.1212, val_accuracy=0.9753
# 15/20, error=0.0429, accuracy=0.9871, val_error=0.1216, val_accuracy=0.9753
# 16/20, error=0.0421, accuracy=0.9874, val_error=0.1219, val_accuracy=0.9753
# 17/20, error=0.0414, accuracy=0.9874, val_error=0.1222, val_accuracy=0.9753
# 18/20, error=0.0408, accuracy=0.9875, val_error=0.1224, val_accuracy=0.9753
# 19/20, error=0.0402, accuracy=0.9875, val_error=0.1228, val_accuracy=0.9753
# 20/20, error=0.0396, accuracy=0.9877, val_error=0.1232, val_accuracy=0.9753
# 1/20, error=0.0254, accuracy=0.9691, val_error=0.0074, val_accuracy=0.9921
# 2/20, error=0.0073, accuracy=0.9916, val_error=0.0058, val_accuracy=0.9941
# 3/20, error=0.0038, accuracy=0.9952, val_error=0.003, val_accuracy=0.9961
# 4/20, error=0.0016, accuracy=0.9983, val_error=0.0028, val_accuracy=0.9961
# 5/20, error=0.001, accuracy=0.999, val_error=0.0026, val_accuracy=0.997
# 6/20, error=0.0007, accuracy=0.9993, val_error=0.0024, val_accuracy=0.997
# 7/20, error=0.0006, accuracy=0.9995, val_error=0.0023, val_accuracy=0.997
# 8/20, error=0.0005, accuracy=0.9995, val_error=0.0023, val_accuracy=0.997
# 9/20, error=0.0004, accuracy=0.9997, val_error=0.0022, val_accuracy=0.997
# 10/20, error=0.0003, accuracy=0.9997, val_error=0.0021, val_accuracy=0.998
# 11/20, error=0.0003, accuracy=0.9997, val_error=0.002, val_accuracy=0.998
# 12/20, error=0.0003, accuracy=0.9997, val_error=0.0019, val_accuracy=0.998
# 13/20, error=0.0003, accuracy=0.9997, val_error=0.0019, val_accuracy=0.998
# 14/20, error=0.0003, accuracy=0.9997, val_error=0.0018, val_accuracy=0.998
# 15/20, error=0.0003, accuracy=0.9997, val_error=0.0018, val_accuracy=0.998
# 16/20, error=0.0003, accuracy=0.9997, val_error=0.0018, val_accuracy=0.998
# 17/20, error=0.0003, accuracy=0.9997, val_error=0.0017, val_accuracy=0.998
# 18/20, error=0.0003, accuracy=0.9997, val_error=0.0017, val_accuracy=0.998
# 19/20, error=0.0003, accuracy=0.9997, val_error=0.0017, val_accuracy=0.998
# 20/20, error=0.0003, accuracy=0.9997, val_error=0.0017, val_accuracy=0.998
# Layers : 2
# 1/20, error=0.1388, accuracy=0.9688, val_error=0.106, val_accuracy=0.9714
# 2/20, error=0.0831, accuracy=0.9791, val_error=0.1081, val_accuracy=0.9714
# 3/20, error=0.0703, accuracy=0.9811, val_error=0.1058, val_accuracy=0.9724
# 4/20, error=0.063, accuracy=0.9822, val_error=0.1066, val_accuracy=0.9724
# 5/20, error=0.0582, accuracy=0.9832, val_error=0.1079, val_accuracy=0.9724
# 6/20, error=0.0548, accuracy=0.9839, val_error=0.1105, val_accuracy=0.9734
# 7/20, error=0.0521, accuracy=0.9844, val_error=0.1138, val_accuracy=0.9734
# 8/20, error=0.05, accuracy=0.9848, val_error=0.1168, val_accuracy=0.9724
# 9/20, error=0.0483, accuracy=0.985, val_error=0.1189, val_accuracy=0.9724
# 10/20, error=0.0469, accuracy=0.9854, val_error=0.1203, val_accuracy=0.9744
# 11/20, error=0.0456, accuracy=0.986, val_error=0.1213, val_accuracy=0.9734
# 12/20, error=0.0446, accuracy=0.9864, val_error=0.1219, val_accuracy=0.9734
# 13/20, error=0.0436, accuracy=0.9865, val_error=0.1224, val_accuracy=0.9753
# 14/20, error=0.0427, accuracy=0.9868, val_error=0.1227, val_accuracy=0.9753
# 15/20, error=0.0419, accuracy=0.9869, val_error=0.123, val_accuracy=0.9753
# 16/20, error=0.0412, accuracy=0.9871, val_error=0.1233, val_accuracy=0.9753
# 17/20, error=0.0405, accuracy=0.9876, val_error=0.1236, val_accuracy=0.9753
# 18/20, error=0.0399, accuracy=0.9872, val_error=0.1239, val_accuracy=0.9763
# 19/20, error=0.0393, accuracy=0.9877, val_error=0.1244, val_accuracy=0.9763
# 20/20, error=0.0387, accuracy=0.9879, val_error=0.1249, val_accuracy=0.9773
# Layers : 2
# 1/20, error=0.1392, accuracy=0.9672, val_error=0.1027, val_accuracy=0.9714
# 2/20, error=0.0849, accuracy=0.9777, val_error=0.0829, val_accuracy=0.9753
# 3/20, error=0.0727, accuracy=0.9802, val_error=0.084, val_accuracy=0.9793
# 4/20, error=0.0656, accuracy=0.9815, val_error=0.0873, val_accuracy=0.9793
# 5/20, error=0.0604, accuracy=0.9821, val_error=0.0907, val_accuracy=0.9793
# 6/20, error=0.0564, accuracy=0.9825, val_error=0.0942, val_accuracy=0.9793
# 7/20, error=0.0531, accuracy=0.9834, val_error=0.097, val_accuracy=0.9783
# 8/20, error=0.0505, accuracy=0.9838, val_error=0.0991, val_accuracy=0.9783
# 9/20, error=0.0484, accuracy=0.9836, val_error=0.1006, val_accuracy=0.9773
# 10/20, error=0.0467, accuracy=0.9838, val_error=0.1016, val_accuracy=0.9783
# 11/20, error=0.0453, accuracy=0.9843, val_error=0.1025, val_accuracy=0.9783
# 12/20, error=0.0441, accuracy=0.9848, val_error=0.1033, val_accuracy=0.9783
# 13/20, error=0.0431, accuracy=0.9854, val_error=0.1042, val_accuracy=0.9783
# 14/20, error=0.0422, accuracy=0.9857, val_error=0.105, val_accuracy=0.9773
# 15/20, error=0.0414, accuracy=0.9864, val_error=0.1058, val_accuracy=0.9773
# 16/20, error=0.0407, accuracy=0.9867, val_error=0.1066, val_accuracy=0.9773
# 17/20, error=0.04, accuracy=0.9869, val_error=0.1074, val_accuracy=0.9773
# 18/20, error=0.0394, accuracy=0.9872, val_error=0.1083, val_accuracy=0.9773
# 19/20, error=0.0388, accuracy=0.9874, val_error=0.1091, val_accuracy=0.9773
# 20/20, error=0.0383, accuracy=0.9874, val_error=0.11, val_accuracy=0.9763
# Test Accuracy =  0.9764285714285714
# Test Loss =  0.0224671514788271
# Balanced dataset shape: (10286, 784), (10286,)
# Balanced dataset shape: (990, 784), (990,)
# Layers : 1
# 1/20, error=0.426, accuracy=0.9018, val_error=0.3518, val_accuracy=0.9202
# 2/20, error=0.3166, accuracy=0.9201, val_error=0.3415, val_accuracy=0.9202
# 3/20, error=0.2899, accuracy=0.9235, val_error=0.3278, val_accuracy=0.9242
# 4/20, error=0.2754, accuracy=0.9279, val_error=0.3174, val_accuracy=0.9283
# 5/20, error=0.2662, accuracy=0.9288, val_error=0.3121, val_accuracy=0.9313
# 6/20, error=0.2597, accuracy=0.9305, val_error=0.3097, val_accuracy=0.9273
# 7/20, error=0.2548, accuracy=0.9321, val_error=0.3096, val_accuracy=0.9293
# 8/20, error=0.2511, accuracy=0.9337, val_error=0.3109, val_accuracy=0.9313
# 9/20, error=0.2482, accuracy=0.9345, val_error=0.3122, val_accuracy=0.9303
# 10/20, error=0.2459, accuracy=0.9354, val_error=0.3126, val_accuracy=0.9293
# 11/20, error=0.2441, accuracy=0.9365, val_error=0.3125, val_accuracy=0.9293
# 12/20, error=0.2427, accuracy=0.937, val_error=0.3124, val_accuracy=0.9303
# 13/20, error=0.2415, accuracy=0.9368, val_error=0.3125, val_accuracy=0.9303
# 14/20, error=0.2404, accuracy=0.9368, val_error=0.3129, val_accuracy=0.9323
# 15/20, error=0.2396, accuracy=0.9376, val_error=0.3135, val_accuracy=0.9323
# 16/20, error=0.2388, accuracy=0.9375, val_error=0.3143, val_accuracy=0.9313
# 17/20, error=0.2381, accuracy=0.9375, val_error=0.3153, val_accuracy=0.9313
# 18/20, error=0.2376, accuracy=0.9377, val_error=0.3164, val_accuracy=0.9313
# 19/20, error=0.237, accuracy=0.9374, val_error=0.3175, val_accuracy=0.9303
# 20/20, error=0.2366, accuracy=0.9378, val_error=0.3187, val_accuracy=0.9303
# 1/20, error=0.0814, accuracy=0.9073, val_error=0.0136, val_accuracy=0.9828
# 2/20, error=0.0076, accuracy=0.9904, val_error=0.0034, val_accuracy=0.996
# 3/20, error=0.0027, accuracy=0.9963, val_error=0.0025, val_accuracy=0.996
# 4/20, error=0.0012, accuracy=0.9985, val_error=0.0022, val_accuracy=0.997
# 5/20, error=0.0007, accuracy=0.9994, val_error=0.0023, val_accuracy=0.997
# 6/20, error=0.0005, accuracy=0.9996, val_error=0.0015, val_accuracy=0.998
# 7/20, error=0.0004, accuracy=0.9996, val_error=0.0011, val_accuracy=0.998
# 8/20, error=0.0003, accuracy=0.9997, val_error=0.0009, val_accuracy=0.999
# 9/20, error=0.0003, accuracy=0.9998, val_error=0.0007, val_accuracy=0.999
# 10/20, error=0.0002, accuracy=0.9998, val_error=0.0007, val_accuracy=0.999
# 11/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 12/20, error=0.0002, accuracy=0.9998, val_error=0.0007, val_accuracy=0.999
# 13/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 14/20, error=0.0001, accuracy=0.9999, val_error=0.0005, val_accuracy=1.0
# 15/20, error=0.0001, accuracy=0.9999, val_error=0.0004, val_accuracy=1.0
# 16/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 17/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 18/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 19/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 20/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.4279, accuracy=0.904, val_error=0.4144, val_accuracy=0.903
# 2/20, error=0.3247, accuracy=0.9207, val_error=0.3666, val_accuracy=0.9152
# 3/20, error=0.2943, accuracy=0.9257, val_error=0.3466, val_accuracy=0.9192
# 4/20, error=0.278, accuracy=0.9281, val_error=0.3389, val_accuracy=0.9212
# 5/20, error=0.268, accuracy=0.9288, val_error=0.3335, val_accuracy=0.9222
# 6/20, error=0.261, accuracy=0.9311, val_error=0.3293, val_accuracy=0.9263
# 7/20, error=0.2559, accuracy=0.9315, val_error=0.3265, val_accuracy=0.9263
# 8/20, error=0.252, accuracy=0.9314, val_error=0.3252, val_accuracy=0.9273
# 9/20, error=0.2489, accuracy=0.9327, val_error=0.3248, val_accuracy=0.9263
# 10/20, error=0.2463, accuracy=0.933, val_error=0.3248, val_accuracy=0.9273
# 11/20, error=0.2441, accuracy=0.9346, val_error=0.3248, val_accuracy=0.9232
# 12/20, error=0.2423, accuracy=0.9358, val_error=0.3245, val_accuracy=0.9232
# 13/20, error=0.2408, accuracy=0.9364, val_error=0.324, val_accuracy=0.9242
# 14/20, error=0.2396, accuracy=0.9365, val_error=0.3232, val_accuracy=0.9232
# 15/20, error=0.2386, accuracy=0.9375, val_error=0.3224, val_accuracy=0.9222
# 16/20, error=0.2378, accuracy=0.9375, val_error=0.3217, val_accuracy=0.9242
# 17/20, error=0.2371, accuracy=0.9372, val_error=0.3212, val_accuracy=0.9253
# 18/20, error=0.2365, accuracy=0.9374, val_error=0.321, val_accuracy=0.9253
# 19/20, error=0.2361, accuracy=0.9375, val_error=0.3209, val_accuracy=0.9253
# 20/20, error=0.2356, accuracy=0.9379, val_error=0.3211, val_accuracy=0.9242
# Layers : 2
# 1/20, error=0.4263, accuracy=0.9014, val_error=0.4421, val_accuracy=0.902
# 2/20, error=0.3184, accuracy=0.9205, val_error=0.3982, val_accuracy=0.9131
# 3/20, error=0.2914, accuracy=0.9248, val_error=0.3661, val_accuracy=0.9152
# 4/20, error=0.2777, accuracy=0.9279, val_error=0.3495, val_accuracy=0.9182
# 5/20, error=0.2683, accuracy=0.9285, val_error=0.3378, val_accuracy=0.9222
# 6/20, error=0.2617, accuracy=0.9301, val_error=0.3287, val_accuracy=0.9253
# 7/20, error=0.2567, accuracy=0.9312, val_error=0.323, val_accuracy=0.9273
# 8/20, error=0.253, accuracy=0.9324, val_error=0.3198, val_accuracy=0.9313
# 9/20, error=0.25, accuracy=0.9337, val_error=0.3179, val_accuracy=0.9303
# 10/20, error=0.2475, accuracy=0.934, val_error=0.3167, val_accuracy=0.9303
# 11/20, error=0.2452, accuracy=0.9345, val_error=0.316, val_accuracy=0.9313
# 12/20, error=0.2433, accuracy=0.9358, val_error=0.3154, val_accuracy=0.9293
# 13/20, error=0.2416, accuracy=0.9372, val_error=0.3151, val_accuracy=0.9313
# 14/20, error=0.2401, accuracy=0.9373, val_error=0.3148, val_accuracy=0.9313
# 15/20, error=0.2388, accuracy=0.9373, val_error=0.3146, val_accuracy=0.9313
# 16/20, error=0.2378, accuracy=0.9382, val_error=0.3146, val_accuracy=0.9303
# 17/20, error=0.2369, accuracy=0.9392, val_error=0.3147, val_accuracy=0.9303
# 18/20, error=0.2361, accuracy=0.9397, val_error=0.3149, val_accuracy=0.9303
# 19/20, error=0.2355, accuracy=0.9393, val_error=0.3152, val_accuracy=0.9303
# 20/20, error=0.2349, accuracy=0.939, val_error=0.3156, val_accuracy=0.9303
# Test Accuracy =  0.9195714285714286
# Test Loss =  0.07821228832436553
# Balanced dataset shape: (10274, 784), (10274,)
# Balanced dataset shape: (1084, 784), (1084,)
# Layers : 1
# 1/20, error=0.4858, accuracy=0.892, val_error=0.3369, val_accuracy=0.8976
# 2/20, error=0.3659, accuracy=0.9097, val_error=0.3086, val_accuracy=0.9068
# 3/20, error=0.3401, accuracy=0.9149, val_error=0.3014, val_accuracy=0.9077
# 4/20, error=0.3257, accuracy=0.9176, val_error=0.2954, val_accuracy=0.9077
# 5/20, error=0.3174, accuracy=0.9195, val_error=0.2869, val_accuracy=0.9087
# 6/20, error=0.3122, accuracy=0.9203, val_error=0.2789, val_accuracy=0.9105
# 7/20, error=0.3081, accuracy=0.921, val_error=0.2745, val_accuracy=0.9133
# 8/20, error=0.3048, accuracy=0.9219, val_error=0.2728, val_accuracy=0.9151
# 9/20, error=0.3022, accuracy=0.9227, val_error=0.2724, val_accuracy=0.9124
# 10/20, error=0.2999, accuracy=0.9231, val_error=0.2725, val_accuracy=0.9161
# 11/20, error=0.2981, accuracy=0.9233, val_error=0.2729, val_accuracy=0.917
# 12/20, error=0.2965, accuracy=0.9239, val_error=0.2735, val_accuracy=0.9161
# 13/20, error=0.2951, accuracy=0.9241, val_error=0.2743, val_accuracy=0.9161
# 14/20, error=0.294, accuracy=0.9235, val_error=0.2751, val_accuracy=0.9161
# 15/20, error=0.2931, accuracy=0.9232, val_error=0.2759, val_accuracy=0.9179
# 16/20, error=0.2924, accuracy=0.9234, val_error=0.2766, val_accuracy=0.9161
# 17/20, error=0.2917, accuracy=0.9238, val_error=0.277, val_accuracy=0.9161
# 18/20, error=0.2912, accuracy=0.9234, val_error=0.2773, val_accuracy=0.917
# 19/20, error=0.2908, accuracy=0.9234, val_error=0.2775, val_accuracy=0.917
# 20/20, error=0.2903, accuracy=0.9236, val_error=0.2777, val_accuracy=0.9179
# 1/20, error=0.0626, accuracy=0.9254, val_error=0.0092, val_accuracy=0.9862
# 2/20, error=0.0062, accuracy=0.9919, val_error=0.0017, val_accuracy=0.9972
# 3/20, error=0.0018, accuracy=0.9974, val_error=0.0009, val_accuracy=0.9982
# 4/20, error=0.0006, accuracy=0.9995, val_error=0.0004, val_accuracy=1.0
# 5/20, error=0.0003, accuracy=0.9998, val_error=0.0003, val_accuracy=1.0
# 6/20, error=0.0002, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 7/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 10/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.4876, accuracy=0.8907, val_error=0.3968, val_accuracy=0.8902
# 2/20, error=0.3683, accuracy=0.9097, val_error=0.4174, val_accuracy=0.8801
# 3/20, error=0.3393, accuracy=0.9133, val_error=0.3813, val_accuracy=0.8875
# 4/20, error=0.3256, accuracy=0.9151, val_error=0.3559, val_accuracy=0.8958
# 5/20, error=0.3173, accuracy=0.9176, val_error=0.3365, val_accuracy=0.8958
# 6/20, error=0.3113, accuracy=0.9189, val_error=0.325, val_accuracy=0.8994
# 7/20, error=0.307, accuracy=0.9199, val_error=0.3196, val_accuracy=0.8976
# 8/20, error=0.3036, accuracy=0.9213, val_error=0.3166, val_accuracy=0.8958
# 9/20, error=0.3008, accuracy=0.922, val_error=0.3142, val_accuracy=0.8985
# 10/20, error=0.2986, accuracy=0.923, val_error=0.3119, val_accuracy=0.9004
# 11/20, error=0.297, accuracy=0.9223, val_error=0.31, val_accuracy=0.905
# 12/20, error=0.2956, accuracy=0.9214, val_error=0.3088, val_accuracy=0.905
# 13/20, error=0.2946, accuracy=0.9219, val_error=0.3081, val_accuracy=0.9059
# 14/20, error=0.2937, accuracy=0.9227, val_error=0.3078, val_accuracy=0.9031
# 15/20, error=0.2929, accuracy=0.9221, val_error=0.3075, val_accuracy=0.905
# 16/20, error=0.2923, accuracy=0.9222, val_error=0.3072, val_accuracy=0.9041
# 17/20, error=0.2918, accuracy=0.9224, val_error=0.3069, val_accuracy=0.9059
# 18/20, error=0.2913, accuracy=0.9224, val_error=0.3066, val_accuracy=0.9059
# 19/20, error=0.2909, accuracy=0.9225, val_error=0.3062, val_accuracy=0.9077
# 20/20, error=0.2905, accuracy=0.9222, val_error=0.3059, val_accuracy=0.9087
# Layers : 2
# 1/20, error=0.4893, accuracy=0.891, val_error=0.3984, val_accuracy=0.8838
# 2/20, error=0.3603, accuracy=0.9092, val_error=0.3275, val_accuracy=0.9004
# 3/20, error=0.3362, accuracy=0.9135, val_error=0.2984, val_accuracy=0.9077
# 4/20, error=0.3233, accuracy=0.9163, val_error=0.2679, val_accuracy=0.9161
# 5/20, error=0.3158, accuracy=0.9191, val_error=0.2564, val_accuracy=0.9197
# 6/20, error=0.3103, accuracy=0.9198, val_error=0.2555, val_accuracy=0.9225
# 7/20, error=0.3062, accuracy=0.9213, val_error=0.2583, val_accuracy=0.9225
# 8/20, error=0.3028, accuracy=0.9225, val_error=0.2618, val_accuracy=0.9197
# 9/20, error=0.3001, accuracy=0.9231, val_error=0.2654, val_accuracy=0.9179
# 10/20, error=0.298, accuracy=0.9228, val_error=0.2689, val_accuracy=0.917
# 11/20, error=0.2964, accuracy=0.9231, val_error=0.2717, val_accuracy=0.9161
# 12/20, error=0.295, accuracy=0.9241, val_error=0.2739, val_accuracy=0.9188
# 13/20, error=0.2939, accuracy=0.924, val_error=0.2756, val_accuracy=0.917
# 14/20, error=0.293, accuracy=0.9242, val_error=0.2771, val_accuracy=0.9161
# 15/20, error=0.2923, accuracy=0.9246, val_error=0.2785, val_accuracy=0.9179
# 16/20, error=0.2918, accuracy=0.9242, val_error=0.2796, val_accuracy=0.9188
# 17/20, error=0.2913, accuracy=0.9241, val_error=0.2805, val_accuracy=0.9197
# 18/20, error=0.2908, accuracy=0.9238, val_error=0.2813, val_accuracy=0.9197
# 19/20, error=0.2904, accuracy=0.9236, val_error=0.2819, val_accuracy=0.9225
# 20/20, error=0.2901, accuracy=0.924, val_error=0.2824, val_accuracy=0.9234
# Test Accuracy =  0.8808571428571429
# Test Loss =  0.11369550490361185
# Balanced dataset shape: (9912, 784), (9912,)
# Balanced dataset shape: (1012, 784), (1012,)
# Layers : 1
# 1/20, error=0.2778, accuracy=0.9305, val_error=0.1552, val_accuracy=0.9615
# 2/20, error=0.183, accuracy=0.9532, val_error=0.1544, val_accuracy=0.9585
# 3/20, error=0.1628, accuracy=0.9592, val_error=0.15, val_accuracy=0.9625
# 4/20, error=0.1514, accuracy=0.9604, val_error=0.1457, val_accuracy=0.9625
# 5/20, error=0.1436, accuracy=0.9621, val_error=0.1423, val_accuracy=0.9615
# 6/20, error=0.1377, accuracy=0.9636, val_error=0.1398, val_accuracy=0.9634
# 7/20, error=0.1328, accuracy=0.964, val_error=0.1387, val_accuracy=0.9634
# 8/20, error=0.1289, accuracy=0.9646, val_error=0.1386, val_accuracy=0.9634
# 9/20, error=0.1257, accuracy=0.9661, val_error=0.1394, val_accuracy=0.9634
# 10/20, error=0.1231, accuracy=0.9662, val_error=0.1407, val_accuracy=0.9644
# 11/20, error=0.121, accuracy=0.967, val_error=0.1423, val_accuracy=0.9644
# 12/20, error=0.1191, accuracy=0.9676, val_error=0.1441, val_accuracy=0.9654
# 13/20, error=0.1174, accuracy=0.9676, val_error=0.1458, val_accuracy=0.9654
# 14/20, error=0.1159, accuracy=0.9685, val_error=0.1475, val_accuracy=0.9634
# 15/20, error=0.1145, accuracy=0.9684, val_error=0.1491, val_accuracy=0.9625
# 16/20, error=0.1132, accuracy=0.9685, val_error=0.1506, val_accuracy=0.9605
# 17/20, error=0.1121, accuracy=0.9687, val_error=0.1521, val_accuracy=0.9605
# 18/20, error=0.111, accuracy=0.9687, val_error=0.1535, val_accuracy=0.9605
# 19/20, error=0.11, accuracy=0.9689, val_error=0.1549, val_accuracy=0.9605
# 20/20, error=0.1091, accuracy=0.9691, val_error=0.1562, val_accuracy=0.9605
# 1/20, error=0.1676, accuracy=0.8214, val_error=0.0108, val_accuracy=0.9862
# 2/20, error=0.0085, accuracy=0.9894, val_error=0.004, val_accuracy=0.996
# 3/20, error=0.0032, accuracy=0.9961, val_error=0.0033, val_accuracy=0.997
# 4/20, error=0.0016, accuracy=0.9982, val_error=0.0022, val_accuracy=0.997
# 5/20, error=0.0008, accuracy=0.9993, val_error=0.0016, val_accuracy=0.998
# 6/20, error=0.0006, accuracy=0.9994, val_error=0.0014, val_accuracy=0.998
# 7/20, error=0.0004, accuracy=0.9997, val_error=0.0012, val_accuracy=0.998
# 8/20, error=0.0002, accuracy=0.9998, val_error=0.001, val_accuracy=0.999
# 9/20, error=0.0002, accuracy=0.9999, val_error=0.0009, val_accuracy=0.999
# 10/20, error=0.0001, accuracy=0.9999, val_error=0.0008, val_accuracy=0.999
# 11/20, error=0.0001, accuracy=0.9999, val_error=0.0007, val_accuracy=0.999
# 12/20, error=0.0001, accuracy=1.0, val_error=0.0007, val_accuracy=0.999
# 13/20, error=0.0, accuracy=1.0, val_error=0.0007, val_accuracy=0.999
# 14/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 15/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 16/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 17/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 18/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 19/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.999
# 20/20, error=0.0, accuracy=1.0, val_error=0.0005, val_accuracy=0.999
# Layers : 2
# 1/20, error=0.2597, accuracy=0.9362, val_error=0.1766, val_accuracy=0.9555
# 2/20, error=0.1822, accuracy=0.9541, val_error=0.1573, val_accuracy=0.9555
# 3/20, error=0.1644, accuracy=0.9583, val_error=0.149, val_accuracy=0.9615
# 4/20, error=0.1535, accuracy=0.9606, val_error=0.1444, val_accuracy=0.9615
# 5/20, error=0.1457, accuracy=0.9616, val_error=0.1418, val_accuracy=0.9634
# 6/20, error=0.1395, accuracy=0.9625, val_error=0.1403, val_accuracy=0.9654
# 7/20, error=0.1345, accuracy=0.9638, val_error=0.1395, val_accuracy=0.9654
# 8/20, error=0.1303, accuracy=0.9647, val_error=0.1391, val_accuracy=0.9654
# 9/20, error=0.127, accuracy=0.9652, val_error=0.1391, val_accuracy=0.9634
# 10/20, error=0.1242, accuracy=0.9652, val_error=0.139, val_accuracy=0.9615
# 11/20, error=0.1219, accuracy=0.9652, val_error=0.1391, val_accuracy=0.9615
# 12/20, error=0.1199, accuracy=0.9657, val_error=0.1394, val_accuracy=0.9625
# 13/20, error=0.1183, accuracy=0.966, val_error=0.1399, val_accuracy=0.9634
# 14/20, error=0.1168, accuracy=0.9658, val_error=0.1406, val_accuracy=0.9625
# 15/20, error=0.1155, accuracy=0.9667, val_error=0.1415, val_accuracy=0.9615
# 16/20, error=0.1143, accuracy=0.9668, val_error=0.1425, val_accuracy=0.9615
# 17/20, error=0.1132, accuracy=0.9671, val_error=0.1436, val_accuracy=0.9644
# 18/20, error=0.1122, accuracy=0.9673, val_error=0.1448, val_accuracy=0.9634
# 19/20, error=0.1113, accuracy=0.9672, val_error=0.1461, val_accuracy=0.9634
# 20/20, error=0.1105, accuracy=0.9676, val_error=0.1474, val_accuracy=0.9634
# Layers : 2
# 1/20, error=0.274, accuracy=0.9314, val_error=0.1512, val_accuracy=0.9615
# 2/20, error=0.1934, accuracy=0.9528, val_error=0.1415, val_accuracy=0.9625
# 3/20, error=0.1704, accuracy=0.9574, val_error=0.1386, val_accuracy=0.9615
# 4/20, error=0.1573, accuracy=0.96, val_error=0.1368, val_accuracy=0.9605
# 5/20, error=0.1485, accuracy=0.9621, val_error=0.1363, val_accuracy=0.9615
# 6/20, error=0.1419, accuracy=0.9619, val_error=0.137, val_accuracy=0.9615
# 7/20, error=0.1368, accuracy=0.9629, val_error=0.1386, val_accuracy=0.9605
# 8/20, error=0.1326, accuracy=0.9639, val_error=0.1407, val_accuracy=0.9595
# 9/20, error=0.1292, accuracy=0.9648, val_error=0.1428, val_accuracy=0.9615
# 10/20, error=0.1263, accuracy=0.9653, val_error=0.1447, val_accuracy=0.9615
# 11/20, error=0.1237, accuracy=0.9654, val_error=0.1465, val_accuracy=0.9605
# 12/20, error=0.1214, accuracy=0.9658, val_error=0.148, val_accuracy=0.9575
# 13/20, error=0.1195, accuracy=0.9662, val_error=0.1494, val_accuracy=0.9575
# 14/20, error=0.1178, accuracy=0.9667, val_error=0.1507, val_accuracy=0.9585
# 15/20, error=0.1163, accuracy=0.9669, val_error=0.1518, val_accuracy=0.9575
# 16/20, error=0.115, accuracy=0.9671, val_error=0.1529, val_accuracy=0.9585
# 17/20, error=0.1139, accuracy=0.9678, val_error=0.1539, val_accuracy=0.9575
# 18/20, error=0.1129, accuracy=0.9684, val_error=0.1548, val_accuracy=0.9575
# 19/20, error=0.1119, accuracy=0.9686, val_error=0.1557, val_accuracy=0.9575
# 20/20, error=0.1111, accuracy=0.9688, val_error=0.1565, val_accuracy=0.9575
# Test Accuracy =  0.9544285714285714
# Test Loss =  0.043690832477721174
# Balanced dataset shape: (9160, 784), (9160,)
# Balanced dataset shape: (906, 784), (906,)
# Layers : 1
# 1/20, error=0.521, accuracy=0.8728, val_error=0.4608, val_accuracy=0.8974
# 2/20, error=0.3973, accuracy=0.896, val_error=0.436, val_accuracy=0.8996
# 3/20, error=0.369, accuracy=0.9026, val_error=0.4274, val_accuracy=0.9018
# 4/20, error=0.3548, accuracy=0.9056, val_error=0.4185, val_accuracy=0.8996
# 5/20, error=0.3454, accuracy=0.9087, val_error=0.414, val_accuracy=0.9062
# 6/20, error=0.3386, accuracy=0.9092, val_error=0.4116, val_accuracy=0.9062
# 7/20, error=0.3335, accuracy=0.9103, val_error=0.4103, val_accuracy=0.9073
# 8/20, error=0.3295, accuracy=0.9116, val_error=0.4094, val_accuracy=0.9073
# 9/20, error=0.3262, accuracy=0.9121, val_error=0.4086, val_accuracy=0.9095
# 10/20, error=0.3236, accuracy=0.9132, val_error=0.4076, val_accuracy=0.9073
# 11/20, error=0.3214, accuracy=0.9134, val_error=0.4065, val_accuracy=0.9073
# 12/20, error=0.3196, accuracy=0.9142, val_error=0.4052, val_accuracy=0.9084
# 13/20, error=0.318, accuracy=0.9151, val_error=0.4039, val_accuracy=0.9062
# 14/20, error=0.3166, accuracy=0.9148, val_error=0.4017, val_accuracy=0.9062
# 15/20, error=0.3153, accuracy=0.9156, val_error=0.3995, val_accuracy=0.9073
# 16/20, error=0.314, accuracy=0.9159, val_error=0.3976, val_accuracy=0.9062
# 17/20, error=0.3128, accuracy=0.916, val_error=0.3961, val_accuracy=0.9051
# 18/20, error=0.3116, accuracy=0.9167, val_error=0.395, val_accuracy=0.9062
# 19/20, error=0.3105, accuracy=0.9166, val_error=0.3942, val_accuracy=0.9073
# 20/20, error=0.3095, accuracy=0.9169, val_error=0.3937, val_accuracy=0.9106
# 1/20, error=0.1027, accuracy=0.8845, val_error=0.0051, val_accuracy=0.9945
# 2/20, error=0.0034, accuracy=0.9955, val_error=0.0008, val_accuracy=1.0
# 3/20, error=0.0012, accuracy=0.9988, val_error=0.0002, val_accuracy=1.0
# 4/20, error=0.0006, accuracy=0.9995, val_error=0.0001, val_accuracy=1.0
# 5/20, error=0.0002, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 6/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 7/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 10/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.5617, accuracy=0.8632, val_error=0.4657, val_accuracy=0.8974
# 2/20, error=0.4104, accuracy=0.894, val_error=0.4328, val_accuracy=0.9051
# 3/20, error=0.3802, accuracy=0.9, val_error=0.4289, val_accuracy=0.904
# 4/20, error=0.3641, accuracy=0.9031, val_error=0.4285, val_accuracy=0.9029
# 5/20, error=0.3531, accuracy=0.9056, val_error=0.4261, val_accuracy=0.9051
# 6/20, error=0.3448, accuracy=0.9086, val_error=0.4217, val_accuracy=0.9073
# 7/20, error=0.3384, accuracy=0.9094, val_error=0.4166, val_accuracy=0.9051
# 8/20, error=0.3334, accuracy=0.9108, val_error=0.4123, val_accuracy=0.9062
# 9/20, error=0.3293, accuracy=0.9109, val_error=0.4093, val_accuracy=0.9062
# 10/20, error=0.3259, accuracy=0.912, val_error=0.4073, val_accuracy=0.9084
# 11/20, error=0.3232, accuracy=0.9124, val_error=0.4059, val_accuracy=0.9084
# 12/20, error=0.321, accuracy=0.9136, val_error=0.4047, val_accuracy=0.9073
# 13/20, error=0.319, accuracy=0.9147, val_error=0.4036, val_accuracy=0.9062
# 14/20, error=0.3173, accuracy=0.9151, val_error=0.4025, val_accuracy=0.9062
# 15/20, error=0.3158, accuracy=0.9152, val_error=0.399, val_accuracy=0.9051
# 16/20, error=0.3144, accuracy=0.9156, val_error=0.397, val_accuracy=0.9051
# 17/20, error=0.3132, accuracy=0.9158, val_error=0.3957, val_accuracy=0.9062
# 18/20, error=0.312, accuracy=0.916, val_error=0.3948, val_accuracy=0.9062
# 19/20, error=0.3109, accuracy=0.9157, val_error=0.3943, val_accuracy=0.9073
# 20/20, error=0.3099, accuracy=0.9158, val_error=0.3939, val_accuracy=0.9084
# Layers : 2
# 1/20, error=0.5512, accuracy=0.865, val_error=0.4416, val_accuracy=0.8974
# 2/20, error=0.4086, accuracy=0.893, val_error=0.4236, val_accuracy=0.8996
# 3/20, error=0.3779, accuracy=0.9009, val_error=0.4184, val_accuracy=0.8996
# 4/20, error=0.3617, accuracy=0.9037, val_error=0.4147, val_accuracy=0.9018
# 5/20, error=0.3516, accuracy=0.9061, val_error=0.4108, val_accuracy=0.9007
# 6/20, error=0.3438, accuracy=0.908, val_error=0.4062, val_accuracy=0.9007
# 7/20, error=0.3374, accuracy=0.9092, val_error=0.4023, val_accuracy=0.904
# 8/20, error=0.3324, accuracy=0.9107, val_error=0.3996, val_accuracy=0.9051
# 9/20, error=0.3283, accuracy=0.9117, val_error=0.398, val_accuracy=0.904
# 10/20, error=0.3251, accuracy=0.9123, val_error=0.3972, val_accuracy=0.904
# 11/20, error=0.3225, accuracy=0.9121, val_error=0.3966, val_accuracy=0.9051
# 12/20, error=0.3203, accuracy=0.9136, val_error=0.3962, val_accuracy=0.904
# 13/20, error=0.3185, accuracy=0.9135, val_error=0.3959, val_accuracy=0.9062
# 14/20, error=0.3168, accuracy=0.9147, val_error=0.3941, val_accuracy=0.9073
# 15/20, error=0.3151, accuracy=0.9157, val_error=0.3923, val_accuracy=0.9062
# 16/20, error=0.3135, accuracy=0.9159, val_error=0.3907, val_accuracy=0.9062
# 17/20, error=0.3121, accuracy=0.916, val_error=0.3894, val_accuracy=0.9073
# 18/20, error=0.3108, accuracy=0.9163, val_error=0.3885, val_accuracy=0.9084
# 19/20, error=0.3096, accuracy=0.9165, val_error=0.388, val_accuracy=0.9095
# 20/20, error=0.3084, accuracy=0.9162, val_error=0.3877, val_accuracy=0.9106
# Test Accuracy =  0.8792142857142857
# Test Loss =  0.11782405519078067
# Balanced dataset shape: (10006, 784), (10006,)
# Balanced dataset shape: (1022, 784), (1022,)
# Layers : 1
# 1/20, error=0.2342, accuracy=0.9496, val_error=0.2424, val_accuracy=0.9481
# 2/20, error=0.1656, accuracy=0.9615, val_error=0.2546, val_accuracy=0.9501
# 3/20, error=0.1487, accuracy=0.9633, val_error=0.2483, val_accuracy=0.9481
# 4/20, error=0.1397, accuracy=0.9647, val_error=0.2508, val_accuracy=0.9491
# 5/20, error=0.1342, accuracy=0.966, val_error=0.2608, val_accuracy=0.9501
# 6/20, error=0.1302, accuracy=0.9661, val_error=0.2692, val_accuracy=0.9501
# 7/20, error=0.1269, accuracy=0.967, val_error=0.273, val_accuracy=0.9491
# 8/20, error=0.1239, accuracy=0.9667, val_error=0.2733, val_accuracy=0.9511
# 9/20, error=0.1213, accuracy=0.9677, val_error=0.2722, val_accuracy=0.9511
# 10/20, error=0.1188, accuracy=0.9684, val_error=0.2709, val_accuracy=0.9511
# 11/20, error=0.1167, accuracy=0.9693, val_error=0.2698, val_accuracy=0.9501
# 12/20, error=0.1147, accuracy=0.9692, val_error=0.2689, val_accuracy=0.9521
# 13/20, error=0.1129, accuracy=0.9699, val_error=0.2684, val_accuracy=0.953
# 14/20, error=0.1113, accuracy=0.9705, val_error=0.2684, val_accuracy=0.9511
# 15/20, error=0.1098, accuracy=0.9709, val_error=0.269, val_accuracy=0.9521
# 16/20, error=0.1084, accuracy=0.9709, val_error=0.2701, val_accuracy=0.9521
# 17/20, error=0.1072, accuracy=0.9712, val_error=0.2717, val_accuracy=0.9521
# 18/20, error=0.1061, accuracy=0.9715, val_error=0.2738, val_accuracy=0.9521
# 19/20, error=0.105, accuracy=0.9715, val_error=0.276, val_accuracy=0.9521
# 20/20, error=0.104, accuracy=0.9719, val_error=0.2785, val_accuracy=0.9501
# 1/20, error=0.0337, accuracy=0.9577, val_error=0.0153, val_accuracy=0.9804
# 2/20, error=0.0081, accuracy=0.9904, val_error=0.0045, val_accuracy=0.9922
# 3/20, error=0.0038, accuracy=0.9952, val_error=0.0014, val_accuracy=0.998
# 4/20, error=0.0024, accuracy=0.9972, val_error=0.0007, val_accuracy=0.999
# 5/20, error=0.0014, accuracy=0.9982, val_error=0.0006, val_accuracy=0.999
# 6/20, error=0.0007, accuracy=0.9993, val_error=0.0005, val_accuracy=0.999
# 7/20, error=0.0004, accuracy=0.9997, val_error=0.0005, val_accuracy=0.999
# 8/20, error=0.0003, accuracy=0.9998, val_error=0.0004, val_accuracy=0.999
# 9/20, error=0.0003, accuracy=0.9998, val_error=0.0004, val_accuracy=0.999
# 10/20, error=0.0002, accuracy=0.9998, val_error=0.0003, val_accuracy=0.999
# 11/20, error=0.0002, accuracy=0.9998, val_error=0.0003, val_accuracy=0.999
# 12/20, error=0.0002, accuracy=0.9998, val_error=0.0002, val_accuracy=1.0
# 13/20, error=0.0002, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 14/20, error=0.0002, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 15/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 16/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 17/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 18/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 19/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 20/20, error=0.0001, accuracy=0.9999, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.2125, accuracy=0.9512, val_error=0.2835, val_accuracy=0.9462
# 2/20, error=0.1594, accuracy=0.9632, val_error=0.293, val_accuracy=0.9452
# 3/20, error=0.1456, accuracy=0.9639, val_error=0.2967, val_accuracy=0.9472
# 4/20, error=0.1375, accuracy=0.965, val_error=0.3025, val_accuracy=0.9462
# 5/20, error=0.132, accuracy=0.9662, val_error=0.3049, val_accuracy=0.9491
# 6/20, error=0.1278, accuracy=0.9669, val_error=0.3062, val_accuracy=0.9462
# 7/20, error=0.1244, accuracy=0.9668, val_error=0.3073, val_accuracy=0.9462
# 8/20, error=0.1215, accuracy=0.9669, val_error=0.3079, val_accuracy=0.9452
# 9/20, error=0.1189, accuracy=0.9672, val_error=0.3079, val_accuracy=0.9452
# 10/20, error=0.1165, accuracy=0.9678, val_error=0.3075, val_accuracy=0.9432
# 11/20, error=0.1143, accuracy=0.9683, val_error=0.3066, val_accuracy=0.9462
# 12/20, error=0.1123, accuracy=0.9688, val_error=0.3055, val_accuracy=0.9472
# 13/20, error=0.1105, accuracy=0.9693, val_error=0.3041, val_accuracy=0.9481
# 14/20, error=0.1089, accuracy=0.9701, val_error=0.3028, val_accuracy=0.9491
# 15/20, error=0.1075, accuracy=0.9705, val_error=0.3018, val_accuracy=0.9491
# 16/20, error=0.1062, accuracy=0.971, val_error=0.3013, val_accuracy=0.9491
# 17/20, error=0.1051, accuracy=0.9715, val_error=0.3014, val_accuracy=0.9481
# 18/20, error=0.104, accuracy=0.972, val_error=0.3019, val_accuracy=0.9491
# 19/20, error=0.1031, accuracy=0.9714, val_error=0.3029, val_accuracy=0.9501
# 20/20, error=0.1022, accuracy=0.9716, val_error=0.3042, val_accuracy=0.9491
# Layers : 2
# 1/20, error=0.2405, accuracy=0.9456, val_error=0.2537, val_accuracy=0.954
# 2/20, error=0.1659, accuracy=0.9617, val_error=0.2583, val_accuracy=0.9491
# 3/20, error=0.1487, accuracy=0.9628, val_error=0.2365, val_accuracy=0.9521
# 4/20, error=0.1382, accuracy=0.9652, val_error=0.2233, val_accuracy=0.9569
# 5/20, error=0.1315, accuracy=0.967, val_error=0.2223, val_accuracy=0.955
# 6/20, error=0.1272, accuracy=0.9676, val_error=0.227, val_accuracy=0.953
# 7/20, error=0.1242, accuracy=0.9681, val_error=0.2341, val_accuracy=0.9521
# 8/20, error=0.1216, accuracy=0.9685, val_error=0.2415, val_accuracy=0.9511
# 9/20, error=0.1194, accuracy=0.9692, val_error=0.2485, val_accuracy=0.9521
# 10/20, error=0.1173, accuracy=0.9698, val_error=0.2546, val_accuracy=0.9511
# 11/20, error=0.1153, accuracy=0.9698, val_error=0.2598, val_accuracy=0.9521
# 12/20, error=0.1136, accuracy=0.9705, val_error=0.2642, val_accuracy=0.9521
# 13/20, error=0.1119, accuracy=0.9709, val_error=0.2679, val_accuracy=0.9511
# 14/20, error=0.1104, accuracy=0.971, val_error=0.2711, val_accuracy=0.9521
# 15/20, error=0.109, accuracy=0.9712, val_error=0.2739, val_accuracy=0.9511
# 16/20, error=0.1077, accuracy=0.9715, val_error=0.2764, val_accuracy=0.9511
# 17/20, error=0.1065, accuracy=0.9718, val_error=0.2787, val_accuracy=0.9501
# 18/20, error=0.1054, accuracy=0.9722, val_error=0.2808, val_accuracy=0.9501
# 19/20, error=0.1044, accuracy=0.9723, val_error=0.2827, val_accuracy=0.9501
# 20/20, error=0.1034, accuracy=0.9727, val_error=0.2845, val_accuracy=0.9501
# Test Accuracy =  0.9222142857142858
# Test Loss =  0.07436920795348789
# Balanced dataset shape: (10508, 784), (10508,)
# Balanced dataset shape: (1084, 784), (1084,)
# Layers : 1
# 1/20, error=0.2354, accuracy=0.9395, val_error=0.1714, val_accuracy=0.9539
# 2/20, error=0.1669, accuracy=0.9546, val_error=0.1673, val_accuracy=0.9511
# 3/20, error=0.1519, accuracy=0.9589, val_error=0.1636, val_accuracy=0.952
# 4/20, error=0.1429, accuracy=0.9603, val_error=0.1611, val_accuracy=0.9539
# 5/20, error=0.1366, accuracy=0.9609, val_error=0.1607, val_accuracy=0.9566
# 6/20, error=0.1317, accuracy=0.962, val_error=0.1617, val_accuracy=0.9566
# 7/20, error=0.1278, accuracy=0.963, val_error=0.1634, val_accuracy=0.9585
# 8/20, error=0.1246, accuracy=0.9634, val_error=0.1656, val_accuracy=0.9585
# 9/20, error=0.1219, accuracy=0.9637, val_error=0.1682, val_accuracy=0.9585
# 10/20, error=0.1196, accuracy=0.9641, val_error=0.1711, val_accuracy=0.9576
# 11/20, error=0.1174, accuracy=0.9644, val_error=0.1742, val_accuracy=0.9566
# 12/20, error=0.1154, accuracy=0.9654, val_error=0.1776, val_accuracy=0.9548
# 13/20, error=0.1139, accuracy=0.966, val_error=0.1811, val_accuracy=0.953
# 14/20, error=0.1126, accuracy=0.9663, val_error=0.1843, val_accuracy=0.952
# 15/20, error=0.1114, accuracy=0.9666, val_error=0.1871, val_accuracy=0.9511
# 16/20, error=0.1104, accuracy=0.9668, val_error=0.1894, val_accuracy=0.9511
# 17/20, error=0.1096, accuracy=0.9675, val_error=0.1912, val_accuracy=0.9511
# 18/20, error=0.1088, accuracy=0.9675, val_error=0.1927, val_accuracy=0.9511
# 19/20, error=0.1081, accuracy=0.9677, val_error=0.1939, val_accuracy=0.9502
# 20/20, error=0.1074, accuracy=0.9681, val_error=0.1949, val_accuracy=0.9493
# 1/20, error=0.0528, accuracy=0.9379, val_error=0.0191, val_accuracy=0.9751
# 2/20, error=0.0131, accuracy=0.9837, val_error=0.0049, val_accuracy=0.9954
# 3/20, error=0.0049, accuracy=0.9942, val_error=0.0033, val_accuracy=0.9963
# 4/20, error=0.0025, accuracy=0.997, val_error=0.002, val_accuracy=0.9982
# 5/20, error=0.0013, accuracy=0.9985, val_error=0.0017, val_accuracy=0.9982
# 6/20, error=0.0008, accuracy=0.9992, val_error=0.0016, val_accuracy=0.9982
# 7/20, error=0.0006, accuracy=0.9995, val_error=0.0015, val_accuracy=0.9982
# 8/20, error=0.0005, accuracy=0.9996, val_error=0.0014, val_accuracy=0.9982
# 9/20, error=0.0004, accuracy=0.9996, val_error=0.0013, val_accuracy=0.9982
# 10/20, error=0.0004, accuracy=0.9996, val_error=0.0011, val_accuracy=0.9982
# 11/20, error=0.0003, accuracy=0.9997, val_error=0.001, val_accuracy=0.9982
# 12/20, error=0.0002, accuracy=0.9998, val_error=0.0009, val_accuracy=0.9982
# 13/20, error=0.0002, accuracy=0.9998, val_error=0.0009, val_accuracy=0.9982
# 14/20, error=0.0001, accuracy=0.9999, val_error=0.0009, val_accuracy=0.9982
# 15/20, error=0.0001, accuracy=0.9999, val_error=0.0009, val_accuracy=0.9982
# 16/20, error=0.0001, accuracy=0.9999, val_error=0.0009, val_accuracy=0.9982
# 17/20, error=0.0001, accuracy=0.9999, val_error=0.0009, val_accuracy=0.9991
# 18/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.9991
# 19/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.9991
# 20/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.9991
# Layers : 2
# 1/20, error=0.2449, accuracy=0.9405, val_error=0.1472, val_accuracy=0.9649
# 2/20, error=0.1631, accuracy=0.9555, val_error=0.1414, val_accuracy=0.9649
# 3/20, error=0.1479, accuracy=0.9578, val_error=0.1455, val_accuracy=0.9576
# 4/20, error=0.1393, accuracy=0.9602, val_error=0.1508, val_accuracy=0.9576
# 5/20, error=0.1332, accuracy=0.9621, val_error=0.1556, val_accuracy=0.9566
# 6/20, error=0.1287, accuracy=0.9633, val_error=0.1607, val_accuracy=0.9548
# 7/20, error=0.1252, accuracy=0.9639, val_error=0.1661, val_accuracy=0.9539
# 8/20, error=0.1225, accuracy=0.9644, val_error=0.1715, val_accuracy=0.953
# 9/20, error=0.1202, accuracy=0.9648, val_error=0.1768, val_accuracy=0.953
# 10/20, error=0.1182, accuracy=0.9654, val_error=0.1815, val_accuracy=0.9511
# 11/20, error=0.1166, accuracy=0.9664, val_error=0.1857, val_accuracy=0.952
# 12/20, error=0.1151, accuracy=0.9669, val_error=0.1893, val_accuracy=0.952
# 13/20, error=0.1138, accuracy=0.9674, val_error=0.1923, val_accuracy=0.952
# 14/20, error=0.1126, accuracy=0.9674, val_error=0.1947, val_accuracy=0.952
# 15/20, error=0.1116, accuracy=0.9672, val_error=0.1967, val_accuracy=0.952
# 16/20, error=0.1106, accuracy=0.9677, val_error=0.1983, val_accuracy=0.953
# 17/20, error=0.1098, accuracy=0.9675, val_error=0.1996, val_accuracy=0.953
# 18/20, error=0.109, accuracy=0.9677, val_error=0.2006, val_accuracy=0.953
# 19/20, error=0.1083, accuracy=0.9678, val_error=0.2014, val_accuracy=0.952
# 20/20, error=0.1076, accuracy=0.9684, val_error=0.202, val_accuracy=0.952
# Layers : 2
# 1/20, error=0.2506, accuracy=0.9374, val_error=0.1525, val_accuracy=0.9576
# 2/20, error=0.1697, accuracy=0.9548, val_error=0.1474, val_accuracy=0.9576
# 3/20, error=0.1541, accuracy=0.9579, val_error=0.1464, val_accuracy=0.953
# 4/20, error=0.1446, accuracy=0.9601, val_error=0.1486, val_accuracy=0.952
# 5/20, error=0.1377, accuracy=0.9619, val_error=0.152, val_accuracy=0.953
# 6/20, error=0.1324, accuracy=0.9637, val_error=0.1559, val_accuracy=0.953
# 7/20, error=0.1284, accuracy=0.9643, val_error=0.1604, val_accuracy=0.9539
# 8/20, error=0.1253, accuracy=0.9645, val_error=0.1649, val_accuracy=0.9539
# 9/20, error=0.1229, accuracy=0.9652, val_error=0.169, val_accuracy=0.952
# 10/20, error=0.1207, accuracy=0.9661, val_error=0.1727, val_accuracy=0.9511
# 11/20, error=0.1189, accuracy=0.9661, val_error=0.1761, val_accuracy=0.9511
# 12/20, error=0.1174, accuracy=0.966, val_error=0.1791, val_accuracy=0.9511
# 13/20, error=0.116, accuracy=0.9664, val_error=0.1819, val_accuracy=0.9511
# 14/20, error=0.1148, accuracy=0.9671, val_error=0.1843, val_accuracy=0.9511
# 15/20, error=0.1137, accuracy=0.9675, val_error=0.1864, val_accuracy=0.9511
# 16/20, error=0.1128, accuracy=0.9677, val_error=0.1882, val_accuracy=0.9511
# 17/20, error=0.1119, accuracy=0.9675, val_error=0.1898, val_accuracy=0.9511
# 18/20, error=0.1111, accuracy=0.9675, val_error=0.1913, val_accuracy=0.9502
# 19/20, error=0.1104, accuracy=0.9677, val_error=0.1926, val_accuracy=0.9502
# 20/20, error=0.1097, accuracy=0.9678, val_error=0.1937, val_accuracy=0.9511
# Test Accuracy =  0.9722857142857143
# Test Loss =  0.027057914289734905
# Balanced dataset shape: (10016, 784), (10016,)
# Balanced dataset shape: (918, 784), (918,)
# Layers : 1
# 1/20, error=0.6315, accuracy=0.8425, val_error=0.4262, val_accuracy=0.8627
# 2/20, error=0.4852, accuracy=0.8722, val_error=0.3717, val_accuracy=0.878
# 3/20, error=0.4663, accuracy=0.8761, val_error=0.3641, val_accuracy=0.8889
# 4/20, error=0.4575, accuracy=0.8796, val_error=0.367, val_accuracy=0.8878
# 5/20, error=0.4517, accuracy=0.8801, val_error=0.3717, val_accuracy=0.8878
# 6/20, error=0.4475, accuracy=0.8808, val_error=0.3776, val_accuracy=0.8889
# 7/20, error=0.4442, accuracy=0.8808, val_error=0.383, val_accuracy=0.8911
# 8/20, error=0.4416, accuracy=0.8821, val_error=0.3874, val_accuracy=0.8911
# 9/20, error=0.4396, accuracy=0.8828, val_error=0.3909, val_accuracy=0.89
# 10/20, error=0.438, accuracy=0.8834, val_error=0.394, val_accuracy=0.89
# 11/20, error=0.4366, accuracy=0.8832, val_error=0.3968, val_accuracy=0.8889
# 12/20, error=0.4356, accuracy=0.8833, val_error=0.3993, val_accuracy=0.8911
# 13/20, error=0.4347, accuracy=0.8829, val_error=0.4014, val_accuracy=0.8922
# 14/20, error=0.434, accuracy=0.883, val_error=0.4033, val_accuracy=0.8911
# 15/20, error=0.4334, accuracy=0.8825, val_error=0.4049, val_accuracy=0.8911
# 16/20, error=0.4329, accuracy=0.8825, val_error=0.4063, val_accuracy=0.8911
# 17/20, error=0.4324, accuracy=0.8825, val_error=0.4075, val_accuracy=0.8922
# 18/20, error=0.432, accuracy=0.8824, val_error=0.4085, val_accuracy=0.8922
# 19/20, error=0.4315, accuracy=0.8831, val_error=0.4094, val_accuracy=0.8922
# 20/20, error=0.4311, accuracy=0.8837, val_error=0.4101, val_accuracy=0.8922
# 1/20, error=0.1151, accuracy=0.8708, val_error=0.0072, val_accuracy=0.9913
# 2/20, error=0.0031, accuracy=0.9957, val_error=0.0016, val_accuracy=0.9978
# 3/20, error=0.0008, accuracy=0.9993, val_error=0.0006, val_accuracy=1.0
# 4/20, error=0.0004, accuracy=0.9997, val_error=0.0003, val_accuracy=1.0
# 5/20, error=0.0002, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 6/20, error=0.0002, accuracy=0.9999, val_error=0.0001, val_accuracy=1.0
# 7/20, error=0.0002, accuracy=0.9999, val_error=0.0001, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=0.9999, val_error=0.0001, val_accuracy=1.0
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 10/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.6478, accuracy=0.8412, val_error=0.4206, val_accuracy=0.8693
# 2/20, error=0.4898, accuracy=0.87, val_error=0.3945, val_accuracy=0.8867
# 3/20, error=0.4673, accuracy=0.8753, val_error=0.3883, val_accuracy=0.8856
# 4/20, error=0.4563, accuracy=0.8781, val_error=0.3858, val_accuracy=0.8856
# 5/20, error=0.4497, accuracy=0.8794, val_error=0.3865, val_accuracy=0.8834
# 6/20, error=0.4455, accuracy=0.8807, val_error=0.3887, val_accuracy=0.8889
# 7/20, error=0.4427, accuracy=0.8811, val_error=0.3914, val_accuracy=0.8889
# 8/20, error=0.4406, accuracy=0.8816, val_error=0.3946, val_accuracy=0.89
# 9/20, error=0.439, accuracy=0.8822, val_error=0.3979, val_accuracy=0.8878
# 10/20, error=0.4377, accuracy=0.8829, val_error=0.4012, val_accuracy=0.8911
# 11/20, error=0.4366, accuracy=0.8831, val_error=0.4043, val_accuracy=0.8911
# 12/20, error=0.4356, accuracy=0.883, val_error=0.4071, val_accuracy=0.8922
# 13/20, error=0.4348, accuracy=0.8833, val_error=0.4095, val_accuracy=0.8911
# 14/20, error=0.4341, accuracy=0.8841, val_error=0.4115, val_accuracy=0.89
# 15/20, error=0.4335, accuracy=0.8853, val_error=0.4131, val_accuracy=0.8889
# 16/20, error=0.4329, accuracy=0.8852, val_error=0.4145, val_accuracy=0.8889
# 17/20, error=0.4324, accuracy=0.8849, val_error=0.4156, val_accuracy=0.8889
# 18/20, error=0.4319, accuracy=0.8854, val_error=0.4165, val_accuracy=0.89
# 19/20, error=0.4315, accuracy=0.8856, val_error=0.4174, val_accuracy=0.8889
# 20/20, error=0.4311, accuracy=0.886, val_error=0.4181, val_accuracy=0.8878
# Layers : 2
# 1/20, error=0.6153, accuracy=0.8455, val_error=0.4132, val_accuracy=0.8845
# 2/20, error=0.4859, accuracy=0.8706, val_error=0.3982, val_accuracy=0.8845
# 3/20, error=0.467, accuracy=0.8751, val_error=0.3917, val_accuracy=0.8856
# 4/20, error=0.4584, accuracy=0.8775, val_error=0.3903, val_accuracy=0.8878
# 5/20, error=0.4534, accuracy=0.8792, val_error=0.3911, val_accuracy=0.8911
# 6/20, error=0.4494, accuracy=0.88, val_error=0.3936, val_accuracy=0.8954
# 7/20, error=0.4462, accuracy=0.881, val_error=0.3971, val_accuracy=0.8922
# 8/20, error=0.4438, accuracy=0.8816, val_error=0.4008, val_accuracy=0.8922
# 9/20, error=0.4418, accuracy=0.8814, val_error=0.4044, val_accuracy=0.8922
# 10/20, error=0.4402, accuracy=0.8822, val_error=0.4079, val_accuracy=0.8911
# 11/20, error=0.4387, accuracy=0.8829, val_error=0.4109, val_accuracy=0.8922
# 12/20, error=0.4375, accuracy=0.8833, val_error=0.4136, val_accuracy=0.8911
# 13/20, error=0.4365, accuracy=0.8834, val_error=0.4158, val_accuracy=0.8911
# 14/20, error=0.4357, accuracy=0.883, val_error=0.4177, val_accuracy=0.89
# 15/20, error=0.4349, accuracy=0.8829, val_error=0.4192, val_accuracy=0.89
# 16/20, error=0.4342, accuracy=0.8831, val_error=0.4204, val_accuracy=0.89
# 17/20, error=0.4337, accuracy=0.8835, val_error=0.4214, val_accuracy=0.89
# 18/20, error=0.4332, accuracy=0.8834, val_error=0.4222, val_accuracy=0.8889
# 19/20, error=0.4327, accuracy=0.8839, val_error=0.4229, val_accuracy=0.89
# 20/20, error=0.4323, accuracy=0.8842, val_error=0.4234, val_accuracy=0.8889
# Test Accuracy =  0.8924285714285715
# Test Loss =  0.10568229461803179
# Balanced dataset shape: (10214, 784), (10214,)
# Balanced dataset shape: (966, 784), (966,)
# Layers : 1
# 1/20, error=0.5056, accuracy=0.8789, val_error=0.2109, val_accuracy=0.9275
# 2/20, error=0.361, accuracy=0.9038, val_error=0.1641, val_accuracy=0.9441
# 3/20, error=0.337, accuracy=0.9078, val_error=0.1632, val_accuracy=0.9451
# 4/20, error=0.3247, accuracy=0.9092, val_error=0.1676, val_accuracy=0.941
# 5/20, error=0.3173, accuracy=0.9113, val_error=0.1698, val_accuracy=0.9389
# 6/20, error=0.3123, accuracy=0.9133, val_error=0.1711, val_accuracy=0.94
# 7/20, error=0.3086, accuracy=0.9147, val_error=0.1725, val_accuracy=0.9379
# 8/20, error=0.3058, accuracy=0.9155, val_error=0.1741, val_accuracy=0.94
# 9/20, error=0.3037, accuracy=0.9155, val_error=0.1759, val_accuracy=0.94
# 10/20, error=0.302, accuracy=0.9159, val_error=0.1778, val_accuracy=0.941
# 11/20, error=0.3004, accuracy=0.9169, val_error=0.1796, val_accuracy=0.941
# 12/20, error=0.2991, accuracy=0.9174, val_error=0.1816, val_accuracy=0.942
# 13/20, error=0.298, accuracy=0.9171, val_error=0.1835, val_accuracy=0.942
# 14/20, error=0.297, accuracy=0.9175, val_error=0.1854, val_accuracy=0.941
# 15/20, error=0.2961, accuracy=0.9179, val_error=0.1872, val_accuracy=0.94
# 16/20, error=0.2952, accuracy=0.9183, val_error=0.1889, val_accuracy=0.9389
# 17/20, error=0.2945, accuracy=0.9185, val_error=0.1906, val_accuracy=0.9389
# 18/20, error=0.2938, accuracy=0.9189, val_error=0.1922, val_accuracy=0.9389
# 19/20, error=0.2931, accuracy=0.9183, val_error=0.1937, val_accuracy=0.94
# 20/20, error=0.2925, accuracy=0.9188, val_error=0.1951, val_accuracy=0.9389
# 1/20, error=0.0534, accuracy=0.9354, val_error=0.0089, val_accuracy=0.9865
# 2/20, error=0.0055, accuracy=0.9929, val_error=0.0006, val_accuracy=1.0
# 3/20, error=0.002, accuracy=0.9977, val_error=0.0002, val_accuracy=1.0
# 4/20, error=0.001, accuracy=0.9988, val_error=0.0001, val_accuracy=1.0
# 5/20, error=0.0006, accuracy=0.9995, val_error=0.0001, val_accuracy=1.0
# 6/20, error=0.0004, accuracy=0.9997, val_error=0.0001, val_accuracy=1.0
# 7/20, error=0.0003, accuracy=0.9998, val_error=0.0001, val_accuracy=1.0
# 8/20, error=0.0003, accuracy=0.9998, val_error=0.0001, val_accuracy=1.0
# 9/20, error=0.0002, accuracy=0.9998, val_error=0.0001, val_accuracy=1.0
# 10/20, error=0.0002, accuracy=0.9998, val_error=0.0, val_accuracy=1.0
# 11/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 12/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 13/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 14/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 15/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 16/20, error=0.0001, accuracy=0.9999, val_error=0.0, val_accuracy=1.0
# 17/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.491, accuracy=0.8817, val_error=0.2038, val_accuracy=0.9358
# 2/20, error=0.3536, accuracy=0.9056, val_error=0.1706, val_accuracy=0.941
# 3/20, error=0.3309, accuracy=0.9085, val_error=0.1621, val_accuracy=0.9441
# 4/20, error=0.3195, accuracy=0.9111, val_error=0.16, val_accuracy=0.9441
# 5/20, error=0.3129, accuracy=0.913, val_error=0.1601, val_accuracy=0.9462
# 6/20, error=0.3083, accuracy=0.9143, val_error=0.1613, val_accuracy=0.9451
# 7/20, error=0.3052, accuracy=0.916, val_error=0.1631, val_accuracy=0.9451
# 8/20, error=0.3028, accuracy=0.916, val_error=0.1651, val_accuracy=0.942
# 9/20, error=0.301, accuracy=0.9169, val_error=0.1672, val_accuracy=0.941
# 10/20, error=0.2995, accuracy=0.9169, val_error=0.1693, val_accuracy=0.941
# 11/20, error=0.2982, accuracy=0.9174, val_error=0.1713, val_accuracy=0.941
# 12/20, error=0.2971, accuracy=0.9178, val_error=0.1733, val_accuracy=0.94
# 13/20, error=0.2961, accuracy=0.9174, val_error=0.1752, val_accuracy=0.94
# 14/20, error=0.2954, accuracy=0.9177, val_error=0.1771, val_accuracy=0.9389
# 15/20, error=0.2947, accuracy=0.9178, val_error=0.179, val_accuracy=0.94
# 16/20, error=0.294, accuracy=0.9183, val_error=0.1809, val_accuracy=0.9389
# 17/20, error=0.2934, accuracy=0.9185, val_error=0.1828, val_accuracy=0.9389
# 18/20, error=0.2928, accuracy=0.9185, val_error=0.1846, val_accuracy=0.9389
# 19/20, error=0.2923, accuracy=0.9192, val_error=0.1864, val_accuracy=0.9389
# 20/20, error=0.2918, accuracy=0.9193, val_error=0.1882, val_accuracy=0.9389
# Layers : 2
# 1/20, error=0.4754, accuracy=0.8853, val_error=0.2534, val_accuracy=0.9161
# 2/20, error=0.353, accuracy=0.9051, val_error=0.2302, val_accuracy=0.9172
# 3/20, error=0.332, accuracy=0.909, val_error=0.1846, val_accuracy=0.94
# 4/20, error=0.3214, accuracy=0.9115, val_error=0.1744, val_accuracy=0.94
# 5/20, error=0.3145, accuracy=0.9134, val_error=0.1717, val_accuracy=0.941
# 6/20, error=0.31, accuracy=0.9143, val_error=0.1711, val_accuracy=0.941
# 7/20, error=0.3068, accuracy=0.9161, val_error=0.1716, val_accuracy=0.9389
# 8/20, error=0.3042, accuracy=0.9165, val_error=0.173, val_accuracy=0.94
# 9/20, error=0.3021, accuracy=0.9166, val_error=0.1747, val_accuracy=0.94
# 10/20, error=0.3003, accuracy=0.9174, val_error=0.1766, val_accuracy=0.942
# 11/20, error=0.2988, accuracy=0.9175, val_error=0.1786, val_accuracy=0.94
# 12/20, error=0.2975, accuracy=0.9181, val_error=0.1805, val_accuracy=0.9389
# 13/20, error=0.2964, accuracy=0.9181, val_error=0.1826, val_accuracy=0.9369
# 14/20, error=0.2955, accuracy=0.9186, val_error=0.1847, val_accuracy=0.9369
# 15/20, error=0.2947, accuracy=0.9191, val_error=0.1867, val_accuracy=0.9379
# 16/20, error=0.2939, accuracy=0.9186, val_error=0.1886, val_accuracy=0.9358
# 17/20, error=0.2932, accuracy=0.9192, val_error=0.1905, val_accuracy=0.9348
# 18/20, error=0.2925, accuracy=0.9197, val_error=0.1923, val_accuracy=0.9348
# 19/20, error=0.2919, accuracy=0.9204, val_error=0.194, val_accuracy=0.9358
# 20/20, error=0.2913, accuracy=0.9202, val_error=0.1956, val_accuracy=0.9358
# Test Accuracy =  0.9332857142857143
# Test Loss =  0.06574931649313784

# %%
X_in,y_in,X_v,y_v,y_t = get_XY(X_train,y_train,X_val,y_val,y_test,7)
# Out:
# Balanced dataset shape: (10508, 784), (10508,)
# Balanced dataset shape: (1084, 784), (1084,)

# %%
X_sample = np.array(X_test)

# %%
plt.imshow(X_sample[200].reshape(28,28))

# %%
def predict_tree_classifiers(tree_classifier,X_sample):
    predictions = []
    pred_all = []
    for classifier in tree_classifier:
        pred = classifier.predict(X_sample)
        pred_all.append(pred)
    predicts = np.array(pred_all).squeeze().transpose()
    for pred in predicts:
        predictions.append(np.argmax(pred))
    return np.array(predictions).astype(int)

# %%
predictions = predict_tree_classifiers(tree_classifier,X_sample)

# %%
acc = 0
for pred,true in zip(predictions,y_test):
    if pred==true:
        acc+=1
print(acc/len(X_sample))
# Out:
# 0.815

# %%
index =0
fig = plt.figure(figsize=(10, 15)) 

rows = 4
columns = 3
for classifier in tree_classifier:
    fig.add_subplot(rows, columns, index+1) 
    plt.imshow(classifier.NN[0].weights.squeeze()[:-2].reshape(28,28))
    plt.axis('off') 
    plt.title('classifier:{}'.format(index))
    index+=1
