# %%
from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score,classification_report
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tqdm.notebook as tqdm
from sklearn.utils import shuffle

# %%
from NeuralNetwork.dense import Dense
from NeuralNetwork.activations import Sigmoid,Softmax,ReLU
from NeuralNetwork.losses import categorical_crossentropy, categorical_crossentropy_derive,mse,mse_derive,binary_crossentropy,binary_crossentropy_derive
from NeuralNetwork.network import predict

# %%
mnist = fetch_openml('mnist_784')

# %%
X = mnist.data/255.0
labels = np.array( mnist.target).astype(int)

# %%
#y = np.squeeze(np.eye(10)[labels])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,labels,test_size=0.2,shuffle=True)
X_val, y_val = X_train.iloc[:1000],y_train[:1000]
X_train, y_train = X_train.iloc[1000:2000],y_train[1000:2000]

# %%
EPOCH = 20
ALPHA = 0.08

# %%
def encode(z):
    if z>=0.5:
        return 1
    return 0

# %%
from sklearn.utils import shuffle
def get_top(X,labels,k=100):
    #dataset = np.column_stack((X,labels))
    X_sample, labels_sample = shuffle(X, labels, )

    topk = []
    for _class in range(10):
        class_index = np.where(labels_sample==_class)[0][:k]
        topk.append(np.column_stack((X_sample.iloc[class_index],labels_sample[class_index])))
    topk = np.vstack(topk)
    return topk

# %%
def train(NN, loss, loss_derive, X, Y, X_val,Y_val, epoch=EPOCH, alpha=ALPHA, verbose = True):
    error_TS = []
    acc_TS = []
    val_acc_TS = []
    val_error_TS = []
    for e in range(epoch):
        errors = 0
        acc = 0
        val_acc = 0
        val_error = 0
        for x, y in zip(X, Y):
            out = predict(NN, x)
            if y==encode(out):
                acc+=1
            errors += loss(y, out)
            gradient = loss_derive(y, out)
            for layer in reversed(NN):
                gradient = layer.backward(gradient, alpha)

        for x, y in zip(X_val, Y_val):
            output = predict(NN, x)
            if y==encode(output):
                val_acc+=1
            val_error += loss(y, output)

        errors /= len(X)
        acc /=len(X)
        val_error /= len(X_val)
        val_acc /=len(X_val)
        if verbose:
            print(f"{e + 1}/{epoch}, error={round(errors,4)}, accuracy={round(acc,4)}, val_error={round(val_error,4)}, val_accuracy={round(val_acc,4)}")
        error_TS.append(errors)
        acc_TS.append(acc)
        val_error_TS.append(val_error)
        val_acc_TS.append(val_acc)
    return [error_TS,acc_TS,val_error_TS,val_acc_TS]

class TreeNN():
    def __init__(self,depth=1,max_depth=3,parent_node = None):
        self.parent_node = parent_node
        self.NN = [
            Dense(784,1),
            Sigmoid()
        ]
        self.depth = depth
        self.max_depth = max_depth
        self.children = []
    
    def get_augemented(self,X,Y):
        Xa_train = []
        Xb_train = []
        for x, y in zip(X, Y):
            output = encode(predict(self.NN, x))
            if y!=output:
                if output==0 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
                if output==1 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

            else:
                if output==0 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

                if output==1 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
        return Xa_train,Xb_train
    
    def plot(self,metrics):
        metrics_names = ['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy']
        for i in range(len(metrics_names)):
            plt.plot(metrics[i])
            plt.xlabel("Epochs")
            plt.ylabel(metrics_names[i])
            plt.savefig("./graph/MNIST_{}_{}.png".format(metrics_names[i],self.depth))
            plt.clf()


    
    def train_tree(self,X,Y,X_val,Y_val):
        print("Layers :",self.depth)
        X_train = np.reshape(X,X.shape +(1,))
        Y_train = np.reshape(Y,Y.shape +(1,))
        X_val_in =np.reshape(X_val,X_val.shape +(1,))
        Y_val_in =np.reshape(Y_val,Y_val.shape +(1,))
        metrics = train(self.NN,binary_crossentropy,binary_crossentropy_derive,X_train,Y_train,X_val_in,Y_val_in)
        self.plot(metrics)
        if self.max_depth>self.depth+1:
            ## Adding Layers
            Na = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            Nb = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            self.children.append(Na)
            self.children.append(Nb)
            #Retrain with extra feature
            Xa_train,Xb_train = self.get_augemented(X_train,Y_train)
            X_retrain = np.column_stack((X, Xa_train))
            X_retrain = np.column_stack((X_retrain, Xb_train))
            X_retrain = np.reshape(X_retrain,X_retrain.shape+(1,))
            Xa,Xb = self.get_augemented(X_val_in,Y_val_in)
            X_reval = np.column_stack((X_val, Xa))
            X_reval = np.column_stack((X_reval, Xb))
            X_reval = np.reshape(X_reval,X_reval.shape+(1,))
            self.NN = [Dense(786,1),Sigmoid()]
            metrics = train(self.NN,mse,mse_derive,X_retrain,Y_train,X_reval,Y_val_in)
            self.plot(metrics)
            #Na
            self.children[0].train_tree(X,np.asanyarray(Xa_train),X_val,np.asanyarray(Xa))
            #Nb
            self.children[1].train_tree(X,np.asanyarray(Xb_train),X_val,np.asanyarray(Xb))

    def predict(self,X):
        if self.depth>self.max_depth:
            return  None  
        predictions = []

        if self.children == []:
            X_train = np.reshape(X,X.shape +(1,))
        else:
            Xa = self.children[0].predict(X)
            Xb = self.children[1].predict(X)
            Xa_encode = []
            Xb_encode = []
            for xa,xb in zip(Xa,Xb):
                Xa_encode.append(encode(xa))
                Xb_encode.append(encode(xb))
            X_train = np.column_stack((X, Xa_encode))
            X_train = np.column_stack((X_train, Xb_encode))
            X_train = np.reshape(X_train,X_train.shape+(1,))
        for x in X_train:
            output = predict(self.NN,x)
            predictions.append(output)

        return predictions
        # check for more probability

# %%
def get_XY(X_train,y_train,X_val,y_val,y_test,class_):
    y_in = np.where(y_train == class_, 1, 0)
    y_v = np.where(y_val == class_, 1, 0)
    y_t = np.where(y_test == class_, 1, 0)
    X_in,y_in= oversample(X_train,y_in)
    X_v,y_v= oversample(X_val,y_v)
    return X_in,y_in,X_v,y_v,y_t

# %%
tree_classifier = []
for classifier in tqdm.tqdm(range(10)):
    root = TreeNN(max_depth=3,parent_node=None)
    X_in,y_in,X_v,y_v,y_t = get_XY(X_train,y_train,X_val,y_val,y_test,classifier)
    root.train_tree(X_in,y_in,X_v,y_v)
    tree_classifier.append(root)
    pred = root.predict(X_test)
    acc = 0
    error = 0
    for p,t in zip(pred,y_t):
        if encode(p)==t:
            acc+=1
        error+=mse(p,t)
    print("Test Accuracy = ",acc/len(y_t))
    print("Test Loss = ",error/len(y_t))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Balanced dataset shape: (1816, 784), (1816,)
# Balanced dataset shape: (1808, 784), (1808,)
# Layers : 1
# 1/20, error=0.1754, accuracy=0.9532, val_error=0.2528, val_accuracy=0.9369
# 2/20, error=0.0326, accuracy=0.9923, val_error=0.2583, val_accuracy=0.9336
# 3/20, error=0.0154, accuracy=0.9961, val_error=0.2677, val_accuracy=0.9303
# 4/20, error=0.008, accuracy=0.9983, val_error=0.2783, val_accuracy=0.9309
# 5/20, error=0.0052, accuracy=0.9994, val_error=0.2854, val_accuracy=0.9204
# 6/20, error=0.0037, accuracy=0.9994, val_error=0.2883, val_accuracy=0.9204
# 7/20, error=0.0029, accuracy=1.0, val_error=0.2892, val_accuracy=0.9314
# 8/20, error=0.0024, accuracy=1.0, val_error=0.2898, val_accuracy=0.9314
# 9/20, error=0.0021, accuracy=1.0, val_error=0.2903, val_accuracy=0.9314
# 10/20, error=0.0019, accuracy=1.0, val_error=0.2907, val_accuracy=0.9314
# 11/20, error=0.0017, accuracy=1.0, val_error=0.2912, val_accuracy=0.9314
# 12/20, error=0.0016, accuracy=1.0, val_error=0.2917, val_accuracy=0.9314
# 13/20, error=0.0015, accuracy=1.0, val_error=0.2922, val_accuracy=0.9314
# 14/20, error=0.0014, accuracy=1.0, val_error=0.2927, val_accuracy=0.9314
# 15/20, error=0.0013, accuracy=1.0, val_error=0.2933, val_accuracy=0.9314
# 16/20, error=0.0012, accuracy=1.0, val_error=0.2938, val_accuracy=0.932
# 17/20, error=0.0011, accuracy=1.0, val_error=0.2943, val_accuracy=0.932
# 18/20, error=0.0011, accuracy=1.0, val_error=0.2948, val_accuracy=0.932
# 19/20, error=0.001, accuracy=1.0, val_error=0.2953, val_accuracy=0.932
# 20/20, error=0.001, accuracy=1.0, val_error=0.2957, val_accuracy=0.9358
# 1/20, error=0.067, accuracy=0.9185, val_error=0.0743, val_accuracy=0.9065
# 2/20, error=0.0185, accuracy=0.9791, val_error=0.0465, val_accuracy=0.948
# 3/20, error=0.0105, accuracy=0.9884, val_error=0.045, val_accuracy=0.9469
# 4/20, error=0.0063, accuracy=0.9939, val_error=0.0464, val_accuracy=0.9436
# 5/20, error=0.0052, accuracy=0.9945, val_error=0.0436, val_accuracy=0.9563
# 6/20, error=0.0043, accuracy=0.9961, val_error=0.0433, val_accuracy=0.9541
# 7/20, error=0.0038, accuracy=0.9961, val_error=0.0431, val_accuracy=0.9546
# 8/20, error=0.0036, accuracy=0.9967, val_error=0.043, val_accuracy=0.9546
# 9/20, error=0.0034, accuracy=0.9967, val_error=0.0432, val_accuracy=0.948
# 10/20, error=0.0033, accuracy=0.9967, val_error=0.044, val_accuracy=0.948
# 11/20, error=0.003, accuracy=0.9967, val_error=0.0457, val_accuracy=0.948
# 12/20, error=0.0027, accuracy=0.9972, val_error=0.047, val_accuracy=0.9386
# 13/20, error=0.0025, accuracy=0.9978, val_error=0.0461, val_accuracy=0.9386
# 14/20, error=0.0024, accuracy=0.9978, val_error=0.0438, val_accuracy=0.9386
# 15/20, error=0.0024, accuracy=0.9978, val_error=0.0429, val_accuracy=0.9386
# 16/20, error=0.0023, accuracy=0.9978, val_error=0.0424, val_accuracy=0.9386
# 17/20, error=0.0023, accuracy=0.9978, val_error=0.042, val_accuracy=0.9386
# 18/20, error=0.0023, accuracy=0.9978, val_error=0.0417, val_accuracy=0.948
# 19/20, error=0.0023, accuracy=0.9978, val_error=0.0414, val_accuracy=0.948
# 20/20, error=0.0023, accuracy=0.9978, val_error=0.0411, val_accuracy=0.9486
# Layers : 2
# 1/20, error=0.2037, accuracy=0.951, val_error=0.1605, val_accuracy=0.9563
# 2/20, error=0.0353, accuracy=0.9901, val_error=0.157, val_accuracy=0.9502
# 3/20, error=0.0163, accuracy=0.9961, val_error=0.1548, val_accuracy=0.9469
# 4/20, error=0.009, accuracy=0.9983, val_error=0.1644, val_accuracy=0.9502
# 5/20, error=0.006, accuracy=0.9989, val_error=0.1763, val_accuracy=0.9502
# 6/20, error=0.0041, accuracy=0.9994, val_error=0.1856, val_accuracy=0.9419
# 7/20, error=0.003, accuracy=1.0, val_error=0.1904, val_accuracy=0.9419
# 8/20, error=0.0024, accuracy=1.0, val_error=0.1933, val_accuracy=0.9425
# 9/20, error=0.0021, accuracy=1.0, val_error=0.1956, val_accuracy=0.9436
# 10/20, error=0.0018, accuracy=1.0, val_error=0.1975, val_accuracy=0.9436
# 11/20, error=0.0017, accuracy=1.0, val_error=0.1991, val_accuracy=0.9336
# 12/20, error=0.0015, accuracy=1.0, val_error=0.2006, val_accuracy=0.9419
# 13/20, error=0.0014, accuracy=1.0, val_error=0.2019, val_accuracy=0.9414
# 14/20, error=0.0013, accuracy=1.0, val_error=0.203, val_accuracy=0.9414
# 15/20, error=0.0012, accuracy=1.0, val_error=0.2041, val_accuracy=0.9414
# 16/20, error=0.0011, accuracy=1.0, val_error=0.2051, val_accuracy=0.9414
# 17/20, error=0.0011, accuracy=1.0, val_error=0.206, val_accuracy=0.9414
# 18/20, error=0.001, accuracy=1.0, val_error=0.2069, val_accuracy=0.9414
# 19/20, error=0.001, accuracy=1.0, val_error=0.2077, val_accuracy=0.9414
# 20/20, error=0.0009, accuracy=1.0, val_error=0.2084, val_accuracy=0.9414
# Layers : 2
# 1/20, error=0.2356, accuracy=0.9482, val_error=0.2317, val_accuracy=0.9419
# 2/20, error=0.0404, accuracy=0.9895, val_error=0.2248, val_accuracy=0.9441
# 3/20, error=0.0215, accuracy=0.9956, val_error=0.2473, val_accuracy=0.9452
# 4/20, error=0.0144, accuracy=0.9978, val_error=0.2703, val_accuracy=0.9358
# 5/20, error=0.011, accuracy=0.9989, val_error=0.2829, val_accuracy=0.9325
# 6/20, error=0.0087, accuracy=0.9989, val_error=0.2952, val_accuracy=0.9331
# 7/20, error=0.0068, accuracy=0.9989, val_error=0.3026, val_accuracy=0.9331
# 8/20, error=0.0054, accuracy=0.9994, val_error=0.3071, val_accuracy=0.9331
# 9/20, error=0.0042, accuracy=0.9994, val_error=0.3103, val_accuracy=0.9281
# 10/20, error=0.0031, accuracy=0.9994, val_error=0.3118, val_accuracy=0.9281
# 11/20, error=0.0024, accuracy=1.0, val_error=0.3117, val_accuracy=0.9281
# 12/20, error=0.002, accuracy=1.0, val_error=0.3113, val_accuracy=0.9281
# 13/20, error=0.0018, accuracy=1.0, val_error=0.3111, val_accuracy=0.9281
# 14/20, error=0.0016, accuracy=1.0, val_error=0.3111, val_accuracy=0.9281
# 15/20, error=0.0015, accuracy=1.0, val_error=0.3113, val_accuracy=0.932
# 16/20, error=0.0013, accuracy=1.0, val_error=0.3116, val_accuracy=0.9287
# 17/20, error=0.0012, accuracy=1.0, val_error=0.312, val_accuracy=0.9287
# 18/20, error=0.0012, accuracy=1.0, val_error=0.3124, val_accuracy=0.9287
# 19/20, error=0.0011, accuracy=1.0, val_error=0.3129, val_accuracy=0.9287
# 20/20, error=0.001, accuracy=1.0, val_error=0.3134, val_accuracy=0.9287
# Test Accuracy =  0.9772857142857143
# Test Loss =  0.01991730939561546
# Balanced dataset shape: (1794, 784), (1794,)
# Balanced dataset shape: (1808, 784), (1808,)
# Layers : 1
# 1/20, error=0.1337, accuracy=0.966, val_error=0.116, val_accuracy=0.9768
# 2/20, error=0.0266, accuracy=0.9928, val_error=0.0897, val_accuracy=0.9801
# 3/20, error=0.0177, accuracy=0.9972, val_error=0.0842, val_accuracy=0.9812
# 4/20, error=0.0135, accuracy=0.9972, val_error=0.0804, val_accuracy=0.9817
# 5/20, error=0.0105, accuracy=0.9978, val_error=0.0772, val_accuracy=0.9829
# 6/20, error=0.0081, accuracy=0.9989, val_error=0.0742, val_accuracy=0.9829
# 7/20, error=0.0061, accuracy=0.9989, val_error=0.0712, val_accuracy=0.9834
# 8/20, error=0.0047, accuracy=0.9994, val_error=0.0686, val_accuracy=0.9834
# 9/20, error=0.0038, accuracy=0.9994, val_error=0.0667, val_accuracy=0.984
# 10/20, error=0.0032, accuracy=1.0, val_error=0.0652, val_accuracy=0.984
# 11/20, error=0.0028, accuracy=1.0, val_error=0.0641, val_accuracy=0.984
# 12/20, error=0.0025, accuracy=1.0, val_error=0.0631, val_accuracy=0.984
# 13/20, error=0.0023, accuracy=1.0, val_error=0.0624, val_accuracy=0.984
# 14/20, error=0.0021, accuracy=1.0, val_error=0.0617, val_accuracy=0.984
# 15/20, error=0.0019, accuracy=1.0, val_error=0.0611, val_accuracy=0.984
# 16/20, error=0.0018, accuracy=1.0, val_error=0.0606, val_accuracy=0.984
# 17/20, error=0.0017, accuracy=1.0, val_error=0.0602, val_accuracy=0.984
# 18/20, error=0.0016, accuracy=1.0, val_error=0.0597, val_accuracy=0.984
# 19/20, error=0.0015, accuracy=1.0, val_error=0.0594, val_accuracy=0.984
# 20/20, error=0.0014, accuracy=1.0, val_error=0.059, val_accuracy=0.984
# 1/20, error=0.0966, accuracy=0.8852, val_error=0.0242, val_accuracy=0.9685
# 2/20, error=0.0142, accuracy=0.9838, val_error=0.0088, val_accuracy=0.9906
# 3/20, error=0.0066, accuracy=0.9939, val_error=0.0062, val_accuracy=0.9934
# 4/20, error=0.0053, accuracy=0.995, val_error=0.0052, val_accuracy=0.9956
# 5/20, error=0.0049, accuracy=0.9955, val_error=0.0047, val_accuracy=0.9956
# 6/20, error=0.0047, accuracy=0.9955, val_error=0.0044, val_accuracy=0.9956
# 7/20, error=0.0046, accuracy=0.9955, val_error=0.0041, val_accuracy=0.9961
# 8/20, error=0.0046, accuracy=0.9955, val_error=0.0039, val_accuracy=0.9961
# 9/20, error=0.0045, accuracy=0.9955, val_error=0.0037, val_accuracy=0.9961
# 10/20, error=0.0043, accuracy=0.9955, val_error=0.0034, val_accuracy=0.9961
# 11/20, error=0.0042, accuracy=0.9961, val_error=0.0033, val_accuracy=0.9961
# 12/20, error=0.0041, accuracy=0.9961, val_error=0.0032, val_accuracy=0.9961
# 13/20, error=0.0041, accuracy=0.9961, val_error=0.0031, val_accuracy=0.9961
# 14/20, error=0.004, accuracy=0.9961, val_error=0.0031, val_accuracy=0.9961
# 15/20, error=0.004, accuracy=0.9961, val_error=0.003, val_accuracy=0.9961
# 16/20, error=0.004, accuracy=0.9961, val_error=0.003, val_accuracy=0.9961
# 17/20, error=0.004, accuracy=0.9961, val_error=0.0029, val_accuracy=0.9967
# 18/20, error=0.004, accuracy=0.9961, val_error=0.0029, val_accuracy=0.9967
# 19/20, error=0.004, accuracy=0.9961, val_error=0.0028, val_accuracy=0.9967
# 20/20, error=0.004, accuracy=0.9961, val_error=0.0028, val_accuracy=0.9967
# Layers : 2
# 1/20, error=0.1277, accuracy=0.9615, val_error=0.0706, val_accuracy=0.9729
# 2/20, error=0.0397, accuracy=0.9911, val_error=0.0561, val_accuracy=0.974
# 3/20, error=0.0269, accuracy=0.9939, val_error=0.0492, val_accuracy=0.9784
# 4/20, error=0.0183, accuracy=0.9955, val_error=0.0483, val_accuracy=0.9795
# 5/20, error=0.0125, accuracy=0.9967, val_error=0.0486, val_accuracy=0.9801
# 6/20, error=0.0088, accuracy=0.9978, val_error=0.0491, val_accuracy=0.9806
# 7/20, error=0.0067, accuracy=0.9989, val_error=0.0493, val_accuracy=0.9806
# 8/20, error=0.0054, accuracy=0.9994, val_error=0.0491, val_accuracy=0.9812
# 9/20, error=0.0045, accuracy=0.9994, val_error=0.0484, val_accuracy=0.9812
# 10/20, error=0.0038, accuracy=0.9994, val_error=0.0473, val_accuracy=0.9812
# 11/20, error=0.0033, accuracy=0.9994, val_error=0.0459, val_accuracy=0.9812
# 12/20, error=0.0029, accuracy=0.9994, val_error=0.0446, val_accuracy=0.9812
# 13/20, error=0.0026, accuracy=1.0, val_error=0.0435, val_accuracy=0.9812
# 14/20, error=0.0023, accuracy=1.0, val_error=0.0426, val_accuracy=0.9812
# 15/20, error=0.0022, accuracy=1.0, val_error=0.0418, val_accuracy=0.9812
# 16/20, error=0.002, accuracy=1.0, val_error=0.0412, val_accuracy=0.9812
# 17/20, error=0.0019, accuracy=1.0, val_error=0.0406, val_accuracy=0.9812
# 18/20, error=0.0017, accuracy=1.0, val_error=0.0401, val_accuracy=0.9812
# 19/20, error=0.0016, accuracy=1.0, val_error=0.0396, val_accuracy=0.9812
# 20/20, error=0.0015, accuracy=1.0, val_error=0.0392, val_accuracy=0.9812
# Layers : 2
# 1/20, error=0.1258, accuracy=0.9643, val_error=0.0458, val_accuracy=0.9856
# 2/20, error=0.0412, accuracy=0.9872, val_error=0.0346, val_accuracy=0.9873
# 3/20, error=0.0254, accuracy=0.9944, val_error=0.0294, val_accuracy=0.9934
# 4/20, error=0.0186, accuracy=0.9961, val_error=0.0266, val_accuracy=0.9934
# 5/20, error=0.014, accuracy=0.9967, val_error=0.0253, val_accuracy=0.9939
# 6/20, error=0.0106, accuracy=0.9978, val_error=0.025, val_accuracy=0.9945
# 7/20, error=0.0082, accuracy=0.9989, val_error=0.025, val_accuracy=0.9945
# 8/20, error=0.0065, accuracy=0.9989, val_error=0.0249, val_accuracy=0.995
# 9/20, error=0.0053, accuracy=0.9989, val_error=0.0248, val_accuracy=0.995
# 10/20, error=0.0043, accuracy=0.9989, val_error=0.0244, val_accuracy=0.995
# 11/20, error=0.0037, accuracy=0.9994, val_error=0.024, val_accuracy=0.995
# 12/20, error=0.0032, accuracy=1.0, val_error=0.0237, val_accuracy=0.995
# 13/20, error=0.0028, accuracy=1.0, val_error=0.0234, val_accuracy=0.995
# 14/20, error=0.0026, accuracy=1.0, val_error=0.0232, val_accuracy=0.995
# 15/20, error=0.0023, accuracy=1.0, val_error=0.0231, val_accuracy=0.995
# 16/20, error=0.0021, accuracy=1.0, val_error=0.0229, val_accuracy=0.995
# 17/20, error=0.002, accuracy=1.0, val_error=0.0228, val_accuracy=0.9945
# 18/20, error=0.0019, accuracy=1.0, val_error=0.0227, val_accuracy=0.9945
# 19/20, error=0.0017, accuracy=1.0, val_error=0.0226, val_accuracy=0.9945
# 20/20, error=0.0016, accuracy=1.0, val_error=0.0226, val_accuracy=0.9945
# Test Accuracy =  0.9821428571428571
# Test Loss =  0.01521986850096131
# Balanced dataset shape: (1804, 784), (1804,)
# Balanced dataset shape: (1776, 784), (1776,)
# Layers : 1
# 1/20, error=0.3227, accuracy=0.913, val_error=0.454, val_accuracy=0.9088
# 2/20, error=0.0825, accuracy=0.9745, val_error=0.4931, val_accuracy=0.9116
# 3/20, error=0.0444, accuracy=0.9867, val_error=0.5757, val_accuracy=0.9054
# 4/20, error=0.0257, accuracy=0.9911, val_error=0.5498, val_accuracy=0.9065
# 5/20, error=0.0174, accuracy=0.9967, val_error=0.4923, val_accuracy=0.9133
# 6/20, error=0.013, accuracy=0.9972, val_error=0.4773, val_accuracy=0.9206
# 7/20, error=0.0102, accuracy=0.9989, val_error=0.4772, val_accuracy=0.9245
# 8/20, error=0.0083, accuracy=0.9994, val_error=0.4808, val_accuracy=0.9206
# 9/20, error=0.007, accuracy=0.9994, val_error=0.4851, val_accuracy=0.9223
# 10/20, error=0.0061, accuracy=1.0, val_error=0.4893, val_accuracy=0.9223
# 11/20, error=0.0054, accuracy=1.0, val_error=0.4932, val_accuracy=0.9223
# 12/20, error=0.0049, accuracy=1.0, val_error=0.497, val_accuracy=0.9223
# 13/20, error=0.0045, accuracy=1.0, val_error=0.5005, val_accuracy=0.9223
# 14/20, error=0.0041, accuracy=1.0, val_error=0.5039, val_accuracy=0.9229
# 15/20, error=0.0038, accuracy=1.0, val_error=0.5071, val_accuracy=0.9229
# 16/20, error=0.0036, accuracy=1.0, val_error=0.5102, val_accuracy=0.9229
# 17/20, error=0.0034, accuracy=1.0, val_error=0.5132, val_accuracy=0.9229
# 18/20, error=0.0032, accuracy=1.0, val_error=0.516, val_accuracy=0.9229
# 19/20, error=0.003, accuracy=1.0, val_error=0.5187, val_accuracy=0.9229
# 20/20, error=0.0029, accuracy=1.0, val_error=0.5213, val_accuracy=0.9229
# 1/20, error=0.224, accuracy=0.7528, val_error=0.1244, val_accuracy=0.8519
# 2/20, error=0.0536, accuracy=0.939, val_error=0.0959, val_accuracy=0.8925
# 3/20, error=0.0298, accuracy=0.9678, val_error=0.0992, val_accuracy=0.8834
# 4/20, error=0.024, accuracy=0.9762, val_error=0.0924, val_accuracy=0.8975
# 5/20, error=0.0221, accuracy=0.9778, val_error=0.0826, val_accuracy=0.9009
# 6/20, error=0.0198, accuracy=0.9789, val_error=0.0611, val_accuracy=0.924
# 7/20, error=0.0078, accuracy=0.9922, val_error=0.058, val_accuracy=0.9324
# 8/20, error=0.0051, accuracy=0.9956, val_error=0.0523, val_accuracy=0.9398
# 9/20, error=0.0049, accuracy=0.9956, val_error=0.0502, val_accuracy=0.9398
# 10/20, error=0.0048, accuracy=0.9956, val_error=0.0492, val_accuracy=0.9398
# 11/20, error=0.0047, accuracy=0.9956, val_error=0.0484, val_accuracy=0.9398
# 12/20, error=0.0046, accuracy=0.9956, val_error=0.0476, val_accuracy=0.9398
# 13/20, error=0.0046, accuracy=0.9956, val_error=0.0468, val_accuracy=0.9437
# 14/20, error=0.0045, accuracy=0.9956, val_error=0.0456, val_accuracy=0.9437
# 15/20, error=0.0043, accuracy=0.9956, val_error=0.0424, val_accuracy=0.9499
# 16/20, error=0.0021, accuracy=0.9983, val_error=0.0432, val_accuracy=0.9493
# 17/20, error=0.0014, accuracy=0.9989, val_error=0.0428, val_accuracy=0.9516
# 18/20, error=0.0013, accuracy=0.9989, val_error=0.0425, val_accuracy=0.9516
# 19/20, error=0.0013, accuracy=0.9989, val_error=0.0423, val_accuracy=0.9471
# 20/20, error=0.0013, accuracy=0.9989, val_error=0.0421, val_accuracy=0.9476
# Layers : 2
# 1/20, error=0.3281, accuracy=0.9108, val_error=0.472, val_accuracy=0.9122
# 2/20, error=0.0778, accuracy=0.9751, val_error=0.416, val_accuracy=0.924
# 3/20, error=0.0416, accuracy=0.9895, val_error=0.4235, val_accuracy=0.9274
# 4/20, error=0.0278, accuracy=0.9945, val_error=0.4338, val_accuracy=0.9285
# 5/20, error=0.0199, accuracy=0.9956, val_error=0.4432, val_accuracy=0.9296
# 6/20, error=0.0145, accuracy=0.9972, val_error=0.4539, val_accuracy=0.9291
# 7/20, error=0.0105, accuracy=0.9983, val_error=0.4615, val_accuracy=0.9291
# 8/20, error=0.0083, accuracy=0.9989, val_error=0.4679, val_accuracy=0.9291
# 9/20, error=0.007, accuracy=0.9994, val_error=0.4757, val_accuracy=0.9296
# 10/20, error=0.006, accuracy=1.0, val_error=0.483, val_accuracy=0.9302
# 11/20, error=0.0054, accuracy=1.0, val_error=0.4894, val_accuracy=0.9268
# 12/20, error=0.0048, accuracy=1.0, val_error=0.495, val_accuracy=0.9268
# 13/20, error=0.0044, accuracy=1.0, val_error=0.4999, val_accuracy=0.9262
# 14/20, error=0.0041, accuracy=1.0, val_error=0.5044, val_accuracy=0.9257
# 15/20, error=0.0038, accuracy=1.0, val_error=0.5085, val_accuracy=0.9257
# 16/20, error=0.0036, accuracy=1.0, val_error=0.5123, val_accuracy=0.9257
# 17/20, error=0.0033, accuracy=1.0, val_error=0.5159, val_accuracy=0.9257
# 18/20, error=0.0032, accuracy=1.0, val_error=0.5192, val_accuracy=0.9257
# 19/20, error=0.003, accuracy=1.0, val_error=0.5224, val_accuracy=0.9257
# 20/20, error=0.0028, accuracy=1.0, val_error=0.5255, val_accuracy=0.9257
# Layers : 2
# 1/20, error=0.419, accuracy=0.9008, val_error=0.3505, val_accuracy=0.9195
# 2/20, error=0.1077, accuracy=0.9667, val_error=0.4639, val_accuracy=0.9133
# 3/20, error=0.0589, accuracy=0.9812, val_error=0.4621, val_accuracy=0.915
# 4/20, error=0.0353, accuracy=0.9911, val_error=0.4283, val_accuracy=0.9127
# 5/20, error=0.0251, accuracy=0.9967, val_error=0.4306, val_accuracy=0.9144
# 6/20, error=0.0188, accuracy=0.9967, val_error=0.4424, val_accuracy=0.9161
# 7/20, error=0.014, accuracy=0.9972, val_error=0.4525, val_accuracy=0.9161
# 8/20, error=0.011, accuracy=0.9983, val_error=0.4597, val_accuracy=0.9161
# 9/20, error=0.0089, accuracy=0.9994, val_error=0.4685, val_accuracy=0.9167
# 10/20, error=0.0073, accuracy=0.9994, val_error=0.4766, val_accuracy=0.9167
# 11/20, error=0.0061, accuracy=1.0, val_error=0.4831, val_accuracy=0.9167
# 12/20, error=0.0054, accuracy=1.0, val_error=0.4884, val_accuracy=0.9167
# 13/20, error=0.0048, accuracy=1.0, val_error=0.493, val_accuracy=0.9167
# 14/20, error=0.0044, accuracy=1.0, val_error=0.4972, val_accuracy=0.9167
# 15/20, error=0.0041, accuracy=1.0, val_error=0.5009, val_accuracy=0.9167
# 16/20, error=0.0038, accuracy=1.0, val_error=0.5044, val_accuracy=0.9172
# 17/20, error=0.0035, accuracy=1.0, val_error=0.5078, val_accuracy=0.9172
# 18/20, error=0.0033, accuracy=1.0, val_error=0.5109, val_accuracy=0.9172
# 19/20, error=0.0031, accuracy=1.0, val_error=0.5139, val_accuracy=0.9172
# 20/20, error=0.003, accuracy=1.0, val_error=0.5168, val_accuracy=0.9172
# Test Accuracy =  0.9612142857142857
# Test Loss =  0.03446812901776288
# Balanced dataset shape: (1800, 784), (1800,)
# Balanced dataset shape: (1818, 784), (1818,)
# Layers : 1
# 1/20, error=0.6183, accuracy=0.8694, val_error=0.4856, val_accuracy=0.8905
# 2/20, error=0.2153, accuracy=0.94, val_error=0.4903, val_accuracy=0.9081
# 3/20, error=0.1268, accuracy=0.9644, val_error=0.5043, val_accuracy=0.901
# 4/20, error=0.096, accuracy=0.9756, val_error=0.5492, val_accuracy=0.8889
# 5/20, error=0.0757, accuracy=0.9806, val_error=0.5938, val_accuracy=0.8696
# 6/20, error=0.0607, accuracy=0.985, val_error=0.6236, val_accuracy=0.8663
# 7/20, error=0.0498, accuracy=0.9878, val_error=0.6435, val_accuracy=0.8608
# 8/20, error=0.0411, accuracy=0.9906, val_error=0.6614, val_accuracy=0.863
# 9/20, error=0.0345, accuracy=0.9933, val_error=0.6756, val_accuracy=0.8619
# 10/20, error=0.0295, accuracy=0.9944, val_error=0.6844, val_accuracy=0.8619
# 11/20, error=0.0255, accuracy=0.9944, val_error=0.691, val_accuracy=0.8619
# 12/20, error=0.0223, accuracy=0.995, val_error=0.6968, val_accuracy=0.8619
# 13/20, error=0.0197, accuracy=0.9967, val_error=0.7016, val_accuracy=0.8619
# 14/20, error=0.0175, accuracy=0.9978, val_error=0.7057, val_accuracy=0.8619
# 15/20, error=0.0157, accuracy=0.9978, val_error=0.709, val_accuracy=0.863
# 16/20, error=0.0141, accuracy=0.9978, val_error=0.7116, val_accuracy=0.863
# 17/20, error=0.0129, accuracy=0.9989, val_error=0.7138, val_accuracy=0.863
# 18/20, error=0.0118, accuracy=0.9994, val_error=0.7157, val_accuracy=0.863
# 19/20, error=0.0109, accuracy=0.9994, val_error=0.7175, val_accuracy=0.863
# 20/20, error=0.0101, accuracy=0.9994, val_error=0.7194, val_accuracy=0.863
# 1/20, error=0.1878, accuracy=0.79, val_error=0.1203, val_accuracy=0.8658
# 2/20, error=0.0884, accuracy=0.9044, val_error=0.0982, val_accuracy=0.8856
# 3/20, error=0.0603, accuracy=0.9361, val_error=0.0669, val_accuracy=0.9197
# 4/20, error=0.036, accuracy=0.9606, val_error=0.0447, val_accuracy=0.9406
# 5/20, error=0.0214, accuracy=0.9783, val_error=0.0484, val_accuracy=0.9373
# 6/20, error=0.0195, accuracy=0.9806, val_error=0.0511, val_accuracy=0.9406
# 7/20, error=0.0186, accuracy=0.9811, val_error=0.0519, val_accuracy=0.9411
# 8/20, error=0.0177, accuracy=0.9828, val_error=0.05, val_accuracy=0.9417
# 9/20, error=0.0173, accuracy=0.9828, val_error=0.0505, val_accuracy=0.9417
# 10/20, error=0.017, accuracy=0.9828, val_error=0.051, val_accuracy=0.9417
# 11/20, error=0.0168, accuracy=0.9833, val_error=0.0494, val_accuracy=0.9417
# 12/20, error=0.0167, accuracy=0.9833, val_error=0.0493, val_accuracy=0.9417
# 13/20, error=0.0166, accuracy=0.9833, val_error=0.0493, val_accuracy=0.9417
# 14/20, error=0.0164, accuracy=0.9839, val_error=0.0494, val_accuracy=0.9417
# 15/20, error=0.0163, accuracy=0.9839, val_error=0.0494, val_accuracy=0.9417
# 16/20, error=0.0162, accuracy=0.9839, val_error=0.0494, val_accuracy=0.9417
# 17/20, error=0.0161, accuracy=0.9839, val_error=0.0496, val_accuracy=0.9417
# 18/20, error=0.0161, accuracy=0.9839, val_error=0.05, val_accuracy=0.9417
# 19/20, error=0.016, accuracy=0.9839, val_error=0.0508, val_accuracy=0.9417
# 20/20, error=0.0158, accuracy=0.9839, val_error=0.051, val_accuracy=0.9417
# Layers : 2
# 1/20, error=0.5938, accuracy=0.875, val_error=0.5186, val_accuracy=0.8966
# 2/20, error=0.2163, accuracy=0.9428, val_error=0.4589, val_accuracy=0.8982
# 3/20, error=0.1366, accuracy=0.9617, val_error=0.4645, val_accuracy=0.9059
# 4/20, error=0.0983, accuracy=0.9761, val_error=0.4843, val_accuracy=0.8999
# 5/20, error=0.0803, accuracy=0.9833, val_error=0.5018, val_accuracy=0.8938
# 6/20, error=0.068, accuracy=0.9861, val_error=0.5253, val_accuracy=0.8944
# 7/20, error=0.0587, accuracy=0.99, val_error=0.5527, val_accuracy=0.8878
# 8/20, error=0.0511, accuracy=0.9906, val_error=0.5778, val_accuracy=0.8883
# 9/20, error=0.0441, accuracy=0.9911, val_error=0.5952, val_accuracy=0.8801
# 10/20, error=0.0383, accuracy=0.9922, val_error=0.6044, val_accuracy=0.8806
# 11/20, error=0.0339, accuracy=0.9928, val_error=0.6113, val_accuracy=0.8817
# 12/20, error=0.0303, accuracy=0.9939, val_error=0.6168, val_accuracy=0.8905
# 13/20, error=0.0272, accuracy=0.995, val_error=0.6219, val_accuracy=0.8911
# 14/20, error=0.0244, accuracy=0.995, val_error=0.6272, val_accuracy=0.8916
# 15/20, error=0.0218, accuracy=0.995, val_error=0.633, val_accuracy=0.8927
# 16/20, error=0.0194, accuracy=0.9967, val_error=0.6387, val_accuracy=0.8922
# 17/20, error=0.0173, accuracy=0.9972, val_error=0.644, val_accuracy=0.8927
# 18/20, error=0.0155, accuracy=0.9978, val_error=0.6492, val_accuracy=0.8938
# 19/20, error=0.014, accuracy=0.9978, val_error=0.6545, val_accuracy=0.8949
# 20/20, error=0.0126, accuracy=0.9983, val_error=0.6598, val_accuracy=0.8949
# Layers : 2
# 1/20, error=0.4112, accuracy=0.8894, val_error=0.5805, val_accuracy=0.8784
# 2/20, error=0.1864, accuracy=0.9472, val_error=0.6311, val_accuracy=0.8856
# 3/20, error=0.1213, accuracy=0.9711, val_error=0.667, val_accuracy=0.8916
# 4/20, error=0.0915, accuracy=0.9794, val_error=0.7219, val_accuracy=0.8894
# 5/20, error=0.0724, accuracy=0.9833, val_error=0.767, val_accuracy=0.885
# 6/20, error=0.06, accuracy=0.9872, val_error=0.7922, val_accuracy=0.8872
# 7/20, error=0.0511, accuracy=0.99, val_error=0.8051, val_accuracy=0.89
# 8/20, error=0.0439, accuracy=0.9906, val_error=0.8136, val_accuracy=0.8894
# 9/20, error=0.0379, accuracy=0.9917, val_error=0.8188, val_accuracy=0.8922
# 10/20, error=0.0334, accuracy=0.9939, val_error=0.8216, val_accuracy=0.8922
# 11/20, error=0.0296, accuracy=0.9956, val_error=0.8238, val_accuracy=0.8872
# 12/20, error=0.0264, accuracy=0.9956, val_error=0.8256, val_accuracy=0.8878
# 13/20, error=0.0236, accuracy=0.9956, val_error=0.8274, val_accuracy=0.8878
# 14/20, error=0.0211, accuracy=0.9961, val_error=0.829, val_accuracy=0.8878
# 15/20, error=0.0189, accuracy=0.9967, val_error=0.8301, val_accuracy=0.8823
# 16/20, error=0.0171, accuracy=0.9978, val_error=0.8307, val_accuracy=0.8801
# 17/20, error=0.0155, accuracy=0.9983, val_error=0.8314, val_accuracy=0.8801
# 18/20, error=0.0142, accuracy=0.9989, val_error=0.8327, val_accuracy=0.8801
# 19/20, error=0.013, accuracy=0.9989, val_error=0.8345, val_accuracy=0.8795
# 20/20, error=0.0119, accuracy=0.9989, val_error=0.8365, val_accuracy=0.879
# Test Accuracy =  0.9565714285714285
# Test Loss =  0.038641229667363705
# Balanced dataset shape: (1822, 784), (1822,)
# Balanced dataset shape: (1786, 784), (1786,)
# Layers : 1
# 1/20, error=0.4503, accuracy=0.8946, val_error=0.3611, val_accuracy=0.8936
# 2/20, error=0.0994, accuracy=0.9687, val_error=0.4853, val_accuracy=0.8931
# 3/20, error=0.0517, accuracy=0.9841, val_error=0.4876, val_accuracy=0.8919
# 4/20, error=0.0329, accuracy=0.9907, val_error=0.5124, val_accuracy=0.8964
# 5/20, error=0.0218, accuracy=0.994, val_error=0.5406, val_accuracy=0.8964
# 6/20, error=0.0152, accuracy=0.9978, val_error=0.5573, val_accuracy=0.8975
# 7/20, error=0.0113, accuracy=0.9989, val_error=0.5664, val_accuracy=0.8919
# 8/20, error=0.0086, accuracy=0.9989, val_error=0.5691, val_accuracy=0.8875
# 9/20, error=0.007, accuracy=1.0, val_error=0.5702, val_accuracy=0.888
# 10/20, error=0.0061, accuracy=1.0, val_error=0.5716, val_accuracy=0.8942
# 11/20, error=0.0054, accuracy=1.0, val_error=0.5731, val_accuracy=0.9003
# 12/20, error=0.0049, accuracy=1.0, val_error=0.5747, val_accuracy=0.9003
# 13/20, error=0.0045, accuracy=1.0, val_error=0.5763, val_accuracy=0.9003
# 14/20, error=0.0041, accuracy=1.0, val_error=0.5779, val_accuracy=0.9003
# 15/20, error=0.0039, accuracy=1.0, val_error=0.5795, val_accuracy=0.9003
# 16/20, error=0.0036, accuracy=1.0, val_error=0.5811, val_accuracy=0.8998
# 17/20, error=0.0034, accuracy=1.0, val_error=0.5827, val_accuracy=0.9003
# 18/20, error=0.0032, accuracy=1.0, val_error=0.5843, val_accuracy=0.9003
# 19/20, error=0.0031, accuracy=1.0, val_error=0.5859, val_accuracy=0.9003
# 20/20, error=0.0029, accuracy=1.0, val_error=0.5874, val_accuracy=0.9003
# 1/20, error=0.1544, accuracy=0.8293, val_error=0.0887, val_accuracy=0.8998
# 2/20, error=0.0595, accuracy=0.9286, val_error=0.057, val_accuracy=0.9384
# 3/20, error=0.0218, accuracy=0.9726, val_error=0.0481, val_accuracy=0.9479
# 4/20, error=0.0125, accuracy=0.9868, val_error=0.043, val_accuracy=0.9541
# 5/20, error=0.0085, accuracy=0.9918, val_error=0.0412, val_accuracy=0.9552
# 6/20, error=0.0074, accuracy=0.9923, val_error=0.0397, val_accuracy=0.9563
# 7/20, error=0.0068, accuracy=0.9934, val_error=0.0382, val_accuracy=0.9563
# 8/20, error=0.0064, accuracy=0.9934, val_error=0.0369, val_accuracy=0.9574
# 9/20, error=0.006, accuracy=0.994, val_error=0.036, val_accuracy=0.9586
# 10/20, error=0.0057, accuracy=0.994, val_error=0.0358, val_accuracy=0.9574
# 11/20, error=0.0051, accuracy=0.9945, val_error=0.0359, val_accuracy=0.9574
# 12/20, error=0.0047, accuracy=0.9956, val_error=0.0348, val_accuracy=0.9574
# 13/20, error=0.0045, accuracy=0.9956, val_error=0.0331, val_accuracy=0.9597
# 14/20, error=0.0043, accuracy=0.9956, val_error=0.0273, val_accuracy=0.9658
# 15/20, error=0.0024, accuracy=0.9967, val_error=0.0247, val_accuracy=0.9709
# 16/20, error=0.0011, accuracy=0.9989, val_error=0.0245, val_accuracy=0.9703
# 17/20, error=0.0009, accuracy=0.9995, val_error=0.0243, val_accuracy=0.9703
# 18/20, error=0.0008, accuracy=0.9995, val_error=0.0241, val_accuracy=0.9703
# 19/20, error=0.0007, accuracy=0.9995, val_error=0.0239, val_accuracy=0.9709
# 20/20, error=0.0007, accuracy=0.9995, val_error=0.0237, val_accuracy=0.9709
# Layers : 2
# 1/20, error=0.3726, accuracy=0.9078, val_error=0.4482, val_accuracy=0.8931
# 2/20, error=0.0901, accuracy=0.9704, val_error=0.4806, val_accuracy=0.8992
# 3/20, error=0.0466, accuracy=0.9841, val_error=0.5018, val_accuracy=0.9071
# 4/20, error=0.029, accuracy=0.9907, val_error=0.5268, val_accuracy=0.9087
# 5/20, error=0.0201, accuracy=0.9962, val_error=0.5464, val_accuracy=0.902
# 6/20, error=0.0151, accuracy=0.9984, val_error=0.5627, val_accuracy=0.9026
# 7/20, error=0.0121, accuracy=0.9995, val_error=0.5781, val_accuracy=0.9031
# 8/20, error=0.0098, accuracy=0.9995, val_error=0.5913, val_accuracy=0.8981
# 9/20, error=0.0078, accuracy=0.9995, val_error=0.5988, val_accuracy=0.8992
# 10/20, error=0.0062, accuracy=1.0, val_error=0.6011, val_accuracy=0.8992
# 11/20, error=0.0054, accuracy=1.0, val_error=0.6039, val_accuracy=0.8992
# 12/20, error=0.0048, accuracy=1.0, val_error=0.607, val_accuracy=0.8992
# 13/20, error=0.0044, accuracy=1.0, val_error=0.6102, val_accuracy=0.8992
# 14/20, error=0.004, accuracy=1.0, val_error=0.6135, val_accuracy=0.8992
# 15/20, error=0.0037, accuracy=1.0, val_error=0.6167, val_accuracy=0.8992
# 16/20, error=0.0035, accuracy=1.0, val_error=0.6199, val_accuracy=0.8992
# 17/20, error=0.0033, accuracy=1.0, val_error=0.6229, val_accuracy=0.8998
# 18/20, error=0.0031, accuracy=1.0, val_error=0.6259, val_accuracy=0.9076
# 19/20, error=0.0029, accuracy=1.0, val_error=0.6287, val_accuracy=0.9076
# 20/20, error=0.0028, accuracy=1.0, val_error=0.6315, val_accuracy=0.9076
# Layers : 2
# 1/20, error=0.3718, accuracy=0.9122, val_error=0.4158, val_accuracy=0.8992
# 2/20, error=0.0799, accuracy=0.9769, val_error=0.4346, val_accuracy=0.9233
# 3/20, error=0.048, accuracy=0.9863, val_error=0.4459, val_accuracy=0.9227
# 4/20, error=0.0332, accuracy=0.9929, val_error=0.4664, val_accuracy=0.9149
# 5/20, error=0.0248, accuracy=0.9951, val_error=0.4916, val_accuracy=0.9166
# 6/20, error=0.0191, accuracy=0.9956, val_error=0.5156, val_accuracy=0.9171
# 7/20, error=0.0149, accuracy=0.9978, val_error=0.5338, val_accuracy=0.9071
# 8/20, error=0.0122, accuracy=0.9978, val_error=0.5485, val_accuracy=0.9065
# 9/20, error=0.01, accuracy=0.9995, val_error=0.5604, val_accuracy=0.9059
# 10/20, error=0.0079, accuracy=0.9995, val_error=0.5657, val_accuracy=0.9065
# 11/20, error=0.0062, accuracy=1.0, val_error=0.5662, val_accuracy=0.9071
# 12/20, error=0.0054, accuracy=1.0, val_error=0.5675, val_accuracy=0.9099
# 13/20, error=0.0048, accuracy=1.0, val_error=0.5694, val_accuracy=0.9099
# 14/20, error=0.0044, accuracy=1.0, val_error=0.5715, val_accuracy=0.9104
# 15/20, error=0.004, accuracy=1.0, val_error=0.5738, val_accuracy=0.9104
# 16/20, error=0.0038, accuracy=1.0, val_error=0.5761, val_accuracy=0.9104
# 17/20, error=0.0035, accuracy=1.0, val_error=0.5784, val_accuracy=0.9104
# 18/20, error=0.0033, accuracy=1.0, val_error=0.5806, val_accuracy=0.9104
# 19/20, error=0.0031, accuracy=1.0, val_error=0.5827, val_accuracy=0.9104
# 20/20, error=0.0029, accuracy=1.0, val_error=0.5848, val_accuracy=0.9099
# Test Accuracy =  0.9600714285714286
# Test Loss =  0.035264572565191936
# Balanced dataset shape: (1834, 784), (1834,)
# Balanced dataset shape: (1820, 784), (1820,)
# Layers : 1
# 1/20, error=0.5728, accuracy=0.861, val_error=0.8415, val_accuracy=0.8038
# 2/20, error=0.1501, accuracy=0.9504, val_error=0.8455, val_accuracy=0.7984
# 3/20, error=0.08, accuracy=0.9755, val_error=0.8575, val_accuracy=0.8126
# 4/20, error=0.0514, accuracy=0.9864, val_error=0.8571, val_accuracy=0.8011
# 5/20, error=0.0341, accuracy=0.994, val_error=0.8647, val_accuracy=0.8022
# 6/20, error=0.0251, accuracy=0.9962, val_error=0.867, val_accuracy=0.8033
# 7/20, error=0.0197, accuracy=0.9967, val_error=0.8704, val_accuracy=0.8088
# 8/20, error=0.016, accuracy=0.9978, val_error=0.8755, val_accuracy=0.8093
# 9/20, error=0.0135, accuracy=0.9989, val_error=0.8798, val_accuracy=0.8093
# 10/20, error=0.0117, accuracy=0.9995, val_error=0.883, val_accuracy=0.8093
# 11/20, error=0.0103, accuracy=0.9995, val_error=0.8855, val_accuracy=0.8093
# 12/20, error=0.0093, accuracy=0.9995, val_error=0.8878, val_accuracy=0.8093
# 13/20, error=0.0085, accuracy=1.0, val_error=0.8901, val_accuracy=0.8099
# 14/20, error=0.0078, accuracy=1.0, val_error=0.8924, val_accuracy=0.8099
# 15/20, error=0.0073, accuracy=1.0, val_error=0.8948, val_accuracy=0.8099
# 16/20, error=0.0068, accuracy=1.0, val_error=0.8972, val_accuracy=0.8099
# 17/20, error=0.0064, accuracy=1.0, val_error=0.8996, val_accuracy=0.8099
# 18/20, error=0.006, accuracy=1.0, val_error=0.9021, val_accuracy=0.8099
# 19/20, error=0.0057, accuracy=1.0, val_error=0.9045, val_accuracy=0.8099
# 20/20, error=0.0054, accuracy=1.0, val_error=0.907, val_accuracy=0.8099
# 1/20, error=0.2009, accuracy=0.777, val_error=0.072, val_accuracy=0.9104
# 2/20, error=0.052, accuracy=0.9395, val_error=0.0286, val_accuracy=0.9599
# 3/20, error=0.0223, accuracy=0.976, val_error=0.016, val_accuracy=0.983
# 4/20, error=0.0088, accuracy=0.9896, val_error=0.0178, val_accuracy=0.9753
# 5/20, error=0.004, accuracy=0.9956, val_error=0.0179, val_accuracy=0.9758
# 6/20, error=0.0022, accuracy=0.9978, val_error=0.0171, val_accuracy=0.9758
# 7/20, error=0.0016, accuracy=0.9989, val_error=0.0147, val_accuracy=0.9758
# 8/20, error=0.0014, accuracy=0.9989, val_error=0.0137, val_accuracy=0.9791
# 9/20, error=0.0013, accuracy=0.9989, val_error=0.0133, val_accuracy=0.9791
# 10/20, error=0.0013, accuracy=0.9989, val_error=0.0129, val_accuracy=0.9863
# 11/20, error=0.0012, accuracy=0.9989, val_error=0.0126, val_accuracy=0.9863
# 12/20, error=0.0011, accuracy=0.9989, val_error=0.0124, val_accuracy=0.9863
# 13/20, error=0.001, accuracy=0.9989, val_error=0.0123, val_accuracy=0.9863
# 14/20, error=0.0008, accuracy=0.9995, val_error=0.0122, val_accuracy=0.9863
# 15/20, error=0.0008, accuracy=0.9995, val_error=0.012, val_accuracy=0.9863
# 16/20, error=0.0007, accuracy=0.9995, val_error=0.0119, val_accuracy=0.9863
# 17/20, error=0.0007, accuracy=0.9995, val_error=0.0117, val_accuracy=0.9863
# 18/20, error=0.0007, accuracy=0.9995, val_error=0.0116, val_accuracy=0.9863
# 19/20, error=0.0007, accuracy=0.9995, val_error=0.0115, val_accuracy=0.9863
# 20/20, error=0.0007, accuracy=0.9995, val_error=0.0114, val_accuracy=0.9863
# Layers : 2
# 1/20, error=0.6281, accuracy=0.843, val_error=0.4586, val_accuracy=0.8533
# 2/20, error=0.1354, accuracy=0.952, val_error=0.5003, val_accuracy=0.8396
# 3/20, error=0.0737, accuracy=0.9776, val_error=0.5595, val_accuracy=0.8396
# 4/20, error=0.0481, accuracy=0.9918, val_error=0.5853, val_accuracy=0.8313
# 5/20, error=0.0359, accuracy=0.994, val_error=0.6028, val_accuracy=0.8319
# 6/20, error=0.0285, accuracy=0.9951, val_error=0.6223, val_accuracy=0.8308
# 7/20, error=0.0232, accuracy=0.9967, val_error=0.6404, val_accuracy=0.8148
# 8/20, error=0.0189, accuracy=0.9967, val_error=0.6554, val_accuracy=0.822
# 9/20, error=0.0155, accuracy=0.9978, val_error=0.6661, val_accuracy=0.8242
# 10/20, error=0.013, accuracy=0.9989, val_error=0.6737, val_accuracy=0.8242
# 11/20, error=0.0114, accuracy=0.9995, val_error=0.6799, val_accuracy=0.8203
# 12/20, error=0.0102, accuracy=1.0, val_error=0.6856, val_accuracy=0.8203
# 13/20, error=0.0093, accuracy=1.0, val_error=0.6909, val_accuracy=0.8203
# 14/20, error=0.0085, accuracy=1.0, val_error=0.696, val_accuracy=0.8203
# 15/20, error=0.0079, accuracy=1.0, val_error=0.7008, val_accuracy=0.8198
# 16/20, error=0.0074, accuracy=1.0, val_error=0.7053, val_accuracy=0.8198
# 17/20, error=0.0069, accuracy=1.0, val_error=0.7096, val_accuracy=0.8203
# 18/20, error=0.0065, accuracy=1.0, val_error=0.7137, val_accuracy=0.8203
# 19/20, error=0.0062, accuracy=1.0, val_error=0.7176, val_accuracy=0.8203
# 20/20, error=0.0059, accuracy=1.0, val_error=0.7213, val_accuracy=0.8198
# Layers : 2
# 1/20, error=0.456, accuracy=0.8746, val_error=0.5018, val_accuracy=0.8429
# 2/20, error=0.137, accuracy=0.9477, val_error=0.5312, val_accuracy=0.8544
# 3/20, error=0.0776, accuracy=0.9755, val_error=0.5883, val_accuracy=0.856
# 4/20, error=0.0492, accuracy=0.988, val_error=0.6219, val_accuracy=0.8604
# 5/20, error=0.0364, accuracy=0.9918, val_error=0.6409, val_accuracy=0.85
# 6/20, error=0.0285, accuracy=0.9945, val_error=0.654, val_accuracy=0.8418
# 7/20, error=0.0233, accuracy=0.9967, val_error=0.6637, val_accuracy=0.8511
# 8/20, error=0.0195, accuracy=0.9978, val_error=0.6714, val_accuracy=0.839
# 9/20, error=0.0166, accuracy=0.9989, val_error=0.6785, val_accuracy=0.8374
# 10/20, error=0.0145, accuracy=0.9995, val_error=0.6853, val_accuracy=0.8385
# 11/20, error=0.0128, accuracy=0.9995, val_error=0.6914, val_accuracy=0.839
# 12/20, error=0.0113, accuracy=0.9995, val_error=0.6965, val_accuracy=0.839
# 13/20, error=0.0101, accuracy=0.9995, val_error=0.7006, val_accuracy=0.839
# 14/20, error=0.0092, accuracy=0.9995, val_error=0.7042, val_accuracy=0.8396
# 15/20, error=0.0084, accuracy=1.0, val_error=0.7075, val_accuracy=0.839
# 16/20, error=0.0078, accuracy=1.0, val_error=0.7106, val_accuracy=0.839
# 17/20, error=0.0072, accuracy=1.0, val_error=0.7135, val_accuracy=0.839
# 18/20, error=0.0068, accuracy=1.0, val_error=0.7164, val_accuracy=0.839
# 19/20, error=0.0064, accuracy=1.0, val_error=0.7192, val_accuracy=0.8478
# 20/20, error=0.006, accuracy=1.0, val_error=0.7219, val_accuracy=0.8549
# Test Accuracy =  0.9449285714285715
# Test Loss =  0.04900194612509656
# Balanced dataset shape: (1770, 784), (1770,)
# Balanced dataset shape: (1806, 784), (1806,)
# Layers : 1
# 1/20, error=0.3924, accuracy=0.9113, val_error=0.247, val_accuracy=0.9319
# 2/20, error=0.1175, accuracy=0.9695, val_error=0.2004, val_accuracy=0.9557
# 3/20, error=0.0748, accuracy=0.9819, val_error=0.1928, val_accuracy=0.9518
# 4/20, error=0.0551, accuracy=0.987, val_error=0.1826, val_accuracy=0.9551
# 5/20, error=0.0411, accuracy=0.9904, val_error=0.1748, val_accuracy=0.954
# 6/20, error=0.0307, accuracy=0.9927, val_error=0.1721, val_accuracy=0.9457
# 7/20, error=0.0231, accuracy=0.9938, val_error=0.174, val_accuracy=0.9457
# 8/20, error=0.0166, accuracy=0.9938, val_error=0.1773, val_accuracy=0.9468
# 9/20, error=0.0126, accuracy=0.9983, val_error=0.1774, val_accuracy=0.9474
# 10/20, error=0.0098, accuracy=0.9989, val_error=0.1774, val_accuracy=0.9474
# 11/20, error=0.008, accuracy=1.0, val_error=0.1776, val_accuracy=0.948
# 12/20, error=0.0068, accuracy=1.0, val_error=0.178, val_accuracy=0.948
# 13/20, error=0.0059, accuracy=1.0, val_error=0.1785, val_accuracy=0.948
# 14/20, error=0.0053, accuracy=1.0, val_error=0.179, val_accuracy=0.948
# 15/20, error=0.0049, accuracy=1.0, val_error=0.1796, val_accuracy=0.948
# 16/20, error=0.0045, accuracy=1.0, val_error=0.1802, val_accuracy=0.948
# 17/20, error=0.0042, accuracy=1.0, val_error=0.1807, val_accuracy=0.948
# 18/20, error=0.0039, accuracy=1.0, val_error=0.1813, val_accuracy=0.948
# 19/20, error=0.0037, accuracy=1.0, val_error=0.1819, val_accuracy=0.9485
# 20/20, error=0.0035, accuracy=1.0, val_error=0.1824, val_accuracy=0.9485
# 1/20, error=0.1422, accuracy=0.8339, val_error=0.0531, val_accuracy=0.9402
# 2/20, error=0.0366, accuracy=0.9593, val_error=0.0465, val_accuracy=0.9369
# 3/20, error=0.0276, accuracy=0.9706, val_error=0.0289, val_accuracy=0.9563
# 4/20, error=0.0173, accuracy=0.9819, val_error=0.0264, val_accuracy=0.9657
# 5/20, error=0.0144, accuracy=0.9853, val_error=0.0267, val_accuracy=0.9651
# 6/20, error=0.0134, accuracy=0.9864, val_error=0.0272, val_accuracy=0.9574
# 7/20, error=0.0125, accuracy=0.9876, val_error=0.0273, val_accuracy=0.9585
# 8/20, error=0.0118, accuracy=0.9881, val_error=0.0264, val_accuracy=0.959
# 9/20, error=0.0114, accuracy=0.9887, val_error=0.0259, val_accuracy=0.959
# 10/20, error=0.011, accuracy=0.9887, val_error=0.0254, val_accuracy=0.9596
# 11/20, error=0.0106, accuracy=0.9887, val_error=0.0249, val_accuracy=0.9607
# 12/20, error=0.01, accuracy=0.9904, val_error=0.0252, val_accuracy=0.9607
# 13/20, error=0.0096, accuracy=0.9904, val_error=0.0257, val_accuracy=0.9535
# 14/20, error=0.0094, accuracy=0.991, val_error=0.0265, val_accuracy=0.954
# 15/20, error=0.0093, accuracy=0.991, val_error=0.0276, val_accuracy=0.9496
# 16/20, error=0.0092, accuracy=0.991, val_error=0.0293, val_accuracy=0.9496
# 17/20, error=0.0091, accuracy=0.991, val_error=0.0291, val_accuracy=0.9502
# 18/20, error=0.0089, accuracy=0.9904, val_error=0.021, val_accuracy=0.9701
# 19/20, error=0.0083, accuracy=0.9921, val_error=0.0277, val_accuracy=0.9607
# 20/20, error=0.0081, accuracy=0.9921, val_error=0.0264, val_accuracy=0.9651
# Layers : 2
# 1/20, error=0.3317, accuracy=0.9277, val_error=0.2652, val_accuracy=0.9286
# 2/20, error=0.1187, accuracy=0.9689, val_error=0.3195, val_accuracy=0.9286
# 3/20, error=0.0658, accuracy=0.9825, val_error=0.286, val_accuracy=0.9275
# 4/20, error=0.0474, accuracy=0.9904, val_error=0.2809, val_accuracy=0.9291
# 5/20, error=0.0356, accuracy=0.991, val_error=0.2642, val_accuracy=0.9302
# 6/20, error=0.0277, accuracy=0.9932, val_error=0.2521, val_accuracy=0.9363
# 7/20, error=0.0221, accuracy=0.9955, val_error=0.248, val_accuracy=0.9374
# 8/20, error=0.0178, accuracy=0.9966, val_error=0.2469, val_accuracy=0.938
# 9/20, error=0.0142, accuracy=0.9972, val_error=0.2456, val_accuracy=0.938
# 10/20, error=0.0114, accuracy=0.9972, val_error=0.243, val_accuracy=0.938
# 11/20, error=0.0092, accuracy=0.9983, val_error=0.2401, val_accuracy=0.938
# 12/20, error=0.0077, accuracy=0.9994, val_error=0.2388, val_accuracy=0.938
# 13/20, error=0.0067, accuracy=0.9994, val_error=0.2387, val_accuracy=0.938
# 14/20, error=0.006, accuracy=1.0, val_error=0.2393, val_accuracy=0.938
# 15/20, error=0.0054, accuracy=1.0, val_error=0.24, val_accuracy=0.9336
# 16/20, error=0.0049, accuracy=1.0, val_error=0.2408, val_accuracy=0.9336
# 17/20, error=0.0045, accuracy=1.0, val_error=0.2416, val_accuracy=0.9336
# 18/20, error=0.0042, accuracy=1.0, val_error=0.2424, val_accuracy=0.9341
# 19/20, error=0.004, accuracy=1.0, val_error=0.2432, val_accuracy=0.9313
# 20/20, error=0.0037, accuracy=1.0, val_error=0.2439, val_accuracy=0.9313
# Layers : 2
# 1/20, error=0.3517, accuracy=0.9282, val_error=0.2216, val_accuracy=0.9324
# 2/20, error=0.1438, accuracy=0.9655, val_error=0.2029, val_accuracy=0.933
# 3/20, error=0.0893, accuracy=0.9763, val_error=0.2258, val_accuracy=0.9291
# 4/20, error=0.0627, accuracy=0.9842, val_error=0.2448, val_accuracy=0.9252
# 5/20, error=0.0461, accuracy=0.9881, val_error=0.2585, val_accuracy=0.9197
# 6/20, error=0.0343, accuracy=0.9915, val_error=0.2577, val_accuracy=0.9175
# 7/20, error=0.0253, accuracy=0.9944, val_error=0.2455, val_accuracy=0.9169
# 8/20, error=0.02, accuracy=0.9972, val_error=0.2436, val_accuracy=0.9175
# 9/20, error=0.0166, accuracy=0.9989, val_error=0.2417, val_accuracy=0.9308
# 10/20, error=0.0141, accuracy=0.9989, val_error=0.2398, val_accuracy=0.9313
# 11/20, error=0.0123, accuracy=0.9989, val_error=0.2386, val_accuracy=0.9308
# 12/20, error=0.0108, accuracy=0.9989, val_error=0.2383, val_accuracy=0.9308
# 13/20, error=0.0096, accuracy=0.9994, val_error=0.2391, val_accuracy=0.9319
# 14/20, error=0.0087, accuracy=0.9994, val_error=0.2407, val_accuracy=0.9313
# 15/20, error=0.0078, accuracy=0.9994, val_error=0.2428, val_accuracy=0.9308
# 16/20, error=0.0071, accuracy=0.9994, val_error=0.2454, val_accuracy=0.9308
# 17/20, error=0.0063, accuracy=0.9994, val_error=0.2481, val_accuracy=0.9275
# 18/20, error=0.0057, accuracy=0.9994, val_error=0.2509, val_accuracy=0.9275
# 19/20, error=0.0051, accuracy=0.9994, val_error=0.2535, val_accuracy=0.9275
# 20/20, error=0.0047, accuracy=0.9994, val_error=0.2558, val_accuracy=0.9275
# Test Accuracy =  0.9727142857142858
# Test Loss =  0.024454290909709547
# Balanced dataset shape: (1766, 784), (1766,)
# Balanced dataset shape: (1734, 784), (1734,)
# Layers : 1
# 1/20, error=0.3117, accuracy=0.9083, val_error=0.3617, val_accuracy=0.9354
# 2/20, error=0.0801, accuracy=0.9717, val_error=0.4924, val_accuracy=0.9112
# 3/20, error=0.0525, accuracy=0.9841, val_error=0.5166, val_accuracy=0.9164
# 4/20, error=0.0399, accuracy=0.9881, val_error=0.5048, val_accuracy=0.9187
# 5/20, error=0.0316, accuracy=0.9932, val_error=0.4849, val_accuracy=0.9256
# 6/20, error=0.0254, accuracy=0.9943, val_error=0.4657, val_accuracy=0.9256
# 7/20, error=0.0205, accuracy=0.996, val_error=0.4515, val_accuracy=0.9279
# 8/20, error=0.0166, accuracy=0.9966, val_error=0.4371, val_accuracy=0.9302
# 9/20, error=0.0139, accuracy=0.9977, val_error=0.4234, val_accuracy=0.9291
# 10/20, error=0.0119, accuracy=0.9989, val_error=0.4138, val_accuracy=0.9354
# 11/20, error=0.0103, accuracy=0.9989, val_error=0.4072, val_accuracy=0.9354
# 12/20, error=0.0089, accuracy=0.9989, val_error=0.4024, val_accuracy=0.9354
# 13/20, error=0.0079, accuracy=0.9989, val_error=0.3988, val_accuracy=0.94
# 14/20, error=0.0071, accuracy=0.9994, val_error=0.3963, val_accuracy=0.94
# 15/20, error=0.0064, accuracy=0.9994, val_error=0.3947, val_accuracy=0.94
# 16/20, error=0.0059, accuracy=0.9994, val_error=0.3938, val_accuracy=0.9394
# 17/20, error=0.0055, accuracy=1.0, val_error=0.3933, val_accuracy=0.9394
# 18/20, error=0.0051, accuracy=1.0, val_error=0.3931, val_accuracy=0.9389
# 19/20, error=0.0048, accuracy=1.0, val_error=0.3932, val_accuracy=0.9389
# 20/20, error=0.0045, accuracy=1.0, val_error=0.3934, val_accuracy=0.9389
# 1/20, error=0.14, accuracy=0.8375, val_error=0.0685, val_accuracy=0.9239
# 2/20, error=0.0432, accuracy=0.949, val_error=0.044, val_accuracy=0.9498
# 3/20, error=0.0137, accuracy=0.9853, val_error=0.028, val_accuracy=0.9642
# 4/20, error=0.006, accuracy=0.9938, val_error=0.0259, val_accuracy=0.9717
# 5/20, error=0.004, accuracy=0.996, val_error=0.0238, val_accuracy=0.9723
# 6/20, error=0.0026, accuracy=0.9977, val_error=0.0208, val_accuracy=0.9764
# 7/20, error=0.0016, accuracy=0.9983, val_error=0.0194, val_accuracy=0.9769
# 8/20, error=0.0011, accuracy=0.9994, val_error=0.0188, val_accuracy=0.9769
# 9/20, error=0.0009, accuracy=0.9994, val_error=0.0184, val_accuracy=0.9769
# 10/20, error=0.0008, accuracy=0.9994, val_error=0.0181, val_accuracy=0.9769
# 11/20, error=0.0008, accuracy=0.9994, val_error=0.0179, val_accuracy=0.9775
# 12/20, error=0.0007, accuracy=0.9994, val_error=0.0176, val_accuracy=0.9775
# 13/20, error=0.0007, accuracy=0.9994, val_error=0.0174, val_accuracy=0.9781
# 14/20, error=0.0006, accuracy=0.9994, val_error=0.0172, val_accuracy=0.9781
# 15/20, error=0.0005, accuracy=0.9994, val_error=0.017, val_accuracy=0.9787
# 16/20, error=0.0003, accuracy=0.9994, val_error=0.0167, val_accuracy=0.9787
# 17/20, error=0.0002, accuracy=1.0, val_error=0.0165, val_accuracy=0.9839
# 18/20, error=0.0002, accuracy=1.0, val_error=0.0164, val_accuracy=0.9839
# 19/20, error=0.0002, accuracy=1.0, val_error=0.0162, val_accuracy=0.9839
# 20/20, error=0.0001, accuracy=1.0, val_error=0.0161, val_accuracy=0.9839
# Layers : 2
# 1/20, error=0.2996, accuracy=0.9219, val_error=0.408, val_accuracy=0.9204
# 2/20, error=0.0898, accuracy=0.9728, val_error=0.4958, val_accuracy=0.9037
# 3/20, error=0.0579, accuracy=0.9802, val_error=0.5295, val_accuracy=0.9048
# 4/20, error=0.0409, accuracy=0.9858, val_error=0.525, val_accuracy=0.9054
# 5/20, error=0.0308, accuracy=0.9892, val_error=0.5084, val_accuracy=0.9118
# 6/20, error=0.0238, accuracy=0.9921, val_error=0.4841, val_accuracy=0.9118
# 7/20, error=0.0189, accuracy=0.9949, val_error=0.4624, val_accuracy=0.9112
# 8/20, error=0.0153, accuracy=0.9966, val_error=0.4448, val_accuracy=0.9164
# 9/20, error=0.0127, accuracy=0.9966, val_error=0.4301, val_accuracy=0.9198
# 10/20, error=0.0107, accuracy=0.9989, val_error=0.4185, val_accuracy=0.9221
# 11/20, error=0.0093, accuracy=0.9994, val_error=0.4095, val_accuracy=0.925
# 12/20, error=0.0082, accuracy=0.9994, val_error=0.4024, val_accuracy=0.9273
# 13/20, error=0.0074, accuracy=1.0, val_error=0.3969, val_accuracy=0.9273
# 14/20, error=0.0067, accuracy=1.0, val_error=0.3924, val_accuracy=0.9273
# 15/20, error=0.0062, accuracy=1.0, val_error=0.3889, val_accuracy=0.9273
# 16/20, error=0.0057, accuracy=1.0, val_error=0.3862, val_accuracy=0.9273
# 17/20, error=0.0054, accuracy=1.0, val_error=0.3841, val_accuracy=0.9273
# 18/20, error=0.005, accuracy=1.0, val_error=0.3825, val_accuracy=0.9273
# 19/20, error=0.0047, accuracy=1.0, val_error=0.3812, val_accuracy=0.9273
# 20/20, error=0.0045, accuracy=1.0, val_error=0.3803, val_accuracy=0.9325
# Layers : 2
# 1/20, error=0.3369, accuracy=0.9111, val_error=0.2523, val_accuracy=0.9302
# 2/20, error=0.1045, accuracy=0.9643, val_error=0.2966, val_accuracy=0.9319
# 3/20, error=0.0636, accuracy=0.9819, val_error=0.3487, val_accuracy=0.9152
# 4/20, error=0.0424, accuracy=0.9853, val_error=0.3817, val_accuracy=0.91
# 5/20, error=0.0307, accuracy=0.9915, val_error=0.4013, val_accuracy=0.9106
# 6/20, error=0.0234, accuracy=0.9949, val_error=0.4114, val_accuracy=0.9106
# 7/20, error=0.0188, accuracy=0.9972, val_error=0.4145, val_accuracy=0.9112
# 8/20, error=0.0155, accuracy=0.9977, val_error=0.4121, val_accuracy=0.9106
# 9/20, error=0.0129, accuracy=0.9977, val_error=0.4071, val_accuracy=0.9227
# 10/20, error=0.0109, accuracy=0.9983, val_error=0.4018, val_accuracy=0.9273
# 11/20, error=0.0094, accuracy=0.9989, val_error=0.3971, val_accuracy=0.9296
# 12/20, error=0.0083, accuracy=1.0, val_error=0.3932, val_accuracy=0.9296
# 13/20, error=0.0074, accuracy=1.0, val_error=0.3904, val_accuracy=0.9343
# 14/20, error=0.0068, accuracy=1.0, val_error=0.3884, val_accuracy=0.9337
# 15/20, error=0.0062, accuracy=1.0, val_error=0.3871, val_accuracy=0.9337
# 16/20, error=0.0057, accuracy=1.0, val_error=0.3863, val_accuracy=0.936
# 17/20, error=0.0054, accuracy=1.0, val_error=0.3858, val_accuracy=0.936
# 18/20, error=0.005, accuracy=1.0, val_error=0.3856, val_accuracy=0.936
# 19/20, error=0.0047, accuracy=1.0, val_error=0.3856, val_accuracy=0.936
# 20/20, error=0.0045, accuracy=1.0, val_error=0.3858, val_accuracy=0.936
# Test Accuracy =  0.9708571428571429
# Test Loss =  0.026182758384144134
# Balanced dataset shape: (1786, 784), (1786,)
# Balanced dataset shape: (1826, 784), (1826,)
# Layers : 1
# 1/20, error=0.7683, accuracy=0.8242, val_error=0.8304, val_accuracy=0.8007
# 2/20, error=0.303, accuracy=0.911, val_error=0.7163, val_accuracy=0.8313
# 3/20, error=0.2011, accuracy=0.9429, val_error=0.7275, val_accuracy=0.8226
# 4/20, error=0.1524, accuracy=0.9563, val_error=0.7517, val_accuracy=0.8023
# 5/20, error=0.1218, accuracy=0.9642, val_error=0.8108, val_accuracy=0.8094
# 6/20, error=0.1, accuracy=0.9698, val_error=0.8277, val_accuracy=0.8154
# 7/20, error=0.0829, accuracy=0.9731, val_error=0.8476, val_accuracy=0.8176
# 8/20, error=0.069, accuracy=0.977, val_error=0.8799, val_accuracy=0.8209
# 9/20, error=0.0568, accuracy=0.9832, val_error=0.9071, val_accuracy=0.8248
# 10/20, error=0.0464, accuracy=0.9854, val_error=0.9312, val_accuracy=0.8226
# 11/20, error=0.0383, accuracy=0.9899, val_error=0.955, val_accuracy=0.8242
# 12/20, error=0.0323, accuracy=0.9922, val_error=0.9745, val_accuracy=0.8258
# 13/20, error=0.0278, accuracy=0.9933, val_error=0.9884, val_accuracy=0.8264
# 14/20, error=0.0243, accuracy=0.995, val_error=0.9992, val_accuracy=0.8269
# 15/20, error=0.0214, accuracy=0.9961, val_error=1.0087, val_accuracy=0.8269
# 16/20, error=0.0193, accuracy=0.9983, val_error=1.0185, val_accuracy=0.828
# 17/20, error=0.0176, accuracy=1.0, val_error=1.0288, val_accuracy=0.828
# 18/20, error=0.0162, accuracy=1.0, val_error=1.039, val_accuracy=0.828
# 19/20, error=0.015, accuracy=1.0, val_error=1.0489, val_accuracy=0.8297
# 20/20, error=0.014, accuracy=1.0, val_error=1.0584, val_accuracy=0.8291
# 1/20, error=0.3045, accuracy=0.6697, val_error=0.2302, val_accuracy=0.7596
# 2/20, error=0.1678, accuracy=0.8119, val_error=0.1172, val_accuracy=0.8625
# 3/20, error=0.0725, accuracy=0.9194, val_error=0.0861, val_accuracy=0.8981
# 4/20, error=0.0509, accuracy=0.9457, val_error=0.0729, val_accuracy=0.9189
# 5/20, error=0.0427, accuracy=0.9541, val_error=0.067, val_accuracy=0.9239
# 6/20, error=0.0366, accuracy=0.963, val_error=0.0669, val_accuracy=0.9255
# 7/20, error=0.0352, accuracy=0.9647, val_error=0.0644, val_accuracy=0.9255
# 8/20, error=0.0339, accuracy=0.9653, val_error=0.06, val_accuracy=0.9255
# 9/20, error=0.0329, accuracy=0.967, val_error=0.0546, val_accuracy=0.9326
# 10/20, error=0.0319, accuracy=0.967, val_error=0.0413, val_accuracy=0.9562
# 11/20, error=0.0255, accuracy=0.9726, val_error=0.0228, val_accuracy=0.971
# 12/20, error=0.0119, accuracy=0.9888, val_error=0.021, val_accuracy=0.9715
# 13/20, error=0.0109, accuracy=0.9894, val_error=0.02, val_accuracy=0.9732
# 14/20, error=0.0107, accuracy=0.9894, val_error=0.0191, val_accuracy=0.9748
# 15/20, error=0.0105, accuracy=0.9894, val_error=0.0181, val_accuracy=0.9819
# 16/20, error=0.0093, accuracy=0.9899, val_error=0.0153, val_accuracy=0.9803
# 17/20, error=0.0036, accuracy=0.9961, val_error=0.015, val_accuracy=0.9819
# 18/20, error=0.0006, accuracy=1.0, val_error=0.0148, val_accuracy=0.9819
# 19/20, error=0.0003, accuracy=1.0, val_error=0.0147, val_accuracy=0.983
# 20/20, error=0.0002, accuracy=1.0, val_error=0.0146, val_accuracy=0.983
# Layers : 2
# 1/20, error=0.7928, accuracy=0.8175, val_error=0.6783, val_accuracy=0.8133
# 2/20, error=0.2953, accuracy=0.9087, val_error=0.6637, val_accuracy=0.8193
# 3/20, error=0.1833, accuracy=0.9423, val_error=0.7519, val_accuracy=0.7985
# 4/20, error=0.136, accuracy=0.9552, val_error=0.7847, val_accuracy=0.8061
# 5/20, error=0.1048, accuracy=0.9664, val_error=0.803, val_accuracy=0.8067
# 6/20, error=0.0826, accuracy=0.9731, val_error=0.8205, val_accuracy=0.8023
# 7/20, error=0.0675, accuracy=0.9787, val_error=0.8425, val_accuracy=0.7968
# 8/20, error=0.0569, accuracy=0.9826, val_error=0.8668, val_accuracy=0.7913
# 9/20, error=0.0484, accuracy=0.9866, val_error=0.8872, val_accuracy=0.799
# 10/20, error=0.041, accuracy=0.991, val_error=0.9021, val_accuracy=0.8018
# 11/20, error=0.035, accuracy=0.9933, val_error=0.9164, val_accuracy=0.8083
# 12/20, error=0.0304, accuracy=0.9938, val_error=0.9315, val_accuracy=0.8056
# 13/20, error=0.0266, accuracy=0.9966, val_error=0.9443, val_accuracy=0.805
# 14/20, error=0.0234, accuracy=0.9972, val_error=0.9554, val_accuracy=0.8061
# 15/20, error=0.021, accuracy=0.9983, val_error=0.9663, val_accuracy=0.8039
# 16/20, error=0.019, accuracy=0.9983, val_error=0.9774, val_accuracy=0.8056
# 17/20, error=0.0174, accuracy=0.9983, val_error=0.9885, val_accuracy=0.8061
# 18/20, error=0.016, accuracy=0.9983, val_error=0.9995, val_accuracy=0.8067
# 19/20, error=0.0149, accuracy=0.9994, val_error=1.01, val_accuracy=0.8094
# 20/20, error=0.0139, accuracy=0.9994, val_error=1.0201, val_accuracy=0.8094
# Layers : 2
# 1/20, error=0.6714, accuracy=0.8343, val_error=0.8332, val_accuracy=0.7996
# 2/20, error=0.2622, accuracy=0.9183, val_error=0.7058, val_accuracy=0.8341
# 3/20, error=0.1767, accuracy=0.9412, val_error=0.7769, val_accuracy=0.8363
# 4/20, error=0.1366, accuracy=0.9541, val_error=0.8061, val_accuracy=0.8313
# 5/20, error=0.1057, accuracy=0.9642, val_error=0.8361, val_accuracy=0.8269
# 6/20, error=0.0809, accuracy=0.9709, val_error=0.8735, val_accuracy=0.8138
# 7/20, error=0.0633, accuracy=0.9832, val_error=0.9079, val_accuracy=0.8187
# 8/20, error=0.0522, accuracy=0.9849, val_error=0.9359, val_accuracy=0.8193
# 9/20, error=0.0442, accuracy=0.9894, val_error=0.9572, val_accuracy=0.8204
# 10/20, error=0.038, accuracy=0.9922, val_error=0.9742, val_accuracy=0.8237
# 11/20, error=0.0331, accuracy=0.9944, val_error=0.9898, val_accuracy=0.8237
# 12/20, error=0.0289, accuracy=0.9961, val_error=1.0038, val_accuracy=0.8242
# 13/20, error=0.0254, accuracy=0.9961, val_error=1.016, val_accuracy=0.8242
# 14/20, error=0.0225, accuracy=0.9966, val_error=1.0264, val_accuracy=0.8242
# 15/20, error=0.0202, accuracy=0.9978, val_error=1.036, val_accuracy=0.8308
# 16/20, error=0.0184, accuracy=0.9983, val_error=1.0453, val_accuracy=0.8308
# 17/20, error=0.0169, accuracy=0.9983, val_error=1.0545, val_accuracy=0.8313
# 18/20, error=0.0156, accuracy=0.9994, val_error=1.0636, val_accuracy=0.8313
# 19/20, error=0.0145, accuracy=0.9994, val_error=1.0725, val_accuracy=0.8313
# 20/20, error=0.0136, accuracy=1.0, val_error=1.0813, val_accuracy=0.8308
# Test Accuracy =  0.9236428571428571
# Test Loss =  0.07153245021098509
# Balanced dataset shape: (1808, 784), (1808,)
# Balanced dataset shape: (1818, 784), (1818,)
# Layers : 1
# 1/20, error=0.6419, accuracy=0.8545, val_error=0.8617, val_accuracy=0.7943
# 2/20, error=0.1938, accuracy=0.9441, val_error=0.9985, val_accuracy=0.7596
# 3/20, error=0.1263, accuracy=0.9629, val_error=0.9532, val_accuracy=0.7701
# 4/20, error=0.0983, accuracy=0.9718, val_error=0.9363, val_accuracy=0.7673
# 5/20, error=0.0818, accuracy=0.9779, val_error=0.932, val_accuracy=0.7794
# 6/20, error=0.0704, accuracy=0.9817, val_error=0.936, val_accuracy=0.7844
# 7/20, error=0.0611, accuracy=0.9823, val_error=0.9438, val_accuracy=0.786
# 8/20, error=0.0534, accuracy=0.9851, val_error=0.9509, val_accuracy=0.8053
# 9/20, error=0.0475, accuracy=0.9912, val_error=0.9577, val_accuracy=0.7954
# 10/20, error=0.0427, accuracy=0.9923, val_error=0.9662, val_accuracy=0.8053
# 11/20, error=0.0386, accuracy=0.9934, val_error=0.9747, val_accuracy=0.8141
# 12/20, error=0.0352, accuracy=0.995, val_error=0.9829, val_accuracy=0.8152
# 13/20, error=0.0323, accuracy=0.995, val_error=0.9908, val_accuracy=0.8152
# 14/20, error=0.0297, accuracy=0.9956, val_error=0.9982, val_accuracy=0.8097
# 15/20, error=0.0273, accuracy=0.9961, val_error=1.0048, val_accuracy=0.7992
# 16/20, error=0.0251, accuracy=0.9961, val_error=1.0099, val_accuracy=0.8097
# 17/20, error=0.0231, accuracy=0.9961, val_error=1.0112, val_accuracy=0.8102
# 18/20, error=0.0213, accuracy=0.9967, val_error=1.0098, val_accuracy=0.8091
# 19/20, error=0.0196, accuracy=0.9967, val_error=1.0075, val_accuracy=0.8036
# 20/20, error=0.0182, accuracy=0.9972, val_error=1.0041, val_accuracy=0.8036
# 1/20, error=0.2073, accuracy=0.7616, val_error=0.1533, val_accuracy=0.8157
# 2/20, error=0.0838, accuracy=0.9093, val_error=0.1218, val_accuracy=0.8548
# 3/20, error=0.0603, accuracy=0.9353, val_error=0.1088, val_accuracy=0.8636
# 4/20, error=0.0485, accuracy=0.9519, val_error=0.1123, val_accuracy=0.8718
# 5/20, error=0.0451, accuracy=0.9541, val_error=0.1146, val_accuracy=0.8685
# 6/20, error=0.0425, accuracy=0.9569, val_error=0.0927, val_accuracy=0.8955
# 7/20, error=0.0364, accuracy=0.9646, val_error=0.089, val_accuracy=0.8955
# 8/20, error=0.0358, accuracy=0.9646, val_error=0.0856, val_accuracy=0.896
# 9/20, error=0.0353, accuracy=0.9652, val_error=0.0792, val_accuracy=0.896
# 10/20, error=0.0308, accuracy=0.969, val_error=0.0689, val_accuracy=0.9125
# 11/20, error=0.0277, accuracy=0.9729, val_error=0.066, val_accuracy=0.912
# 12/20, error=0.0274, accuracy=0.9729, val_error=0.0644, val_accuracy=0.9125
# 13/20, error=0.0253, accuracy=0.9751, val_error=0.0622, val_accuracy=0.9257
# 14/20, error=0.0236, accuracy=0.9768, val_error=0.0612, val_accuracy=0.9257
# 15/20, error=0.0235, accuracy=0.9768, val_error=0.0603, val_accuracy=0.9257
# 16/20, error=0.0234, accuracy=0.9768, val_error=0.0597, val_accuracy=0.9257
# 17/20, error=0.0234, accuracy=0.9768, val_error=0.0594, val_accuracy=0.9268
# 18/20, error=0.0233, accuracy=0.9768, val_error=0.0593, val_accuracy=0.9296
# 19/20, error=0.0233, accuracy=0.9768, val_error=0.0598, val_accuracy=0.9296
# 20/20, error=0.0232, accuracy=0.9768, val_error=0.0611, val_accuracy=0.9191
# Layers : 2
# 1/20, error=0.6874, accuracy=0.8402, val_error=0.7968, val_accuracy=0.7783
# 2/20, error=0.2002, accuracy=0.9381, val_error=0.7641, val_accuracy=0.8168
# 3/20, error=0.1322, accuracy=0.964, val_error=0.7484, val_accuracy=0.8207
# 4/20, error=0.1051, accuracy=0.9723, val_error=0.7844, val_accuracy=0.8113
# 5/20, error=0.0872, accuracy=0.9762, val_error=0.7886, val_accuracy=0.8157
# 6/20, error=0.073, accuracy=0.9801, val_error=0.7792, val_accuracy=0.8196
# 7/20, error=0.0627, accuracy=0.9845, val_error=0.769, val_accuracy=0.8196
# 8/20, error=0.055, accuracy=0.9878, val_error=0.7644, val_accuracy=0.8289
# 9/20, error=0.0491, accuracy=0.9912, val_error=0.7676, val_accuracy=0.835
# 10/20, error=0.0442, accuracy=0.9928, val_error=0.7748, val_accuracy=0.8339
# 11/20, error=0.0399, accuracy=0.9934, val_error=0.7832, val_accuracy=0.8251
# 12/20, error=0.0362, accuracy=0.9939, val_error=0.7921, val_accuracy=0.8251
# 13/20, error=0.0329, accuracy=0.9945, val_error=0.802, val_accuracy=0.8256
# 14/20, error=0.0299, accuracy=0.9961, val_error=0.8156, val_accuracy=0.8207
# 15/20, error=0.0272, accuracy=0.9961, val_error=0.837, val_accuracy=0.8262
# 16/20, error=0.0247, accuracy=0.9967, val_error=0.8644, val_accuracy=0.8218
# 17/20, error=0.0226, accuracy=0.9967, val_error=0.8873, val_accuracy=0.8229
# 18/20, error=0.0208, accuracy=0.9978, val_error=0.9036, val_accuracy=0.8284
# 19/20, error=0.0192, accuracy=0.9978, val_error=0.916, val_accuracy=0.8262
# 20/20, error=0.0178, accuracy=0.9978, val_error=0.9263, val_accuracy=0.8267
# Layers : 2
# 1/20, error=0.5193, accuracy=0.865, val_error=0.8439, val_accuracy=0.7618
# 2/20, error=0.1823, accuracy=0.9425, val_error=0.8382, val_accuracy=0.7723
# 3/20, error=0.1326, accuracy=0.9607, val_error=0.8173, val_accuracy=0.7976
# 4/20, error=0.1081, accuracy=0.969, val_error=0.8375, val_accuracy=0.7987
# 5/20, error=0.0897, accuracy=0.9729, val_error=0.8601, val_accuracy=0.7893
# 6/20, error=0.0758, accuracy=0.9779, val_error=0.8778, val_accuracy=0.802
# 7/20, error=0.0648, accuracy=0.9829, val_error=0.8798, val_accuracy=0.8053
# 8/20, error=0.0565, accuracy=0.9856, val_error=0.882, val_accuracy=0.8042
# 9/20, error=0.05, accuracy=0.9878, val_error=0.89, val_accuracy=0.8097
# 10/20, error=0.0446, accuracy=0.9906, val_error=0.9048, val_accuracy=0.8097
# 11/20, error=0.0397, accuracy=0.9928, val_error=0.9249, val_accuracy=0.8163
# 12/20, error=0.0357, accuracy=0.9939, val_error=0.9442, val_accuracy=0.8168
# 13/20, error=0.0323, accuracy=0.995, val_error=0.9586, val_accuracy=0.8119
# 14/20, error=0.0295, accuracy=0.9956, val_error=0.969, val_accuracy=0.819
# 15/20, error=0.027, accuracy=0.9956, val_error=0.977, val_accuracy=0.8196
# 16/20, error=0.0249, accuracy=0.9961, val_error=0.9836, val_accuracy=0.819
# 17/20, error=0.023, accuracy=0.9967, val_error=0.9895, val_accuracy=0.8196
# 18/20, error=0.0214, accuracy=0.9972, val_error=0.9952, val_accuracy=0.8234
# 19/20, error=0.0199, accuracy=0.9972, val_error=1.0008, val_accuracy=0.8212
# 20/20, error=0.0186, accuracy=0.9978, val_error=1.0066, val_accuracy=0.8212
# Test Accuracy =  0.9405
# Test Loss =  0.05351191714761331

# %%
def predict_tree_classifiers(tree_classifier,X_sample):
    predictions = []
    pred_all = []
    for classifier in tree_classifier:
        pred = classifier.predict(X_sample)
        pred_all.append(pred)
    predicts = np.array(pred_all).squeeze().transpose()
    for pred in predicts:
        predictions.append(pred)
    return np.array(predictions)

# %%
def eval_tree(tree_classifier,X_sample,y_sample):
    predictions = predict_tree_classifiers(tree_classifier,X_sample)
    acc = 0
    for pred,true in zip(predictions,y_sample):
        if np.argmax(pred)==true:
            acc+=1
    return acc/len(X_sample)

# %%
print("test_acc:",eval_tree(tree_classifier,X_test,y_test))
print("val_acc:",eval_tree(tree_classifier,X_val,y_val))
print("train_acc:",eval_tree(tree_classifier,X_train,y_train))
# Out:
# test_acc: 0.8311428571428572
# val_acc: 0.825
# train_acc: 0.985

# %%
# Multiclass values
plots_multi = [{'dataset': 'test', 'acc': 0.8083571428571429},#test,
{'dataset': 'validation', 'acc': 0.8136}#val
, {'dataset': 'training', 'acc': 0.8144117647058824}]

# %%
index =0
fig = plt.figure(figsize=(10, 5)) 

rows = 2
columns = 5
for classifier in tree_classifier:
    fig.add_subplot(rows, columns, index+1) 
    plt.imshow(classifier.NN[0].weights.squeeze()[:-2].reshape(28,28))
    plt.axis('off') 
    plt.title('classifier:{}'.format(index))
    index+=1

# %%
top100 = get_top(X,labels)
np.random.shuffle(top100)

# %%
pairs = []
pair_labels = []
for row1 in top100:
    for row2 in top100:
        pairs.append(np.hstack((row2[:-1],row1[:-1])))
        if row1[-1]==row2[-1]:
            pair_labels.append(1)
        else:
            pair_labels.append(0)

pairs = np.vstack(pairs)
pair_labels = np.array(pair_labels)

# %%
def predict_siamese(tree_classifier,X,threshold=1):
    X_sample = X.reshape(len(X), 2, 784)
    predictions = []
    first_images = []
    second_images = []
    
    for sample in X_sample:
        first_images.append(predict_tree_classifiers(tree_classifier,sample[0].reshape(1,784)))
        second_images.append(predict_tree_classifiers(tree_classifier,sample[1].reshape(1,784)))

    for first,second in zip(first_images,second_images):
        euclidean_dist =np.sqrt(np.sum(np.square(first - second)))
        if euclidean_dist<threshold:
            predictions.append(1)
        else:
            predictions.append(0)
    return np.array(predictions)

# %%
X_train,X_val,y_train,y_val = train_test_split(pairs,pair_labels,test_size=0.2,shuffle=True)

# %%
def eval(predictions,true_val):
    acc = 0
    for pred,true in zip(predictions,true_val):
        if pred==true:
            acc+=1
    return acc/len(true_val)

# %%
def eval_siamese(X_sample,label_sample,k=5):
    topk = get_top(X,labels,k)
    np.random.shuffle(topk)
    predictions = []
    for sample in tqdm.tqdm(X_sample.to_numpy()):
        pairs = []
        pair_labels = []
        for row in topk:
            pairs.append(np.hstack((sample[:],row[:-1])))
            pair_labels.append(row[-1])
        pairs = np.vstack(pairs)
        pair_labels = np.array(pair_labels).astype(int)
        sample_predictions = predict_siamese(tree_classifier,pairs)
        predict = np.bincount(pair_labels[sample_predictions==1])
        if predict.size:
            predictions.append(predict.argmax())
        else:
            predictions.append(10)
    acc = eval(np.array(predictions),label_sample)
    return {'k':k,'acc':acc}

# %%
X_train,X_test,y_train,y_test = train_test_split(X,labels,test_size=0.2,shuffle=True)
X_val, y_val = X_train.iloc[:5000],y_train[:5000]
X_train, y_train = X_train.iloc[5000:],y_train[5000:]

# %%
plt.imshow(pairs[45002].reshape(2,784)[0].reshape(28,28))

# %%
#test
eval_siamese(X_test[:1000],y_test[:1000],k=10)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {'k': 10, 'acc': 0.804}

# %%
#train
eval_siamese(X_train.iloc[:len(X_train)//4],y_train[:len(y_train)//4],k=20)
# Out:
#   0%|          | 0/12750 [00:00<?, ?it/s]
# {'k': 20, 'acc': 0.7890196078431373}

# %%
plots_bin = [{'dataset': 'test', 'acc': 0.7723571428571429},#test
{'dataset': 'validation', 'acc': 0.7866},#val
{'dataset': 'training', 'acc': 0.7890196078431373}]#train

# %%
outputs = []
for i in tqdm.tqdm([1,2,4,8,16,20,32,64]):
    outputs.append(eval_siamese(X_test,y_test,k=i))
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
outputs
# Out:
# [{'k': 1, 'acc': 0.4719285714285714},
#  {'k': 2, 'acc': 0.6239285714285714},
#  {'k': 4, 'acc': 0.6858571428571428},
#  {'k': 8, 'acc': 0.65},
#  {'k': 16, 'acc': 0.7668571428571429},
#  {'k': 32, 'acc': 0.7987785714285714},
#  {'k': 64, 'acc': 0.792}]

# %%
plots = pd.DataFrame(outputs)

# %%
plt.plot(plots['k'],plots['acc'])
plt.title('Accuracy vs K')
plt.xlabel('k value')
plt.ylabel('Test Accuracy')
plt.savefig('./graph/acc_vs_k.png')

# %%
plots_multi = pd.DataFrame(plots_multi)
plots_bin = pd.DataFrame(plots_bin)

# %%
X_axis =np.arange(len(plots_bin))
plt.bar(X_axis+0.2,plots_multi['acc'],0.4,label='Growing Tree NN')
plt.bar(X_axis-0.2,plots_bin['acc'],0.4,label='Binary Classifier')
plt.xticks(X_axis,plots_bin['dataset'])
plt.title('Accuracy Plot for Classifiers')
plt.xlabel('Dataset')
plt.ylabel('Accuracy')
plt.ylim(0.7,0.85)
plt.legend()
plt.savefig('./graph/compare.png')

# %%
def oversample(X_train,Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    max_samples = max(len(class_0), len(class_1))
    class_0_upsampled = class_0.sample(max_samples, replace=True, random_state=42) if len(class_0) < max_samples else class_0
    class_1_upsampled = class_1.sample(max_samples, replace=True, random_state=42) if len(class_1) < max_samples else class_1
    X_train_balanced = pd.concat([class_0_upsampled, class_1_upsampled])
    Y_train_balanced = pd.Series([0] * max_samples + [1] * max_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    #print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced,Y_train_balanced

def undersample(X_train, Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    
    # Separate classes
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    
    # Determine minimum sample size
    min_samples = min(len(class_0), len(class_1))
    
    # Downsample both classes to match the smaller class
    class_0_downsampled = class_0.sample(min_samples, random_state=42)
    class_1_downsampled = class_1.sample(min_samples, random_state=42)
    
    # Combine downsampled classes and shuffle
    X_train_balanced = pd.concat([class_0_downsampled, class_1_downsampled])
    Y_train_balanced = pd.Series([0] * min_samples + [1] * min_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    
    # Convert to numpy arrays
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    
    #print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced, Y_train_balanced
