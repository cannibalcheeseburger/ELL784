# %%
from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score,classification_report
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tqdm.notebook as tqdm
from sklearn.utils import shuffle

# %%
from NeuralNetwork.dense import Dense
from NeuralNetwork.activations import Sigmoid,Softmax,ReLU
from NeuralNetwork.losses import categorical_crossentropy, categorical_crossentropy_derive,mse,mse_derive,binary_crossentropy,binary_crossentropy_derive
from NeuralNetwork.network import predict

# %%
mnist = fetch_openml('mnist_784')

# %%
X = mnist.data/255.0
labels = np.array( mnist.target).astype(int)

# %%
#y = np.squeeze(np.eye(10)[labels])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,labels,test_size=0.2,shuffle=True)
X_val, y_val = X_train.iloc[:5000],y_train[:5000]
X_train, y_train = X_train.iloc[5000:],y_train[5000:]

# %%
EPOCH = 20
ALPHA = 0.08

# %%
def encode(z):
    if z>=0.5:
        return 1
    return 0

# %%
def train(NN, loss, loss_derive, X, Y, X_val,Y_val, epoch=EPOCH, alpha=ALPHA, verbose = True):
    error_TS = []
    acc_TS = []
    val_acc_TS = []
    val_error_TS = []
    for e in range(epoch):
        errors = 0
        acc = 0
        val_acc = 0
        val_error = 0
        for x, y in zip(X, Y):
            out = predict(NN, x)
            if y==encode(out):
                acc+=1
            errors += loss(y, out)
            gradient = loss_derive(y, out)
            for layer in reversed(NN):
                gradient = layer.backward(gradient, alpha)

        for x, y in zip(X_val, Y_val):
            output = predict(NN, x)
            if y==encode(output):
                val_acc+=1
            val_error += loss(y, output)

        errors /= len(X)
        acc /=len(X)
        val_error /= len(X_val)
        val_acc /=len(X_val)
        if verbose:
            print(f"{e + 1}/{epoch}, error={round(errors,4)}, accuracy={round(acc,4)}, val_error={round(val_error,4)}, val_accuracy={round(val_acc,4)}")
        error_TS.append(errors)
        acc_TS.append(acc)
        val_error_TS.append(val_error)
        val_acc_TS.append(val_acc)
    return [error_TS,acc_TS,val_error_TS,val_acc_TS]

class TreeNN():
    def __init__(self,depth=1,max_depth=3,parent_node = None):
        self.parent_node = parent_node
        self.NN = [
            Dense(784,1),
            Sigmoid()
        ]
        self.depth = depth
        self.max_depth = max_depth
        self.children = []
    
    def get_augemented(self,X,Y):
        Xa_train = []
        Xb_train = []
        for x, y in zip(X, Y):
            output = encode(predict(self.NN, x))
            if y!=output:
                if output==0 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
                if output==1 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

            else:
                if output==0 and y==0:
                    Xa_train.append(0)
                    Xb_train.append(1)

                if output==1 and y==1:
                    Xa_train.append(1)
                    Xb_train.append(0)
        return Xa_train,Xb_train
    
    def plot(self,metrics):
        metrics_names = ['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy']
        for i in range(len(metrics_names)):
            plt.plot(metrics[i])
            plt.xlabel("Epochs")
            plt.ylabel(metrics_names[i])
            plt.savefig("./graph/MNIST_{}_{}.png".format(metrics_names[i],self.depth))
            plt.clf()


    
    def train_tree(self,X,Y,X_val,Y_val):
        print("Layers :",self.depth)
        X_train = np.reshape(X,X.shape +(1,))
        Y_train = np.reshape(Y,Y.shape +(1,))
        X_val_in =np.reshape(X_val,X_val.shape +(1,))
        Y_val_in =np.reshape(Y_val,Y_val.shape +(1,))
        metrics = train(self.NN,binary_crossentropy,binary_crossentropy_derive,X_train,Y_train,X_val_in,Y_val_in)
        self.plot(metrics)
        if self.max_depth>self.depth+1:
            ## Adding Layers
            Na = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            Nb = TreeNN(depth=self.depth+1,max_depth=self.max_depth,parent_node=self)
            self.children.append(Na)
            self.children.append(Nb)
            #Retrain with extra feature
            Xa_train,Xb_train = self.get_augemented(X_train,Y_train)
            X_retrain = np.column_stack((X, Xa_train))
            X_retrain = np.column_stack((X_retrain, Xb_train))
            X_retrain = np.reshape(X_retrain,X_retrain.shape+(1,))
            Xa,Xb = self.get_augemented(X_val_in,Y_val_in)
            X_reval = np.column_stack((X_val, Xa))
            X_reval = np.column_stack((X_reval, Xb))
            X_reval = np.reshape(X_reval,X_reval.shape+(1,))
            self.NN = [Dense(786,1),Sigmoid()]
            metrics = train(self.NN,mse,mse_derive,X_retrain,Y_train,X_reval,Y_val_in)
            self.plot(metrics)
            #Na
            self.children[0].train_tree(X,np.asanyarray(Xa_train),X_val,np.asanyarray(Xa))
            #Nb
            self.children[1].train_tree(X,np.asanyarray(Xb_train),X_val,np.asanyarray(Xb))

    def predict(self,X):
        if self.depth>self.max_depth:
            return  None  
        predictions = []

        if self.children == []:
            X_train = np.reshape(X,X.shape +(1,))
        else:
            Xa = self.children[0].predict(X)
            Xb = self.children[1].predict(X)
            Xa_encode = []
            Xb_encode = []
            for xa,xb in zip(Xa,Xb):
                Xa_encode.append(encode(xa))
                Xb_encode.append(encode(xb))
            X_train = np.column_stack((X, Xa_encode))
            X_train = np.column_stack((X_train, Xb_encode))
            X_train = np.reshape(X_train,X_train.shape+(1,))
        for x in X_train:
            output = predict(self.NN,x)
            predictions.append(output)

        return predictions
        # check for more probability

# %%
def oversample(X_train,Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    max_samples = max(len(class_0), len(class_1))
    class_0_upsampled = class_0.sample(max_samples, replace=True, random_state=42) if len(class_0) < max_samples else class_0
    class_1_upsampled = class_1.sample(max_samples, replace=True, random_state=42) if len(class_1) < max_samples else class_1
    X_train_balanced = pd.concat([class_0_upsampled, class_1_upsampled])
    Y_train_balanced = pd.Series([0] * max_samples + [1] * max_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced,Y_train_balanced

def undersample(X_train, Y_train):
    X_train_df = pd.DataFrame(X_train)
    Y_train_series = pd.Series(Y_train)
    X_train_df = X_train_df.reset_index(drop=True)
    Y_train_series = Y_train_series.reset_index(drop=True)
    
    # Separate classes
    class_0 = X_train_df[Y_train_series == 0]
    class_1 = X_train_df[Y_train_series == 1]
    
    # Determine minimum sample size
    min_samples = min(len(class_0), len(class_1))
    
    # Downsample both classes to match the smaller class
    class_0_downsampled = class_0.sample(min_samples, random_state=42)
    class_1_downsampled = class_1.sample(min_samples, random_state=42)
    
    # Combine downsampled classes and shuffle
    X_train_balanced = pd.concat([class_0_downsampled, class_1_downsampled])
    Y_train_balanced = pd.Series([0] * min_samples + [1] * min_samples)
    X_train_balanced, Y_train_balanced = shuffle(X_train_balanced, Y_train_balanced, random_state=42)
    
    # Convert to numpy arrays
    X_train_balanced = X_train_balanced.to_numpy()
    Y_train_balanced = Y_train_balanced.to_numpy()
    
    print(f"Balanced dataset shape: {X_train_balanced.shape}, {Y_train_balanced.shape}")
    return X_train_balanced, Y_train_balanced

# %%
def get_XY(X_train,y_train,X_val,y_val,y_test,class_):
    y_in = np.where(y_train == class_, 1, 0)
    y_v = np.where(y_val == class_, 1, 0)
    y_t = np.where(y_test == class_, 1, 0)
    X_in,y_in= undersample(X_train,y_in)
    X_v,y_v= undersample(X_val,y_v)
    return X_in,y_in,X_v,y_v,y_t

# %%
tree_classifier = []
for classifier in tqdm.tqdm(range(10)):
    root = TreeNN(max_depth=3,parent_node=None)
    X_in,y_in,X_v,y_v,y_t = get_XY(X_train,y_train,X_val,y_val,y_test,classifier)
    root.train_tree(X_in,y_in,X_v,y_v)
    tree_classifier.append(root)
    pred = root.predict(X_test)
    acc = 0
    error = 0
    for p,t in zip(pred,y_t):
        if encode(p)==t:
            acc+=1
        error+=mse(p,t)
    print("Test Accuracy = ",acc/len(y_t))
    print("Test Loss = ",error/len(y_t))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Balanced dataset shape: (9988, 784), (9988,)
# Balanced dataset shape: (998, 784), (998,)
# Layers : 1
# 1/20, error=0.1697, accuracy=0.9612, val_error=0.1289, val_accuracy=0.9749
# 2/20, error=0.1017, accuracy=0.9771, val_error=0.1343, val_accuracy=0.9749
# 3/20, error=0.0873, accuracy=0.9799, val_error=0.1475, val_accuracy=0.9729
# 4/20, error=0.08, accuracy=0.9809, val_error=0.1575, val_accuracy=0.9709
# 5/20, error=0.0749, accuracy=0.982, val_error=0.1596, val_accuracy=0.9709
# 6/20, error=0.0708, accuracy=0.9827, val_error=0.161, val_accuracy=0.9689
# 7/20, error=0.0674, accuracy=0.9832, val_error=0.161, val_accuracy=0.9689
# 8/20, error=0.0645, accuracy=0.9836, val_error=0.1596, val_accuracy=0.9689
# 9/20, error=0.0618, accuracy=0.9839, val_error=0.1582, val_accuracy=0.9689
# 10/20, error=0.0595, accuracy=0.9842, val_error=0.1569, val_accuracy=0.9699
# 11/20, error=0.0574, accuracy=0.9852, val_error=0.1562, val_accuracy=0.9699
# 12/20, error=0.0556, accuracy=0.9856, val_error=0.1567, val_accuracy=0.9699
# 13/20, error=0.0539, accuracy=0.9856, val_error=0.1582, val_accuracy=0.9699
# 14/20, error=0.0525, accuracy=0.9857, val_error=0.1598, val_accuracy=0.9699
# 15/20, error=0.0512, accuracy=0.9864, val_error=0.1612, val_accuracy=0.9699
# 16/20, error=0.0501, accuracy=0.9865, val_error=0.1624, val_accuracy=0.9709
# 17/20, error=0.049, accuracy=0.9867, val_error=0.1633, val_accuracy=0.9709
# 18/20, error=0.0479, accuracy=0.9869, val_error=0.1637, val_accuracy=0.9709
# 19/20, error=0.047, accuracy=0.9873, val_error=0.164, val_accuracy=0.9719
# 20/20, error=0.0461, accuracy=0.9875, val_error=0.1642, val_accuracy=0.9719
# 1/20, error=0.0453, accuracy=0.9477, val_error=0.0179, val_accuracy=0.978
# 2/20, error=0.0108, accuracy=0.987, val_error=0.0103, val_accuracy=0.987
# 3/20, error=0.0063, accuracy=0.9917, val_error=0.0058, val_accuracy=0.994
# 4/20, error=0.0031, accuracy=0.9959, val_error=0.0043, val_accuracy=0.995
# 5/20, error=0.0017, accuracy=0.9983, val_error=0.0039, val_accuracy=0.995
# 6/20, error=0.0011, accuracy=0.9989, val_error=0.003, val_accuracy=0.996
# 7/20, error=0.0008, accuracy=0.9991, val_error=0.0023, val_accuracy=0.997
# 8/20, error=0.0006, accuracy=0.9994, val_error=0.002, val_accuracy=0.997
# 9/20, error=0.0005, accuracy=0.9996, val_error=0.0017, val_accuracy=0.997
# 10/20, error=0.0004, accuracy=0.9997, val_error=0.0016, val_accuracy=0.997
# 11/20, error=0.0004, accuracy=0.9997, val_error=0.0014, val_accuracy=0.998
# 12/20, error=0.0003, accuracy=0.9997, val_error=0.0011, val_accuracy=0.998
# 13/20, error=0.0003, accuracy=0.9997, val_error=0.0008, val_accuracy=0.999
# 14/20, error=0.0003, accuracy=0.9997, val_error=0.0006, val_accuracy=0.999
# 15/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 16/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 17/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 18/20, error=0.0002, accuracy=0.9998, val_error=0.0006, val_accuracy=0.999
# 19/20, error=0.0001, accuracy=0.9999, val_error=0.0006, val_accuracy=0.999
# 20/20, error=0.0001, accuracy=0.9999, val_error=0.0006, val_accuracy=0.999
# Layers : 2
# 1/20, error=0.1715, accuracy=0.9612, val_error=0.1357, val_accuracy=0.9689
# 2/20, error=0.101, accuracy=0.9773, val_error=0.132, val_accuracy=0.9729
# 3/20, error=0.0866, accuracy=0.979, val_error=0.1416, val_accuracy=0.9729
# 4/20, error=0.0787, accuracy=0.9803, val_error=0.1439, val_accuracy=0.9739
# 5/20, error=0.0729, accuracy=0.9808, val_error=0.1457, val_accuracy=0.9719
# 6/20, error=0.0684, accuracy=0.9821, val_error=0.1472, val_accuracy=0.9709
# 7/20, error=0.0646, accuracy=0.9833, val_error=0.1481, val_accuracy=0.9729
# 8/20, error=0.0617, accuracy=0.9838, val_error=0.1488, val_accuracy=0.9719
# 9/20, error=0.0595, accuracy=0.9843, val_error=0.1495, val_accuracy=0.9709
# 10/20, error=0.0577, accuracy=0.9849, val_error=0.1497, val_accuracy=0.9719
# 11/20, error=0.0561, accuracy=0.9855, val_error=0.1499, val_accuracy=0.9719
# 12/20, error=0.0545, accuracy=0.986, val_error=0.1505, val_accuracy=0.9719
# 13/20, error=0.053, accuracy=0.9863, val_error=0.1515, val_accuracy=0.9739
# 14/20, error=0.0516, accuracy=0.9867, val_error=0.1524, val_accuracy=0.9729
# 15/20, error=0.0503, accuracy=0.9869, val_error=0.153, val_accuracy=0.9729
# 16/20, error=0.049, accuracy=0.9868, val_error=0.1535, val_accuracy=0.9739
# 17/20, error=0.0478, accuracy=0.987, val_error=0.1537, val_accuracy=0.9729
# 18/20, error=0.0467, accuracy=0.9874, val_error=0.1538, val_accuracy=0.9729
# 19/20, error=0.0457, accuracy=0.988, val_error=0.1539, val_accuracy=0.9729
# 20/20, error=0.0447, accuracy=0.9881, val_error=0.1541, val_accuracy=0.9719
# Layers : 2
# 1/20, error=0.1765, accuracy=0.9601, val_error=0.1441, val_accuracy=0.9719
# 2/20, error=0.1022, accuracy=0.9763, val_error=0.1466, val_accuracy=0.9729
# 3/20, error=0.0871, accuracy=0.9797, val_error=0.1429, val_accuracy=0.9729
# 4/20, error=0.0791, accuracy=0.981, val_error=0.1378, val_accuracy=0.9739
# 5/20, error=0.0736, accuracy=0.9819, val_error=0.135, val_accuracy=0.9739
# 6/20, error=0.069, accuracy=0.983, val_error=0.1325, val_accuracy=0.9729
# 7/20, error=0.0653, accuracy=0.9838, val_error=0.1303, val_accuracy=0.9739
# 8/20, error=0.0623, accuracy=0.9841, val_error=0.13, val_accuracy=0.9729
# 9/20, error=0.0597, accuracy=0.9852, val_error=0.1322, val_accuracy=0.976
# 10/20, error=0.0576, accuracy=0.9859, val_error=0.1342, val_accuracy=0.976
# 11/20, error=0.0557, accuracy=0.9861, val_error=0.1353, val_accuracy=0.977
# 12/20, error=0.0539, accuracy=0.9865, val_error=0.1364, val_accuracy=0.977
# 13/20, error=0.0523, accuracy=0.9869, val_error=0.1376, val_accuracy=0.976
# 14/20, error=0.0509, accuracy=0.987, val_error=0.1391, val_accuracy=0.976
# 15/20, error=0.0495, accuracy=0.987, val_error=0.1411, val_accuracy=0.976
# 16/20, error=0.0483, accuracy=0.9871, val_error=0.1431, val_accuracy=0.976
# 17/20, error=0.0473, accuracy=0.9874, val_error=0.1451, val_accuracy=0.9749
# 18/20, error=0.0463, accuracy=0.9873, val_error=0.147, val_accuracy=0.9749
# 19/20, error=0.0454, accuracy=0.9875, val_error=0.1487, val_accuracy=0.9749
# 20/20, error=0.0445, accuracy=0.9876, val_error=0.1502, val_accuracy=0.976
# Test Accuracy =  0.9818571428571429
# Test Loss =  0.016873172240245243
# Balanced dataset shape: (11426, 784), (11426,)
# Balanced dataset shape: (1134, 784), (1134,)
# Layers : 1
# 1/20, error=0.1189, accuracy=0.9701, val_error=0.0837, val_accuracy=0.9806
# 2/20, error=0.0785, accuracy=0.9792, val_error=0.0814, val_accuracy=0.985
# 3/20, error=0.0682, accuracy=0.9817, val_error=0.0823, val_accuracy=0.985
# 4/20, error=0.0626, accuracy=0.983, val_error=0.0825, val_accuracy=0.985
# 5/20, error=0.0589, accuracy=0.9847, val_error=0.0821, val_accuracy=0.985
# 6/20, error=0.056, accuracy=0.9858, val_error=0.0819, val_accuracy=0.985
# 7/20, error=0.0536, accuracy=0.9862, val_error=0.0819, val_accuracy=0.985
# 8/20, error=0.0516, accuracy=0.9863, val_error=0.082, val_accuracy=0.985
# 9/20, error=0.05, accuracy=0.9864, val_error=0.0822, val_accuracy=0.9841
# 10/20, error=0.0486, accuracy=0.9867, val_error=0.0826, val_accuracy=0.9841
# 11/20, error=0.0473, accuracy=0.987, val_error=0.083, val_accuracy=0.985
# 12/20, error=0.0462, accuracy=0.987, val_error=0.0835, val_accuracy=0.9859
# 13/20, error=0.0452, accuracy=0.9873, val_error=0.0841, val_accuracy=0.9859
# 14/20, error=0.0443, accuracy=0.9876, val_error=0.0847, val_accuracy=0.9868
# 15/20, error=0.0435, accuracy=0.9877, val_error=0.0854, val_accuracy=0.9868
# 16/20, error=0.0428, accuracy=0.9879, val_error=0.086, val_accuracy=0.9859
# 17/20, error=0.0421, accuracy=0.988, val_error=0.0866, val_accuracy=0.9859
# 18/20, error=0.0414, accuracy=0.9882, val_error=0.0873, val_accuracy=0.985
# 19/20, error=0.0409, accuracy=0.9884, val_error=0.0879, val_accuracy=0.985
# 20/20, error=0.0403, accuracy=0.9886, val_error=0.0886, val_accuracy=0.985
# 1/20, error=0.045, accuracy=0.9487, val_error=0.0125, val_accuracy=0.9859
# 2/20, error=0.0071, accuracy=0.9907, val_error=0.0062, val_accuracy=0.9921
# 3/20, error=0.0032, accuracy=0.9959, val_error=0.0033, val_accuracy=0.9965
# 4/20, error=0.0019, accuracy=0.9978, val_error=0.0029, val_accuracy=0.9974
# 5/20, error=0.0014, accuracy=0.9984, val_error=0.0024, val_accuracy=0.9974
# 6/20, error=0.0012, accuracy=0.9989, val_error=0.0023, val_accuracy=0.9974
# 7/20, error=0.001, accuracy=0.999, val_error=0.0022, val_accuracy=0.9974
# 8/20, error=0.0009, accuracy=0.999, val_error=0.0019, val_accuracy=0.9974
# 9/20, error=0.0008, accuracy=0.9993, val_error=0.0015, val_accuracy=0.9974
# 10/20, error=0.0006, accuracy=0.9993, val_error=0.0015, val_accuracy=0.9982
# 11/20, error=0.0005, accuracy=0.9994, val_error=0.0013, val_accuracy=0.9982
# 12/20, error=0.0005, accuracy=0.9996, val_error=0.001, val_accuracy=0.9991
# 13/20, error=0.0004, accuracy=0.9996, val_error=0.0009, val_accuracy=0.9991
# 14/20, error=0.0004, accuracy=0.9996, val_error=0.0008, val_accuracy=0.9991
# 15/20, error=0.0004, accuracy=0.9996, val_error=0.0008, val_accuracy=0.9991
# 16/20, error=0.0003, accuracy=0.9996, val_error=0.0008, val_accuracy=0.9991
# 17/20, error=0.0003, accuracy=0.9996, val_error=0.0008, val_accuracy=0.9991
# 18/20, error=0.0003, accuracy=0.9997, val_error=0.0007, val_accuracy=0.9991
# 19/20, error=0.0003, accuracy=0.9997, val_error=0.0007, val_accuracy=0.9991
# 20/20, error=0.0003, accuracy=0.9997, val_error=0.0007, val_accuracy=0.9991
# Layers : 2
# 1/20, error=0.1212, accuracy=0.9687, val_error=0.0986, val_accuracy=0.9824
# 2/20, error=0.0808, accuracy=0.978, val_error=0.0883, val_accuracy=0.9841
# 3/20, error=0.0721, accuracy=0.9802, val_error=0.0849, val_accuracy=0.9859
# 4/20, error=0.0663, accuracy=0.9815, val_error=0.0831, val_accuracy=0.9859
# 5/20, error=0.0619, accuracy=0.9826, val_error=0.0825, val_accuracy=0.9868
# 6/20, error=0.0584, accuracy=0.9838, val_error=0.0825, val_accuracy=0.9877
# 7/20, error=0.0556, accuracy=0.9849, val_error=0.0829, val_accuracy=0.9877
# 8/20, error=0.0532, accuracy=0.9853, val_error=0.0833, val_accuracy=0.9877
# 9/20, error=0.0512, accuracy=0.9857, val_error=0.0838, val_accuracy=0.9877
# 10/20, error=0.0494, accuracy=0.9862, val_error=0.0844, val_accuracy=0.9868
# 11/20, error=0.048, accuracy=0.9864, val_error=0.0851, val_accuracy=0.9868
# 12/20, error=0.0467, accuracy=0.9869, val_error=0.0858, val_accuracy=0.9868
# 13/20, error=0.0456, accuracy=0.9871, val_error=0.0865, val_accuracy=0.9868
# 14/20, error=0.0446, accuracy=0.9872, val_error=0.0872, val_accuracy=0.9859
# 15/20, error=0.0437, accuracy=0.9879, val_error=0.0879, val_accuracy=0.9868
# 16/20, error=0.0429, accuracy=0.9877, val_error=0.0885, val_accuracy=0.9868
# 17/20, error=0.0421, accuracy=0.9878, val_error=0.0891, val_accuracy=0.9868
# 18/20, error=0.0415, accuracy=0.9883, val_error=0.0896, val_accuracy=0.9877
# 19/20, error=0.0408, accuracy=0.9882, val_error=0.0902, val_accuracy=0.9877
# 20/20, error=0.0402, accuracy=0.9884, val_error=0.0907, val_accuracy=0.9877
# Layers : 2
# 1/20, error=0.1268, accuracy=0.9683, val_error=0.0972, val_accuracy=0.9806
# 2/20, error=0.0844, accuracy=0.9779, val_error=0.0874, val_accuracy=0.9806
# 3/20, error=0.0741, accuracy=0.9794, val_error=0.0844, val_accuracy=0.9841
# 4/20, error=0.0673, accuracy=0.9812, val_error=0.0834, val_accuracy=0.9841
# 5/20, error=0.0624, accuracy=0.9826, val_error=0.0833, val_accuracy=0.9841
# 6/20, error=0.0588, accuracy=0.9834, val_error=0.0839, val_accuracy=0.9841
# 7/20, error=0.0561, accuracy=0.984, val_error=0.0847, val_accuracy=0.985
# 8/20, error=0.054, accuracy=0.9846, val_error=0.0855, val_accuracy=0.985
# 9/20, error=0.0522, accuracy=0.9849, val_error=0.0862, val_accuracy=0.9859
# 10/20, error=0.0506, accuracy=0.9851, val_error=0.0868, val_accuracy=0.9868
# 11/20, error=0.0492, accuracy=0.9855, val_error=0.0874, val_accuracy=0.9859
# 12/20, error=0.0479, accuracy=0.9855, val_error=0.0878, val_accuracy=0.9859
# 13/20, error=0.0467, accuracy=0.9863, val_error=0.0882, val_accuracy=0.9859
# 14/20, error=0.0457, accuracy=0.9865, val_error=0.0885, val_accuracy=0.985
# 15/20, error=0.0447, accuracy=0.9868, val_error=0.0888, val_accuracy=0.985
# 16/20, error=0.0438, accuracy=0.987, val_error=0.089, val_accuracy=0.985
# 17/20, error=0.043, accuracy=0.9874, val_error=0.0893, val_accuracy=0.9841
# 18/20, error=0.0422, accuracy=0.9877, val_error=0.0895, val_accuracy=0.9841
# 19/20, error=0.0415, accuracy=0.9878, val_error=0.0897, val_accuracy=0.9841
# 20/20, error=0.0408, accuracy=0.9878, val_error=0.09, val_accuracy=0.9841
# Test Accuracy =  0.9825
# Test Loss =  0.01661679576040701
# Balanced dataset shape: (10302, 784), (10302,)
# Balanced dataset shape: (998, 784), (998,)
# Layers : 1
# 1/20, error=0.4197, accuracy=0.9058, val_error=0.275, val_accuracy=0.9279
# 2/20, error=0.298, accuracy=0.9262, val_error=0.2551, val_accuracy=0.9349
# 3/20, error=0.2734, accuracy=0.9316, val_error=0.2508, val_accuracy=0.9369
# 4/20, error=0.2613, accuracy=0.9319, val_error=0.2419, val_accuracy=0.9349
# 5/20, error=0.2532, accuracy=0.9341, val_error=0.2331, val_accuracy=0.9369
# 6/20, error=0.2473, accuracy=0.9349, val_error=0.2273, val_accuracy=0.9399
# 7/20, error=0.2428, accuracy=0.936, val_error=0.2245, val_accuracy=0.9389
# 8/20, error=0.2396, accuracy=0.9376, val_error=0.2236, val_accuracy=0.9419
# 9/20, error=0.2371, accuracy=0.9378, val_error=0.2238, val_accuracy=0.9419
# 10/20, error=0.2349, accuracy=0.9389, val_error=0.2244, val_accuracy=0.9439
# 11/20, error=0.233, accuracy=0.9394, val_error=0.2253, val_accuracy=0.9459
# 12/20, error=0.2313, accuracy=0.9391, val_error=0.2264, val_accuracy=0.9479
# 13/20, error=0.2298, accuracy=0.9392, val_error=0.2276, val_accuracy=0.9469
# 14/20, error=0.2283, accuracy=0.9396, val_error=0.229, val_accuracy=0.9469
# 15/20, error=0.227, accuracy=0.9397, val_error=0.2304, val_accuracy=0.9469
# 16/20, error=0.2259, accuracy=0.9404, val_error=0.2318, val_accuracy=0.9459
# 17/20, error=0.2248, accuracy=0.9405, val_error=0.2333, val_accuracy=0.9449
# 18/20, error=0.2238, accuracy=0.9407, val_error=0.2347, val_accuracy=0.9449
# 19/20, error=0.2229, accuracy=0.9411, val_error=0.2361, val_accuracy=0.9469
# 20/20, error=0.2221, accuracy=0.941, val_error=0.2375, val_accuracy=0.9459
# 1/20, error=0.073, accuracy=0.9153, val_error=0.0235, val_accuracy=0.9699
# 2/20, error=0.0099, accuracy=0.9878, val_error=0.0052, val_accuracy=0.994
# 3/20, error=0.003, accuracy=0.9963, val_error=0.0018, val_accuracy=0.997
# 4/20, error=0.0012, accuracy=0.9985, val_error=0.0007, val_accuracy=0.999
# 5/20, error=0.0005, accuracy=0.9994, val_error=0.0002, val_accuracy=1.0
# 6/20, error=0.0002, accuracy=0.9998, val_error=0.0002, val_accuracy=1.0
# 7/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 10/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.4095, accuracy=0.9039, val_error=0.2574, val_accuracy=0.9349
# 2/20, error=0.301, accuracy=0.9243, val_error=0.2356, val_accuracy=0.9399
# 3/20, error=0.2754, accuracy=0.9284, val_error=0.2315, val_accuracy=0.9429
# 4/20, error=0.262, accuracy=0.9312, val_error=0.2293, val_accuracy=0.9419
# 5/20, error=0.2534, accuracy=0.9333, val_error=0.2254, val_accuracy=0.9409
# 6/20, error=0.2477, accuracy=0.935, val_error=0.2228, val_accuracy=0.9429
# 7/20, error=0.2434, accuracy=0.9353, val_error=0.2216, val_accuracy=0.9429
# 8/20, error=0.2401, accuracy=0.9361, val_error=0.2211, val_accuracy=0.9439
# 9/20, error=0.2375, accuracy=0.936, val_error=0.2211, val_accuracy=0.9439
# 10/20, error=0.2352, accuracy=0.9372, val_error=0.2215, val_accuracy=0.9469
# 11/20, error=0.2332, accuracy=0.9376, val_error=0.2222, val_accuracy=0.9459
# 12/20, error=0.2315, accuracy=0.9386, val_error=0.2232, val_accuracy=0.9439
# 13/20, error=0.2299, accuracy=0.9392, val_error=0.2244, val_accuracy=0.9429
# 14/20, error=0.2286, accuracy=0.9395, val_error=0.2256, val_accuracy=0.9439
# 15/20, error=0.2273, accuracy=0.94, val_error=0.2268, val_accuracy=0.9449
# 16/20, error=0.2262, accuracy=0.9399, val_error=0.228, val_accuracy=0.9439
# 17/20, error=0.2252, accuracy=0.9402, val_error=0.2293, val_accuracy=0.9439
# 18/20, error=0.2243, accuracy=0.9402, val_error=0.2307, val_accuracy=0.9449
# 19/20, error=0.2235, accuracy=0.9404, val_error=0.2321, val_accuracy=0.9449
# 20/20, error=0.2228, accuracy=0.9405, val_error=0.2336, val_accuracy=0.9459
# Layers : 2
# 1/20, error=0.3872, accuracy=0.9102, val_error=0.264, val_accuracy=0.9409
# 2/20, error=0.2955, accuracy=0.9266, val_error=0.2259, val_accuracy=0.9419
# 3/20, error=0.2724, accuracy=0.9288, val_error=0.2201, val_accuracy=0.9419
# 4/20, error=0.2588, accuracy=0.9316, val_error=0.2185, val_accuracy=0.9429
# 5/20, error=0.2506, accuracy=0.9341, val_error=0.217, val_accuracy=0.9459
# 6/20, error=0.2452, accuracy=0.9354, val_error=0.2169, val_accuracy=0.9429
# 7/20, error=0.2412, accuracy=0.9377, val_error=0.2177, val_accuracy=0.9409
# 8/20, error=0.238, accuracy=0.9375, val_error=0.219, val_accuracy=0.9399
# 9/20, error=0.2354, accuracy=0.9384, val_error=0.2206, val_accuracy=0.9419
# 10/20, error=0.2332, accuracy=0.9396, val_error=0.2225, val_accuracy=0.9399
# 11/20, error=0.2314, accuracy=0.9397, val_error=0.2244, val_accuracy=0.9429
# 12/20, error=0.2297, accuracy=0.9399, val_error=0.2262, val_accuracy=0.9419
# 13/20, error=0.2282, accuracy=0.9397, val_error=0.228, val_accuracy=0.9419
# 14/20, error=0.2269, accuracy=0.9405, val_error=0.2297, val_accuracy=0.9429
# 15/20, error=0.2256, accuracy=0.9405, val_error=0.2313, val_accuracy=0.9429
# 16/20, error=0.2245, accuracy=0.9405, val_error=0.2327, val_accuracy=0.9429
# 17/20, error=0.2235, accuracy=0.941, val_error=0.2341, val_accuracy=0.9429
# 18/20, error=0.2226, accuracy=0.9415, val_error=0.2353, val_accuracy=0.9419
# 19/20, error=0.2216, accuracy=0.9414, val_error=0.2365, val_accuracy=0.9449
# 20/20, error=0.2208, accuracy=0.9414, val_error=0.2377, val_accuracy=0.9449
# Test Accuracy =  0.9473571428571429
# Test Loss =  0.05114363895819381
# Balanced dataset shape: (10414, 784), (10414,)
# Balanced dataset shape: (1048, 784), (1048,)
# Layers : 1
# 1/20, error=0.4595, accuracy=0.8943, val_error=0.565, val_accuracy=0.8578
# 2/20, error=0.3432, accuracy=0.9143, val_error=0.53, val_accuracy=0.8578
# 3/20, error=0.3205, accuracy=0.9169, val_error=0.4877, val_accuracy=0.8674
# 4/20, error=0.3094, accuracy=0.9191, val_error=0.4797, val_accuracy=0.8731
# 5/20, error=0.3014, accuracy=0.9205, val_error=0.4762, val_accuracy=0.876
# 6/20, error=0.2953, accuracy=0.9223, val_error=0.4713, val_accuracy=0.876
# 7/20, error=0.2907, accuracy=0.9233, val_error=0.4707, val_accuracy=0.8807
# 8/20, error=0.2872, accuracy=0.9239, val_error=0.4741, val_accuracy=0.8798
# 9/20, error=0.2844, accuracy=0.9255, val_error=0.4787, val_accuracy=0.8807
# 10/20, error=0.2821, accuracy=0.9256, val_error=0.4835, val_accuracy=0.8807
# 11/20, error=0.2801, accuracy=0.9258, val_error=0.4884, val_accuracy=0.8788
# 12/20, error=0.2784, accuracy=0.9256, val_error=0.4932, val_accuracy=0.8769
# 13/20, error=0.277, accuracy=0.9254, val_error=0.4979, val_accuracy=0.876
# 14/20, error=0.2757, accuracy=0.9256, val_error=0.5023, val_accuracy=0.876
# 15/20, error=0.2746, accuracy=0.9255, val_error=0.5063, val_accuracy=0.876
# 16/20, error=0.2736, accuracy=0.9266, val_error=0.5099, val_accuracy=0.876
# 17/20, error=0.2727, accuracy=0.9273, val_error=0.513, val_accuracy=0.874
# 18/20, error=0.2719, accuracy=0.9278, val_error=0.5159, val_accuracy=0.8731
# 19/20, error=0.2712, accuracy=0.9278, val_error=0.5185, val_accuracy=0.874
# 20/20, error=0.2706, accuracy=0.9277, val_error=0.521, val_accuracy=0.874
# 1/20, error=0.0493, accuracy=0.9411, val_error=0.0119, val_accuracy=0.9857
# 2/20, error=0.0072, accuracy=0.9913, val_error=0.0041, val_accuracy=0.9943
# 3/20, error=0.0026, accuracy=0.9967, val_error=0.0022, val_accuracy=0.9962
# 4/20, error=0.0011, accuracy=0.9986, val_error=0.0013, val_accuracy=0.9981
# 5/20, error=0.0005, accuracy=0.9994, val_error=0.0009, val_accuracy=0.999
# 6/20, error=0.0003, accuracy=0.9997, val_error=0.0005, val_accuracy=1.0
# 7/20, error=0.0001, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 10/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.4418, accuracy=0.8957, val_error=0.5993, val_accuracy=0.8635
# 2/20, error=0.3412, accuracy=0.9172, val_error=0.4964, val_accuracy=0.8721
# 3/20, error=0.3233, accuracy=0.9195, val_error=0.4524, val_accuracy=0.8788
# 4/20, error=0.3134, accuracy=0.9197, val_error=0.4458, val_accuracy=0.8817
# 5/20, error=0.3063, accuracy=0.9202, val_error=0.4419, val_accuracy=0.8798
# 6/20, error=0.3009, accuracy=0.9216, val_error=0.439, val_accuracy=0.8845
# 7/20, error=0.2964, accuracy=0.9218, val_error=0.4386, val_accuracy=0.8884
# 8/20, error=0.2926, accuracy=0.9226, val_error=0.4412, val_accuracy=0.8912
# 9/20, error=0.2892, accuracy=0.9233, val_error=0.4447, val_accuracy=0.8903
# 10/20, error=0.2865, accuracy=0.924, val_error=0.4487, val_accuracy=0.8912
# 11/20, error=0.2841, accuracy=0.9249, val_error=0.4529, val_accuracy=0.8893
# 12/20, error=0.282, accuracy=0.9256, val_error=0.4573, val_accuracy=0.8865
# 13/20, error=0.2801, accuracy=0.9258, val_error=0.462, val_accuracy=0.8845
# 14/20, error=0.2786, accuracy=0.9257, val_error=0.4668, val_accuracy=0.8836
# 15/20, error=0.2772, accuracy=0.9263, val_error=0.4716, val_accuracy=0.8817
# 16/20, error=0.276, accuracy=0.9269, val_error=0.4762, val_accuracy=0.8798
# 17/20, error=0.275, accuracy=0.9272, val_error=0.4804, val_accuracy=0.8788
# 18/20, error=0.2741, accuracy=0.9276, val_error=0.4843, val_accuracy=0.8779
# 19/20, error=0.2732, accuracy=0.9279, val_error=0.4881, val_accuracy=0.8779
# 20/20, error=0.2725, accuracy=0.9281, val_error=0.4918, val_accuracy=0.8779
# Layers : 2
# 1/20, error=0.4451, accuracy=0.8938, val_error=0.4257, val_accuracy=0.8969
# 2/20, error=0.3397, accuracy=0.9146, val_error=0.4119, val_accuracy=0.895
# 3/20, error=0.3163, accuracy=0.9192, val_error=0.4133, val_accuracy=0.8912
# 4/20, error=0.3051, accuracy=0.9219, val_error=0.4285, val_accuracy=0.8865
# 5/20, error=0.2979, accuracy=0.9227, val_error=0.4506, val_accuracy=0.8798
# 6/20, error=0.293, accuracy=0.9228, val_error=0.4659, val_accuracy=0.876
# 7/20, error=0.2898, accuracy=0.9226, val_error=0.4752, val_accuracy=0.8712
# 8/20, error=0.2869, accuracy=0.9233, val_error=0.4831, val_accuracy=0.8702
# 9/20, error=0.2844, accuracy=0.9234, val_error=0.4914, val_accuracy=0.8693
# 10/20, error=0.2823, accuracy=0.9245, val_error=0.5, val_accuracy=0.8674
# 11/20, error=0.2805, accuracy=0.9256, val_error=0.5085, val_accuracy=0.8683
# 12/20, error=0.2789, accuracy=0.9259, val_error=0.5162, val_accuracy=0.8674
# 13/20, error=0.2775, accuracy=0.9268, val_error=0.5229, val_accuracy=0.8645
# 14/20, error=0.2763, accuracy=0.9268, val_error=0.5283, val_accuracy=0.8655
# 15/20, error=0.2753, accuracy=0.9269, val_error=0.5326, val_accuracy=0.8664
# 16/20, error=0.2744, accuracy=0.9267, val_error=0.5359, val_accuracy=0.8664
# 17/20, error=0.2737, accuracy=0.9273, val_error=0.5383, val_accuracy=0.8655
# 18/20, error=0.273, accuracy=0.928, val_error=0.5401, val_accuracy=0.8664
# 19/20, error=0.2724, accuracy=0.9279, val_error=0.5415, val_accuracy=0.8645
# 20/20, error=0.2719, accuracy=0.9281, val_error=0.5427, val_accuracy=0.8655
# Test Accuracy =  0.8228571428571428
# Test Loss =  0.17239904157954486
# Balanced dataset shape: (9802, 784), (9802,)
# Balanced dataset shape: (1078, 784), (1078,)
# Layers : 1
# 1/20, error=0.2837, accuracy=0.9328, val_error=0.227, val_accuracy=0.9406
# 2/20, error=0.1803, accuracy=0.9534, val_error=0.1995, val_accuracy=0.9453
# 3/20, error=0.16, accuracy=0.9581, val_error=0.188, val_accuracy=0.949
# 4/20, error=0.1474, accuracy=0.9608, val_error=0.1844, val_accuracy=0.9499
# 5/20, error=0.1389, accuracy=0.9618, val_error=0.1849, val_accuracy=0.9536
# 6/20, error=0.1326, accuracy=0.9628, val_error=0.187, val_accuracy=0.9545
# 7/20, error=0.1277, accuracy=0.9654, val_error=0.1898, val_accuracy=0.9527
# 8/20, error=0.1239, accuracy=0.9663, val_error=0.1922, val_accuracy=0.9527
# 9/20, error=0.1208, accuracy=0.9665, val_error=0.1944, val_accuracy=0.9527
# 10/20, error=0.118, accuracy=0.9661, val_error=0.1965, val_accuracy=0.9508
# 11/20, error=0.1156, accuracy=0.9667, val_error=0.1983, val_accuracy=0.9518
# 12/20, error=0.1136, accuracy=0.9669, val_error=0.1996, val_accuracy=0.9536
# 13/20, error=0.1118, accuracy=0.9678, val_error=0.2007, val_accuracy=0.9536
# 14/20, error=0.1102, accuracy=0.9679, val_error=0.2016, val_accuracy=0.9555
# 15/20, error=0.1088, accuracy=0.9684, val_error=0.2025, val_accuracy=0.9545
# 16/20, error=0.1075, accuracy=0.9687, val_error=0.2033, val_accuracy=0.9545
# 17/20, error=0.1063, accuracy=0.9691, val_error=0.2042, val_accuracy=0.9545
# 18/20, error=0.1051, accuracy=0.9687, val_error=0.2051, val_accuracy=0.9545
# 19/20, error=0.104, accuracy=0.9693, val_error=0.206, val_accuracy=0.9555
# 20/20, error=0.103, accuracy=0.9698, val_error=0.2069, val_accuracy=0.9564
# 1/20, error=0.0577, accuracy=0.9309, val_error=0.0108, val_accuracy=0.9861
# 2/20, error=0.0079, accuracy=0.9901, val_error=0.0044, val_accuracy=0.9944
# 3/20, error=0.0036, accuracy=0.9957, val_error=0.0023, val_accuracy=0.9963
# 4/20, error=0.0019, accuracy=0.9977, val_error=0.0017, val_accuracy=0.9972
# 5/20, error=0.0011, accuracy=0.9988, val_error=0.0014, val_accuracy=0.9972
# 6/20, error=0.0006, accuracy=0.9994, val_error=0.0012, val_accuracy=0.9972
# 7/20, error=0.0004, accuracy=0.9997, val_error=0.0011, val_accuracy=0.9991
# 8/20, error=0.0003, accuracy=0.9997, val_error=0.001, val_accuracy=0.9991
# 9/20, error=0.0002, accuracy=0.9998, val_error=0.0009, val_accuracy=0.9991
# 10/20, error=0.0002, accuracy=0.9998, val_error=0.0008, val_accuracy=0.9991
# 11/20, error=0.0001, accuracy=0.9999, val_error=0.0007, val_accuracy=0.9991
# 12/20, error=0.0001, accuracy=1.0, val_error=0.0007, val_accuracy=0.9991
# 13/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 14/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 15/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 16/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 17/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 18/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 19/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# 20/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9991
# Layers : 2
# 1/20, error=0.2597, accuracy=0.9324, val_error=0.2202, val_accuracy=0.9499
# 2/20, error=0.1695, accuracy=0.9576, val_error=0.2069, val_accuracy=0.9508
# 3/20, error=0.1497, accuracy=0.9609, val_error=0.2081, val_accuracy=0.9481
# 4/20, error=0.1387, accuracy=0.9626, val_error=0.2078, val_accuracy=0.949
# 5/20, error=0.1313, accuracy=0.9636, val_error=0.2085, val_accuracy=0.949
# 6/20, error=0.1255, accuracy=0.9651, val_error=0.2085, val_accuracy=0.9481
# 7/20, error=0.1212, accuracy=0.9668, val_error=0.2073, val_accuracy=0.949
# 8/20, error=0.1179, accuracy=0.9674, val_error=0.2053, val_accuracy=0.9499
# 9/20, error=0.1153, accuracy=0.9678, val_error=0.203, val_accuracy=0.9499
# 10/20, error=0.1133, accuracy=0.9681, val_error=0.2009, val_accuracy=0.9508
# 11/20, error=0.1115, accuracy=0.9682, val_error=0.1994, val_accuracy=0.9545
# 12/20, error=0.11, accuracy=0.9685, val_error=0.1984, val_accuracy=0.9555
# 13/20, error=0.1086, accuracy=0.9687, val_error=0.198, val_accuracy=0.9583
# 14/20, error=0.1073, accuracy=0.9692, val_error=0.1981, val_accuracy=0.9573
# 15/20, error=0.1062, accuracy=0.9692, val_error=0.1986, val_accuracy=0.9573
# 16/20, error=0.1051, accuracy=0.9696, val_error=0.1995, val_accuracy=0.9564
# 17/20, error=0.1041, accuracy=0.9694, val_error=0.2006, val_accuracy=0.9583
# 18/20, error=0.1031, accuracy=0.9697, val_error=0.2019, val_accuracy=0.9573
# 19/20, error=0.1022, accuracy=0.97, val_error=0.2033, val_accuracy=0.9573
# 20/20, error=0.1013, accuracy=0.9702, val_error=0.2047, val_accuracy=0.9573
# Layers : 2
# 1/20, error=0.2682, accuracy=0.9351, val_error=0.2625, val_accuracy=0.9295
# 2/20, error=0.1811, accuracy=0.9554, val_error=0.2127, val_accuracy=0.9481
# 3/20, error=0.1603, accuracy=0.958, val_error=0.2018, val_accuracy=0.9518
# 4/20, error=0.1468, accuracy=0.9611, val_error=0.1948, val_accuracy=0.9518
# 5/20, error=0.1379, accuracy=0.9637, val_error=0.1937, val_accuracy=0.9518
# 6/20, error=0.1317, accuracy=0.9649, val_error=0.194, val_accuracy=0.9508
# 7/20, error=0.127, accuracy=0.9655, val_error=0.1956, val_accuracy=0.9508
# 8/20, error=0.1231, accuracy=0.967, val_error=0.1978, val_accuracy=0.9527
# 9/20, error=0.1198, accuracy=0.9667, val_error=0.1996, val_accuracy=0.9508
# 10/20, error=0.1169, accuracy=0.967, val_error=0.2006, val_accuracy=0.9499
# 11/20, error=0.1144, accuracy=0.9684, val_error=0.2009, val_accuracy=0.9508
# 12/20, error=0.1123, accuracy=0.9685, val_error=0.201, val_accuracy=0.9508
# 13/20, error=0.1105, accuracy=0.9687, val_error=0.2013, val_accuracy=0.9508
# 14/20, error=0.1089, accuracy=0.9692, val_error=0.2019, val_accuracy=0.9508
# 15/20, error=0.1076, accuracy=0.9695, val_error=0.2026, val_accuracy=0.9508
# 16/20, error=0.1063, accuracy=0.9696, val_error=0.2035, val_accuracy=0.9499
# 17/20, error=0.1052, accuracy=0.9698, val_error=0.2045, val_accuracy=0.9499
# 18/20, error=0.1042, accuracy=0.9699, val_error=0.2055, val_accuracy=0.949
# 19/20, error=0.1033, accuracy=0.9703, val_error=0.2066, val_accuracy=0.949
# 20/20, error=0.1024, accuracy=0.9706, val_error=0.2076, val_accuracy=0.949
# Test Accuracy =  0.9722142857142857
# Test Loss =  0.027064803236303756
# Balanced dataset shape: (9260, 784), (9260,)
# Balanced dataset shape: (896, 784), (896,)
# Layers : 1
# 1/20, error=0.5182, accuracy=0.8694, val_error=0.4365, val_accuracy=0.8884
# 2/20, error=0.3823, accuracy=0.9016, val_error=0.4139, val_accuracy=0.8951
# 3/20, error=0.3536, accuracy=0.907, val_error=0.4072, val_accuracy=0.8996
# 4/20, error=0.3379, accuracy=0.9094, val_error=0.4115, val_accuracy=0.9029
# 5/20, error=0.3277, accuracy=0.9124, val_error=0.4195, val_accuracy=0.9018
# 6/20, error=0.3212, accuracy=0.913, val_error=0.4301, val_accuracy=0.9018
# 7/20, error=0.3166, accuracy=0.9134, val_error=0.4426, val_accuracy=0.8996
# 8/20, error=0.313, accuracy=0.9156, val_error=0.4554, val_accuracy=0.8984
# 9/20, error=0.3101, accuracy=0.9171, val_error=0.4671, val_accuracy=0.8951
# 10/20, error=0.3078, accuracy=0.9175, val_error=0.4777, val_accuracy=0.8951
# 11/20, error=0.306, accuracy=0.9177, val_error=0.4871, val_accuracy=0.894
# 12/20, error=0.3044, accuracy=0.9177, val_error=0.4955, val_accuracy=0.8951
# 13/20, error=0.3032, accuracy=0.9183, val_error=0.5028, val_accuracy=0.8973
# 14/20, error=0.3021, accuracy=0.918, val_error=0.5085, val_accuracy=0.8984
# 15/20, error=0.3011, accuracy=0.9184, val_error=0.5134, val_accuracy=0.8984
# 16/20, error=0.3003, accuracy=0.9186, val_error=0.5176, val_accuracy=0.8996
# 17/20, error=0.2995, accuracy=0.9188, val_error=0.5213, val_accuracy=0.8996
# 18/20, error=0.2989, accuracy=0.919, val_error=0.5243, val_accuracy=0.8996
# 19/20, error=0.2983, accuracy=0.9193, val_error=0.5266, val_accuracy=0.8996
# 20/20, error=0.2978, accuracy=0.9202, val_error=0.5283, val_accuracy=0.8984
# 1/20, error=0.053, accuracy=0.9354, val_error=0.01, val_accuracy=0.9866
# 2/20, error=0.0047, accuracy=0.9937, val_error=0.0028, val_accuracy=0.9955
# 3/20, error=0.0015, accuracy=0.9981, val_error=0.0013, val_accuracy=0.9978
# 4/20, error=0.0007, accuracy=0.9994, val_error=0.0011, val_accuracy=0.9989
# 5/20, error=0.0005, accuracy=0.9995, val_error=0.0008, val_accuracy=0.9989
# 6/20, error=0.0003, accuracy=0.9998, val_error=0.0006, val_accuracy=0.9989
# 7/20, error=0.0003, accuracy=0.9998, val_error=0.0005, val_accuracy=1.0
# 8/20, error=0.0002, accuracy=0.9998, val_error=0.0004, val_accuracy=1.0
# 9/20, error=0.0002, accuracy=0.9999, val_error=0.0004, val_accuracy=1.0
# 10/20, error=0.0002, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 11/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 12/20, error=0.0001, accuracy=0.9999, val_error=0.0003, val_accuracy=1.0
# 13/20, error=0.0001, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0004, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0004, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.5049, accuracy=0.8731, val_error=0.4431, val_accuracy=0.9029
# 2/20, error=0.3823, accuracy=0.8999, val_error=0.4542, val_accuracy=0.8951
# 3/20, error=0.3549, accuracy=0.9066, val_error=0.4753, val_accuracy=0.8984
# 4/20, error=0.3418, accuracy=0.9092, val_error=0.4784, val_accuracy=0.8962
# 5/20, error=0.3334, accuracy=0.9121, val_error=0.4809, val_accuracy=0.8951
# 6/20, error=0.3274, accuracy=0.9126, val_error=0.4834, val_accuracy=0.8951
# 7/20, error=0.3227, accuracy=0.9133, val_error=0.4873, val_accuracy=0.8973
# 8/20, error=0.3187, accuracy=0.914, val_error=0.4934, val_accuracy=0.8973
# 9/20, error=0.3154, accuracy=0.9149, val_error=0.5011, val_accuracy=0.8973
# 10/20, error=0.3126, accuracy=0.9149, val_error=0.5097, val_accuracy=0.8962
# 11/20, error=0.3102, accuracy=0.915, val_error=0.5188, val_accuracy=0.894
# 12/20, error=0.3082, accuracy=0.9161, val_error=0.5279, val_accuracy=0.894
# 13/20, error=0.3065, accuracy=0.9166, val_error=0.5361, val_accuracy=0.894
# 14/20, error=0.3051, accuracy=0.9171, val_error=0.543, val_accuracy=0.8929
# 15/20, error=0.3039, accuracy=0.9173, val_error=0.5489, val_accuracy=0.8929
# 16/20, error=0.3028, accuracy=0.9175, val_error=0.5538, val_accuracy=0.8929
# 17/20, error=0.3019, accuracy=0.9181, val_error=0.5576, val_accuracy=0.8906
# 18/20, error=0.3011, accuracy=0.9181, val_error=0.5601, val_accuracy=0.8906
# 19/20, error=0.3004, accuracy=0.9183, val_error=0.5613, val_accuracy=0.8906
# 20/20, error=0.2999, accuracy=0.918, val_error=0.5615, val_accuracy=0.8906
# Layers : 2
# 1/20, error=0.533, accuracy=0.8677, val_error=0.4506, val_accuracy=0.8917
# 2/20, error=0.3779, accuracy=0.8995, val_error=0.4451, val_accuracy=0.8951
# 3/20, error=0.3488, accuracy=0.907, val_error=0.4367, val_accuracy=0.8996
# 4/20, error=0.334, accuracy=0.9103, val_error=0.4375, val_accuracy=0.9018
# 5/20, error=0.3258, accuracy=0.9131, val_error=0.4446, val_accuracy=0.904
# 6/20, error=0.32, accuracy=0.9134, val_error=0.4552, val_accuracy=0.9007
# 7/20, error=0.3155, accuracy=0.9148, val_error=0.4673, val_accuracy=0.8996
# 8/20, error=0.3118, accuracy=0.915, val_error=0.4771, val_accuracy=0.8984
# 9/20, error=0.3089, accuracy=0.9154, val_error=0.486, val_accuracy=0.8962
# 10/20, error=0.3065, accuracy=0.9153, val_error=0.4949, val_accuracy=0.8973
# 11/20, error=0.3046, accuracy=0.9157, val_error=0.5031, val_accuracy=0.8984
# 12/20, error=0.3031, accuracy=0.9165, val_error=0.5104, val_accuracy=0.8984
# 13/20, error=0.3018, accuracy=0.9176, val_error=0.5166, val_accuracy=0.8984
# 14/20, error=0.3008, accuracy=0.9183, val_error=0.522, val_accuracy=0.8973
# 15/20, error=0.2999, accuracy=0.918, val_error=0.5257, val_accuracy=0.8984
# 16/20, error=0.2991, accuracy=0.9178, val_error=0.5283, val_accuracy=0.8973
# 17/20, error=0.2985, accuracy=0.9184, val_error=0.5303, val_accuracy=0.8984
# 18/20, error=0.2979, accuracy=0.9185, val_error=0.5322, val_accuracy=0.8984
# 19/20, error=0.2973, accuracy=0.9189, val_error=0.534, val_accuracy=0.8984
# 20/20, error=0.2968, accuracy=0.9199, val_error=0.5358, val_accuracy=0.8984
# Test Accuracy =  0.8672142857142857
# Test Loss =  0.1299379313578792
# Balanced dataset shape: (10050, 784), (10050,)
# Balanced dataset shape: (968, 784), (968,)
# Layers : 1
# 1/20, error=0.2042, accuracy=0.9526, val_error=0.2348, val_accuracy=0.9597
# 2/20, error=0.1393, accuracy=0.9667, val_error=0.2149, val_accuracy=0.9618
# 3/20, error=0.1235, accuracy=0.9691, val_error=0.2199, val_accuracy=0.9597
# 4/20, error=0.1144, accuracy=0.9715, val_error=0.2239, val_accuracy=0.9607
# 5/20, error=0.1091, accuracy=0.9723, val_error=0.2247, val_accuracy=0.9597
# 6/20, error=0.1046, accuracy=0.9736, val_error=0.2259, val_accuracy=0.9607
# 7/20, error=0.1008, accuracy=0.9745, val_error=0.2275, val_accuracy=0.9566
# 8/20, error=0.0978, accuracy=0.9753, val_error=0.2292, val_accuracy=0.9556
# 9/20, error=0.0952, accuracy=0.975, val_error=0.231, val_accuracy=0.9556
# 10/20, error=0.0931, accuracy=0.9752, val_error=0.2333, val_accuracy=0.9566
# 11/20, error=0.0911, accuracy=0.9761, val_error=0.2361, val_accuracy=0.9556
# 12/20, error=0.0894, accuracy=0.9767, val_error=0.2391, val_accuracy=0.9535
# 13/20, error=0.0878, accuracy=0.9767, val_error=0.2422, val_accuracy=0.9535
# 14/20, error=0.0863, accuracy=0.9772, val_error=0.245, val_accuracy=0.9535
# 15/20, error=0.085, accuracy=0.9773, val_error=0.2477, val_accuracy=0.9535
# 16/20, error=0.0839, accuracy=0.9775, val_error=0.25, val_accuracy=0.9514
# 17/20, error=0.0829, accuracy=0.9771, val_error=0.252, val_accuracy=0.9504
# 18/20, error=0.0819, accuracy=0.9774, val_error=0.2537, val_accuracy=0.9504
# 19/20, error=0.0811, accuracy=0.9777, val_error=0.2551, val_accuracy=0.9494
# 20/20, error=0.0803, accuracy=0.9781, val_error=0.2564, val_accuracy=0.9494
# 1/20, error=0.0258, accuracy=0.9673, val_error=0.0184, val_accuracy=0.9762
# 2/20, error=0.0056, accuracy=0.9929, val_error=0.0122, val_accuracy=0.9845
# 3/20, error=0.0028, accuracy=0.9964, val_error=0.0043, val_accuracy=0.9948
# 4/20, error=0.0014, accuracy=0.9984, val_error=0.0014, val_accuracy=0.999
# 5/20, error=0.0008, accuracy=0.9994, val_error=0.0012, val_accuracy=0.999
# 6/20, error=0.0007, accuracy=0.9994, val_error=0.0013, val_accuracy=0.999
# 7/20, error=0.0006, accuracy=0.9994, val_error=0.0013, val_accuracy=0.999
# 8/20, error=0.0004, accuracy=0.9995, val_error=0.0013, val_accuracy=0.999
# 9/20, error=0.0003, accuracy=0.9998, val_error=0.0013, val_accuracy=0.999
# 10/20, error=0.0003, accuracy=0.9998, val_error=0.0013, val_accuracy=0.999
# 11/20, error=0.0002, accuracy=0.9998, val_error=0.0012, val_accuracy=0.999
# 12/20, error=0.0001, accuracy=1.0, val_error=0.0011, val_accuracy=0.999
# 13/20, error=0.0001, accuracy=1.0, val_error=0.0011, val_accuracy=0.999
# 14/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 15/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 16/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 17/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 18/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 19/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# 20/20, error=0.0, accuracy=1.0, val_error=0.001, val_accuracy=0.999
# Layers : 2
# 1/20, error=0.2072, accuracy=0.9532, val_error=0.1986, val_accuracy=0.9587
# 2/20, error=0.1309, accuracy=0.9672, val_error=0.2035, val_accuracy=0.9607
# 3/20, error=0.1146, accuracy=0.9693, val_error=0.1982, val_accuracy=0.9576
# 4/20, error=0.1069, accuracy=0.9724, val_error=0.1998, val_accuracy=0.9545
# 5/20, error=0.1023, accuracy=0.9732, val_error=0.2036, val_accuracy=0.9545
# 6/20, error=0.0986, accuracy=0.9746, val_error=0.2082, val_accuracy=0.9535
# 7/20, error=0.0957, accuracy=0.9753, val_error=0.2123, val_accuracy=0.9535
# 8/20, error=0.0933, accuracy=0.9756, val_error=0.2158, val_accuracy=0.9535
# 9/20, error=0.0913, accuracy=0.9759, val_error=0.2187, val_accuracy=0.9535
# 10/20, error=0.0896, accuracy=0.9763, val_error=0.2211, val_accuracy=0.9525
# 11/20, error=0.0881, accuracy=0.9765, val_error=0.2232, val_accuracy=0.9525
# 12/20, error=0.0868, accuracy=0.9769, val_error=0.2252, val_accuracy=0.9525
# 13/20, error=0.0856, accuracy=0.9774, val_error=0.2274, val_accuracy=0.9535
# 14/20, error=0.0845, accuracy=0.9772, val_error=0.2295, val_accuracy=0.9535
# 15/20, error=0.0835, accuracy=0.9775, val_error=0.2318, val_accuracy=0.9535
# 16/20, error=0.0825, accuracy=0.9773, val_error=0.234, val_accuracy=0.9545
# 17/20, error=0.0815, accuracy=0.9776, val_error=0.2361, val_accuracy=0.9535
# 18/20, error=0.0807, accuracy=0.9779, val_error=0.2382, val_accuracy=0.9535
# 19/20, error=0.0799, accuracy=0.9782, val_error=0.2402, val_accuracy=0.9525
# 20/20, error=0.0791, accuracy=0.9784, val_error=0.2421, val_accuracy=0.9525
# Layers : 2
# 1/20, error=0.1967, accuracy=0.9524, val_error=0.2407, val_accuracy=0.9566
# 2/20, error=0.1344, accuracy=0.9676, val_error=0.2191, val_accuracy=0.9587
# 3/20, error=0.1216, accuracy=0.9699, val_error=0.2151, val_accuracy=0.9566
# 4/20, error=0.1122, accuracy=0.9716, val_error=0.214, val_accuracy=0.9576
# 5/20, error=0.1058, accuracy=0.9728, val_error=0.217, val_accuracy=0.9566
# 6/20, error=0.1011, accuracy=0.9735, val_error=0.2201, val_accuracy=0.9566
# 7/20, error=0.0975, accuracy=0.974, val_error=0.219, val_accuracy=0.9566
# 8/20, error=0.0947, accuracy=0.9745, val_error=0.2167, val_accuracy=0.9566
# 9/20, error=0.0925, accuracy=0.9746, val_error=0.2173, val_accuracy=0.9545
# 10/20, error=0.0907, accuracy=0.9754, val_error=0.2194, val_accuracy=0.9545
# 11/20, error=0.0889, accuracy=0.9758, val_error=0.2217, val_accuracy=0.9535
# 12/20, error=0.0873, accuracy=0.9765, val_error=0.2241, val_accuracy=0.9535
# 13/20, error=0.0858, accuracy=0.9768, val_error=0.2266, val_accuracy=0.9535
# 14/20, error=0.0844, accuracy=0.9773, val_error=0.2293, val_accuracy=0.9535
# 15/20, error=0.0831, accuracy=0.9773, val_error=0.2322, val_accuracy=0.9535
# 16/20, error=0.082, accuracy=0.9774, val_error=0.2351, val_accuracy=0.9535
# 17/20, error=0.0809, accuracy=0.9776, val_error=0.2379, val_accuracy=0.9535
# 18/20, error=0.08, accuracy=0.9773, val_error=0.2404, val_accuracy=0.9535
# 19/20, error=0.0792, accuracy=0.9772, val_error=0.2428, val_accuracy=0.9525
# 20/20, error=0.0784, accuracy=0.9773, val_error=0.245, val_accuracy=0.9535
# Test Accuracy =  0.9643571428571428
# Test Loss =  0.03454770202840275
# Balanced dataset shape: (10650, 784), (10650,)
# Balanced dataset shape: (998, 784), (998,)
# Layers : 1
# 1/20, error=0.246, accuracy=0.9414, val_error=0.1789, val_accuracy=0.9599
# 2/20, error=0.1739, accuracy=0.9551, val_error=0.1593, val_accuracy=0.9629
# 3/20, error=0.1595, accuracy=0.9577, val_error=0.1419, val_accuracy=0.9689
# 4/20, error=0.1518, accuracy=0.9585, val_error=0.1403, val_accuracy=0.9679
# 5/20, error=0.1467, accuracy=0.9583, val_error=0.1411, val_accuracy=0.9669
# 6/20, error=0.1429, accuracy=0.9589, val_error=0.1419, val_accuracy=0.9669
# 7/20, error=0.1398, accuracy=0.9595, val_error=0.1424, val_accuracy=0.9669
# 8/20, error=0.1372, accuracy=0.9604, val_error=0.1426, val_accuracy=0.9669
# 9/20, error=0.1348, accuracy=0.9612, val_error=0.1429, val_accuracy=0.9669
# 10/20, error=0.1328, accuracy=0.9618, val_error=0.1431, val_accuracy=0.9659
# 11/20, error=0.131, accuracy=0.9618, val_error=0.1434, val_accuracy=0.9659
# 12/20, error=0.1295, accuracy=0.9623, val_error=0.1438, val_accuracy=0.9669
# 13/20, error=0.1282, accuracy=0.9625, val_error=0.1441, val_accuracy=0.9669
# 14/20, error=0.127, accuracy=0.9631, val_error=0.1444, val_accuracy=0.9659
# 15/20, error=0.126, accuracy=0.9629, val_error=0.1448, val_accuracy=0.9659
# 16/20, error=0.1251, accuracy=0.963, val_error=0.1451, val_accuracy=0.9669
# 17/20, error=0.1242, accuracy=0.9628, val_error=0.1454, val_accuracy=0.9669
# 18/20, error=0.1235, accuracy=0.963, val_error=0.1456, val_accuracy=0.9669
# 19/20, error=0.1228, accuracy=0.9634, val_error=0.1458, val_accuracy=0.9659
# 20/20, error=0.1222, accuracy=0.9634, val_error=0.1458, val_accuracy=0.9659
# 1/20, error=0.0388, accuracy=0.9531, val_error=0.0056, val_accuracy=0.992
# 2/20, error=0.006, accuracy=0.9921, val_error=0.0021, val_accuracy=0.998
# 3/20, error=0.0026, accuracy=0.9971, val_error=0.0013, val_accuracy=0.998
# 4/20, error=0.0014, accuracy=0.9984, val_error=0.0008, val_accuracy=0.999
# 5/20, error=0.0008, accuracy=0.9992, val_error=0.0004, val_accuracy=1.0
# 6/20, error=0.0006, accuracy=0.9994, val_error=0.0003, val_accuracy=1.0
# 7/20, error=0.0004, accuracy=0.9995, val_error=0.0004, val_accuracy=1.0
# 8/20, error=0.0003, accuracy=0.9997, val_error=0.0002, val_accuracy=1.0
# 9/20, error=0.0002, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 10/20, error=0.0001, accuracy=0.9999, val_error=0.0002, val_accuracy=1.0
# 11/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 12/20, error=0.0001, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.2554, accuracy=0.9388, val_error=0.1705, val_accuracy=0.9619
# 2/20, error=0.1822, accuracy=0.9528, val_error=0.1569, val_accuracy=0.9629
# 3/20, error=0.1643, accuracy=0.956, val_error=0.147, val_accuracy=0.9649
# 4/20, error=0.1544, accuracy=0.9577, val_error=0.139, val_accuracy=0.9639
# 5/20, error=0.1477, accuracy=0.9588, val_error=0.1346, val_accuracy=0.9599
# 6/20, error=0.1431, accuracy=0.9592, val_error=0.1323, val_accuracy=0.9629
# 7/20, error=0.1397, accuracy=0.9595, val_error=0.1308, val_accuracy=0.9629
# 8/20, error=0.1368, accuracy=0.9598, val_error=0.1297, val_accuracy=0.9639
# 9/20, error=0.1344, accuracy=0.9595, val_error=0.1291, val_accuracy=0.9639
# 10/20, error=0.1322, accuracy=0.9603, val_error=0.1286, val_accuracy=0.9649
# 11/20, error=0.1304, accuracy=0.9605, val_error=0.1284, val_accuracy=0.9649
# 12/20, error=0.1288, accuracy=0.9597, val_error=0.1282, val_accuracy=0.9659
# 13/20, error=0.1274, accuracy=0.9608, val_error=0.1281, val_accuracy=0.9659
# 14/20, error=0.1262, accuracy=0.9615, val_error=0.128, val_accuracy=0.9659
# 15/20, error=0.1251, accuracy=0.9618, val_error=0.1279, val_accuracy=0.9659
# 16/20, error=0.1241, accuracy=0.9622, val_error=0.1279, val_accuracy=0.9669
# 17/20, error=0.1233, accuracy=0.9624, val_error=0.128, val_accuracy=0.9659
# 18/20, error=0.1224, accuracy=0.9627, val_error=0.128, val_accuracy=0.9649
# 19/20, error=0.1217, accuracy=0.9631, val_error=0.128, val_accuracy=0.9649
# 20/20, error=0.121, accuracy=0.9636, val_error=0.1281, val_accuracy=0.9649
# Layers : 2
# 1/20, error=0.25, accuracy=0.9412, val_error=0.1417, val_accuracy=0.9639
# 2/20, error=0.1713, accuracy=0.9557, val_error=0.1395, val_accuracy=0.9629
# 3/20, error=0.1575, accuracy=0.9574, val_error=0.1386, val_accuracy=0.9639
# 4/20, error=0.1499, accuracy=0.9589, val_error=0.1373, val_accuracy=0.9669
# 5/20, error=0.1452, accuracy=0.9594, val_error=0.1363, val_accuracy=0.9699
# 6/20, error=0.1419, accuracy=0.9604, val_error=0.1351, val_accuracy=0.9689
# 7/20, error=0.1391, accuracy=0.9608, val_error=0.1345, val_accuracy=0.9689
# 8/20, error=0.1368, accuracy=0.9608, val_error=0.1344, val_accuracy=0.9679
# 9/20, error=0.1347, accuracy=0.9607, val_error=0.1347, val_accuracy=0.9679
# 10/20, error=0.1329, accuracy=0.9608, val_error=0.135, val_accuracy=0.9689
# 11/20, error=0.1312, accuracy=0.9615, val_error=0.1353, val_accuracy=0.9679
# 12/20, error=0.1298, accuracy=0.9618, val_error=0.1355, val_accuracy=0.9689
# 13/20, error=0.1284, accuracy=0.9622, val_error=0.1358, val_accuracy=0.9689
# 14/20, error=0.1272, accuracy=0.9625, val_error=0.136, val_accuracy=0.9689
# 15/20, error=0.1262, accuracy=0.9629, val_error=0.1363, val_accuracy=0.9679
# 16/20, error=0.1252, accuracy=0.9633, val_error=0.1364, val_accuracy=0.9679
# 17/20, error=0.1243, accuracy=0.9634, val_error=0.1365, val_accuracy=0.9689
# 18/20, error=0.1235, accuracy=0.9633, val_error=0.1365, val_accuracy=0.9689
# 19/20, error=0.1228, accuracy=0.9635, val_error=0.1364, val_accuracy=0.9669
# 20/20, error=0.1221, accuracy=0.9636, val_error=0.1362, val_accuracy=0.9669
# Test Accuracy =  0.9521428571428572
# Test Loss =  0.04599217537619044
# Balanced dataset shape: (9928, 784), (9928,)
# Balanced dataset shape: (942, 784), (942,)
# Layers : 1
# 1/20, error=0.6282, accuracy=0.8425, val_error=0.6075, val_accuracy=0.8291
# 2/20, error=0.4682, accuracy=0.8745, val_error=0.5994, val_accuracy=0.8365
# 3/20, error=0.4498, accuracy=0.8798, val_error=0.611, val_accuracy=0.8418
# 4/20, error=0.4398, accuracy=0.8822, val_error=0.6101, val_accuracy=0.845
# 5/20, error=0.4333, accuracy=0.8835, val_error=0.6063, val_accuracy=0.8461
# 6/20, error=0.4291, accuracy=0.8848, val_error=0.6055, val_accuracy=0.8471
# 7/20, error=0.4261, accuracy=0.8854, val_error=0.607, val_accuracy=0.8482
# 8/20, error=0.4238, accuracy=0.8864, val_error=0.609, val_accuracy=0.8493
# 9/20, error=0.4218, accuracy=0.8869, val_error=0.6109, val_accuracy=0.8503
# 10/20, error=0.4202, accuracy=0.8875, val_error=0.6122, val_accuracy=0.8493
# 11/20, error=0.4188, accuracy=0.8878, val_error=0.6131, val_accuracy=0.8493
# 12/20, error=0.4177, accuracy=0.8884, val_error=0.614, val_accuracy=0.8493
# 13/20, error=0.4166, accuracy=0.888, val_error=0.6151, val_accuracy=0.845
# 14/20, error=0.4157, accuracy=0.8885, val_error=0.6166, val_accuracy=0.8461
# 15/20, error=0.415, accuracy=0.8889, val_error=0.6184, val_accuracy=0.845
# 16/20, error=0.4143, accuracy=0.8889, val_error=0.6202, val_accuracy=0.845
# 17/20, error=0.4138, accuracy=0.8896, val_error=0.622, val_accuracy=0.845
# 18/20, error=0.4133, accuracy=0.8897, val_error=0.6236, val_accuracy=0.8461
# 19/20, error=0.4128, accuracy=0.8901, val_error=0.6251, val_accuracy=0.845
# 20/20, error=0.4125, accuracy=0.8904, val_error=0.6263, val_accuracy=0.8429
# 1/20, error=0.0659, accuracy=0.9212, val_error=0.0099, val_accuracy=0.9873
# 2/20, error=0.0045, accuracy=0.994, val_error=0.0025, val_accuracy=0.9968
# 3/20, error=0.0013, accuracy=0.9986, val_error=0.0008, val_accuracy=0.9989
# 4/20, error=0.0004, accuracy=0.9996, val_error=0.0004, val_accuracy=1.0
# 5/20, error=0.0001, accuracy=1.0, val_error=0.0003, val_accuracy=1.0
# 6/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 7/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 8/20, error=0.0001, accuracy=1.0, val_error=0.0002, val_accuracy=1.0
# 9/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 10/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 11/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 12/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 13/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 14/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 15/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 16/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 17/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 18/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 19/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# 20/20, error=0.0, accuracy=1.0, val_error=0.0001, val_accuracy=1.0
# Layers : 2
# 1/20, error=0.6447, accuracy=0.843, val_error=0.5564, val_accuracy=0.8397
# 2/20, error=0.4769, accuracy=0.8735, val_error=0.4962, val_accuracy=0.8577
# 3/20, error=0.4566, accuracy=0.8798, val_error=0.4909, val_accuracy=0.8652
# 4/20, error=0.4458, accuracy=0.8823, val_error=0.4952, val_accuracy=0.8652
# 5/20, error=0.4375, accuracy=0.8833, val_error=0.5064, val_accuracy=0.8641
# 6/20, error=0.4314, accuracy=0.8842, val_error=0.5193, val_accuracy=0.862
# 7/20, error=0.4272, accuracy=0.8852, val_error=0.5339, val_accuracy=0.8609
# 8/20, error=0.4242, accuracy=0.886, val_error=0.5481, val_accuracy=0.8599
# 9/20, error=0.422, accuracy=0.887, val_error=0.561, val_accuracy=0.8567
# 10/20, error=0.4203, accuracy=0.8877, val_error=0.5725, val_accuracy=0.8546
# 11/20, error=0.419, accuracy=0.8879, val_error=0.5825, val_accuracy=0.8535
# 12/20, error=0.4179, accuracy=0.8888, val_error=0.5909, val_accuracy=0.8503
# 13/20, error=0.4169, accuracy=0.8887, val_error=0.598, val_accuracy=0.8493
# 14/20, error=0.4161, accuracy=0.8891, val_error=0.6038, val_accuracy=0.8482
# 15/20, error=0.4154, accuracy=0.8892, val_error=0.6087, val_accuracy=0.845
# 16/20, error=0.4147, accuracy=0.8888, val_error=0.6128, val_accuracy=0.8461
# 17/20, error=0.4141, accuracy=0.8892, val_error=0.6162, val_accuracy=0.845
# 18/20, error=0.4135, accuracy=0.8898, val_error=0.6191, val_accuracy=0.8461
# 19/20, error=0.413, accuracy=0.8898, val_error=0.6216, val_accuracy=0.845
# 20/20, error=0.4125, accuracy=0.8901, val_error=0.6238, val_accuracy=0.8461
# Layers : 2
# 1/20, error=0.6129, accuracy=0.8467, val_error=0.495, val_accuracy=0.8588
# 2/20, error=0.4748, accuracy=0.8765, val_error=0.4811, val_accuracy=0.8662
# 3/20, error=0.4542, accuracy=0.8809, val_error=0.4997, val_accuracy=0.8588
# 4/20, error=0.4414, accuracy=0.884, val_error=0.5099, val_accuracy=0.8567
# 5/20, error=0.4328, accuracy=0.8844, val_error=0.5153, val_accuracy=0.8609
# 6/20, error=0.4276, accuracy=0.886, val_error=0.52, val_accuracy=0.8609
# 7/20, error=0.4242, accuracy=0.8868, val_error=0.525, val_accuracy=0.862
# 8/20, error=0.4217, accuracy=0.8872, val_error=0.5301, val_accuracy=0.8631
# 9/20, error=0.4198, accuracy=0.8871, val_error=0.5351, val_accuracy=0.8631
# 10/20, error=0.4183, accuracy=0.8883, val_error=0.5396, val_accuracy=0.862
# 11/20, error=0.417, accuracy=0.8882, val_error=0.5435, val_accuracy=0.8609
# 12/20, error=0.416, accuracy=0.8887, val_error=0.5471, val_accuracy=0.8609
# 13/20, error=0.4151, accuracy=0.8899, val_error=0.5508, val_accuracy=0.8631
# 14/20, error=0.4144, accuracy=0.8893, val_error=0.5545, val_accuracy=0.8641
# 15/20, error=0.4138, accuracy=0.8901, val_error=0.5583, val_accuracy=0.8641
# 16/20, error=0.4132, accuracy=0.8903, val_error=0.5619, val_accuracy=0.8641
# 17/20, error=0.4127, accuracy=0.8905, val_error=0.5655, val_accuracy=0.862
# 18/20, error=0.4123, accuracy=0.891, val_error=0.5689, val_accuracy=0.862
# 19/20, error=0.4119, accuracy=0.8911, val_error=0.572, val_accuracy=0.862
# 20/20, error=0.4116, accuracy=0.8906, val_error=0.575, val_accuracy=0.8641
# Test Accuracy =  0.8092857142857143
# Test Loss =  0.18749018839895087
# Balanced dataset shape: (10180, 784), (10180,)
# Balanced dataset shape: (940, 784), (940,)
# Layers : 1
# 1/20, error=0.4765, accuracy=0.8814, val_error=0.3042, val_accuracy=0.917
# 2/20, error=0.3623, accuracy=0.9059, val_error=0.2871, val_accuracy=0.9266
# 3/20, error=0.3407, accuracy=0.9083, val_error=0.2869, val_accuracy=0.9287
# 4/20, error=0.3295, accuracy=0.9093, val_error=0.2895, val_accuracy=0.9245
# 5/20, error=0.3227, accuracy=0.9111, val_error=0.2907, val_accuracy=0.9266
# 6/20, error=0.318, accuracy=0.9127, val_error=0.2916, val_accuracy=0.9277
# 7/20, error=0.3144, accuracy=0.9139, val_error=0.2927, val_accuracy=0.9277
# 8/20, error=0.3115, accuracy=0.9152, val_error=0.294, val_accuracy=0.9287
# 9/20, error=0.3091, accuracy=0.9158, val_error=0.2952, val_accuracy=0.9287
# 10/20, error=0.3071, accuracy=0.9167, val_error=0.2963, val_accuracy=0.9277
# 11/20, error=0.3056, accuracy=0.9163, val_error=0.2975, val_accuracy=0.9266
# 12/20, error=0.3044, accuracy=0.916, val_error=0.2988, val_accuracy=0.9277
# 13/20, error=0.3035, accuracy=0.9162, val_error=0.3002, val_accuracy=0.9287
# 14/20, error=0.3027, accuracy=0.9168, val_error=0.3017, val_accuracy=0.9277
# 15/20, error=0.302, accuracy=0.9175, val_error=0.3032, val_accuracy=0.9277
# 16/20, error=0.3014, accuracy=0.9176, val_error=0.3047, val_accuracy=0.9277
# 17/20, error=0.3008, accuracy=0.9181, val_error=0.3062, val_accuracy=0.9277
# 18/20, error=0.3003, accuracy=0.9187, val_error=0.3078, val_accuracy=0.9287
# 19/20, error=0.2999, accuracy=0.9187, val_error=0.3093, val_accuracy=0.9298
# 20/20, error=0.2994, accuracy=0.9181, val_error=0.3108, val_accuracy=0.9298
# 1/20, error=0.0424, accuracy=0.9478, val_error=0.0083, val_accuracy=0.9904
# 2/20, error=0.0031, accuracy=0.9957, val_error=0.0039, val_accuracy=0.9947
# 3/20, error=0.0008, accuracy=0.9992, val_error=0.0027, val_accuracy=0.9947
# 4/20, error=0.0004, accuracy=0.9996, val_error=0.0019, val_accuracy=0.9957
# 5/20, error=0.0003, accuracy=0.9998, val_error=0.0015, val_accuracy=0.9979
# 6/20, error=0.0002, accuracy=0.9999, val_error=0.0012, val_accuracy=0.9979
# 7/20, error=0.0001, accuracy=0.9999, val_error=0.0011, val_accuracy=0.9979
# 8/20, error=0.0001, accuracy=1.0, val_error=0.001, val_accuracy=0.9979
# 9/20, error=0.0001, accuracy=1.0, val_error=0.0009, val_accuracy=0.9979
# 10/20, error=0.0, accuracy=1.0, val_error=0.0009, val_accuracy=0.9979
# 11/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.9979
# 12/20, error=0.0, accuracy=1.0, val_error=0.0008, val_accuracy=0.9979
# 13/20, error=0.0, accuracy=1.0, val_error=0.0007, val_accuracy=0.9979
# 14/20, error=0.0, accuracy=1.0, val_error=0.0007, val_accuracy=0.9979
# 15/20, error=0.0, accuracy=1.0, val_error=0.0007, val_accuracy=0.9989
# 16/20, error=0.0, accuracy=1.0, val_error=0.0007, val_accuracy=0.9989
# 17/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9989
# 18/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9989
# 19/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9989
# 20/20, error=0.0, accuracy=1.0, val_error=0.0006, val_accuracy=0.9989
# Layers : 2
# 1/20, error=0.4637, accuracy=0.8852, val_error=0.2875, val_accuracy=0.9245
# 2/20, error=0.3512, accuracy=0.9087, val_error=0.2792, val_accuracy=0.9277
# 3/20, error=0.3318, accuracy=0.9122, val_error=0.2759, val_accuracy=0.9266
# 4/20, error=0.3228, accuracy=0.9125, val_error=0.271, val_accuracy=0.934
# 5/20, error=0.3178, accuracy=0.9128, val_error=0.268, val_accuracy=0.9351
# 6/20, error=0.3143, accuracy=0.9133, val_error=0.2674, val_accuracy=0.934
# 7/20, error=0.3117, accuracy=0.9141, val_error=0.2682, val_accuracy=0.9372
# 8/20, error=0.3095, accuracy=0.9146, val_error=0.2699, val_accuracy=0.9372
# 9/20, error=0.3077, accuracy=0.915, val_error=0.2722, val_accuracy=0.9372
# 10/20, error=0.3063, accuracy=0.9151, val_error=0.275, val_accuracy=0.9372
# 11/20, error=0.3051, accuracy=0.9156, val_error=0.278, val_accuracy=0.9383
# 12/20, error=0.3041, accuracy=0.9162, val_error=0.2811, val_accuracy=0.9362
# 13/20, error=0.3032, accuracy=0.9163, val_error=0.2841, val_accuracy=0.9319
# 14/20, error=0.3025, accuracy=0.9166, val_error=0.2869, val_accuracy=0.934
# 15/20, error=0.3019, accuracy=0.9162, val_error=0.2895, val_accuracy=0.934
# 16/20, error=0.3013, accuracy=0.9162, val_error=0.2918, val_accuracy=0.934
# 17/20, error=0.3008, accuracy=0.9168, val_error=0.2939, val_accuracy=0.934
# 18/20, error=0.3004, accuracy=0.9174, val_error=0.2958, val_accuracy=0.934
# 19/20, error=0.3, accuracy=0.9176, val_error=0.2976, val_accuracy=0.934
# 20/20, error=0.2996, accuracy=0.9175, val_error=0.2993, val_accuracy=0.933
# Layers : 2
# 1/20, error=0.4846, accuracy=0.8844, val_error=0.2624, val_accuracy=0.9245
# 2/20, error=0.3649, accuracy=0.9056, val_error=0.2539, val_accuracy=0.9298
# 3/20, error=0.3412, accuracy=0.9093, val_error=0.2521, val_accuracy=0.933
# 4/20, error=0.329, accuracy=0.9113, val_error=0.2575, val_accuracy=0.933
# 5/20, error=0.3212, accuracy=0.9132, val_error=0.2632, val_accuracy=0.9319
# 6/20, error=0.3158, accuracy=0.9138, val_error=0.2684, val_accuracy=0.9309
# 7/20, error=0.312, accuracy=0.9149, val_error=0.2733, val_accuracy=0.9309
# 8/20, error=0.3093, accuracy=0.9147, val_error=0.2781, val_accuracy=0.9309
# 9/20, error=0.3073, accuracy=0.9147, val_error=0.2825, val_accuracy=0.9309
# 10/20, error=0.306, accuracy=0.9145, val_error=0.2864, val_accuracy=0.933
# 11/20, error=0.3048, accuracy=0.9148, val_error=0.2897, val_accuracy=0.933
# 12/20, error=0.3038, accuracy=0.9151, val_error=0.2925, val_accuracy=0.9319
# 13/20, error=0.303, accuracy=0.9152, val_error=0.2949, val_accuracy=0.9319
# 14/20, error=0.3022, accuracy=0.9154, val_error=0.2972, val_accuracy=0.9319
# 15/20, error=0.3015, accuracy=0.9158, val_error=0.2992, val_accuracy=0.9309
# 16/20, error=0.3009, accuracy=0.9165, val_error=0.301, val_accuracy=0.9298
# 17/20, error=0.3003, accuracy=0.9171, val_error=0.3027, val_accuracy=0.9298
# 18/20, error=0.2998, accuracy=0.9173, val_error=0.3043, val_accuracy=0.9298
# 19/20, error=0.2994, accuracy=0.918, val_error=0.3058, val_accuracy=0.9298
# 20/20, error=0.299, accuracy=0.9181, val_error=0.3072, val_accuracy=0.9309
# Test Accuracy =  0.8925714285714286
# Test Loss =  0.10446397284983545

# %%
def predict_tree_classifiers(tree_classifier,X_sample):
    predictions = []
    pred_all = []
    for classifier in tree_classifier:
        pred = classifier.predict(X_sample)
        pred_all.append(pred)
    predicts = np.array(pred_all).squeeze().transpose()
    for pred in predicts:
        predictions.append(pred)
    return np.array(predictions)

# %%
def eval_tree(tree_classifier,X_sample,y_sample):
    predictions = predict_tree_classifiers(tree_classifier,X_sample)
    acc = 0
    for pred,true in zip(predictions,y_sample):
        if np.argmax(pred)==true:
            acc+=1
    return acc/len(X_sample)

# %%
print("test_acc:",eval_tree(tree_classifier,X_test,y_test))
print("val_acc:",eval_tree(tree_classifier,X_val,y_val))
print("train_acc:",eval_tree(tree_classifier,X_train,y_train))
# Out:
# test_acc: 0.8083571428571429
# val_acc: 0.8136
# train_acc: 0.8144117647058824

# %%
# Multiclass values
plots_multi = [{'dataset': 'test', 'acc': 0.8083571428571429},#test,
{'dataset': 'validation', 'acc': 0.8136}#val
, {'dataset': 'training', 'acc': 0.8144117647058824}]

# %%
index =0
fig = plt.figure(figsize=(10, 5)) 

rows = 2
columns = 5
for classifier in tree_classifier:
    fig.add_subplot(rows, columns, index+1) 
    plt.imshow(classifier.NN[0].weights.squeeze()[:-2].reshape(28,28))
    plt.axis('off') 
    plt.title('classifier:{}'.format(index))
    index+=1

# %%
from sklearn.utils import shuffle
def get_top(X,labels,k=100):
    #dataset = np.column_stack((X,labels))
    X_sample, labels_sample = shuffle(X, labels, )

    topk = []
    for _class in range(10):
        class_index = np.where(labels_sample==_class)[0][:k]
        topk.append(np.column_stack((X_sample.iloc[class_index],labels_sample[class_index])))
    topk = np.vstack(topk)
    return topk

# %%
top100 = get_top(X,labels)
np.random.shuffle(top100)

# %%
pairs = []
pair_labels = []
for row1 in top100:
    for row2 in top100:
        pairs.append(np.hstack((row2[:-1],row1[:-1])))
        if row1[-1]==row2[-1]:
            pair_labels.append(1)
        else:
            pair_labels.append(0)

pairs = np.vstack(pairs)
pair_labels = np.array(pair_labels)

# %%
def predict_siamese(tree_classifier,X,threshold=1):
    X_sample = X.reshape(len(X), 2, 784)
    predictions = []
    first_images = []
    second_images = []
    
    for sample in X_sample:
        first_images.append(predict_tree_classifiers(tree_classifier,sample[0].reshape(1,784)))
        second_images.append(predict_tree_classifiers(tree_classifier,sample[1].reshape(1,784)))

    for first,second in zip(first_images,second_images):
        euclidean_dist =np.sqrt(np.sum(np.square(first - second)))
        if euclidean_dist<threshold:
            predictions.append(1)
        else:
            predictions.append(0)
    return np.array(predictions)

# %%
X_train,X_val,y_train,y_val = train_test_split(pairs,pair_labels,test_size=0.2,shuffle=True)

# %%
predictions = predict_siamese(tree_classifier,X_val)

# %%
def eval(predictions,true_val):
    acc = 0
    for pred,true in zip(predictions,true_val):
        if pred==true:
            acc+=1
    return acc/len(true_val)

# %%
def eval_siamese(X_sample,label_sample,k=5):
    topk = get_top(X,labels,k)
    np.random.shuffle(topk)
    predictions = []
    for sample in tqdm.tqdm(X_sample.to_numpy()):
        pairs = []
        pair_labels = []
        for row in topk:
            pairs.append(np.hstack((sample[:],row[:-1])))
            pair_labels.append(row[-1])
        pairs = np.vstack(pairs)
        pair_labels = np.array(pair_labels).astype(int)
        sample_predictions = predict_siamese(tree_classifier,pairs)
        predict = np.bincount(pair_labels[sample_predictions==1])
        if predict.size:
            predictions.append(predict.argmax())
        else:
            predictions.append(10)
    acc = eval(np.array(predictions),label_sample)
    return {'k':k,'acc':acc}

# %%
X_train,X_test,y_train,y_test = train_test_split(X,labels,test_size=0.2,shuffle=True)
X_val, y_val = X_train.iloc[:5000],y_train[:5000]
X_train, y_train = X_train.iloc[5000:],y_train[5000:]

# %%
#test
eval_siamese(X_test,y_test,k=20)
# Out:
#   0%|          | 0/14000 [00:00<?, ?it/s]
# {'k': 20, 'acc': 0.7723571428571429}

# %%
#train
eval_siamese(X_train.iloc[:len(X_train)//4],y_train[:len(y_train)//4],k=20)
# Out:
#   0%|          | 0/12750 [00:00<?, ?it/s]
# {'k': 20, 'acc': 0.7890196078431373}

# %%
plots_bin = [{'dataset': 'test', 'acc': 0.7723571428571429},#test
{'dataset': 'validation', 'acc': 0.7866},#val
{'dataset': 'training', 'acc': 0.7890196078431373}]#train

# %%
outputs = []
for i in tqdm.tqdm([1,2,4,8,16,20,32,64]):
    outputs.append(eval_siamese(X_test.iloc[:len(X_test)//8],y_test[:len(y_test)//8],k=i))
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
outputs
# Out:
# [{'k': 1, 'acc': 0.4719285714285714},
#  {'k': 2, 'acc': 0.6239285714285714},
#  {'k': 4, 'acc': 0.6858571428571428},
#  {'k': 8, 'acc': 0.65},
#  {'k': 16, 'acc': 0.7668571428571429},
#  {'k': 32, 'acc': 0.7987785714285714},
#  {'k': 64, 'acc': 0.792}]

# %%
plots = pd.DataFrame(outputs)

# %%
plt.plot(plots['k'],plots['acc'])
plt.title('Accuracy vs K')
plt.xlabel('k value')
plt.ylabel('Test Accuracy')
plt.savefig('./graph/acc_vs_k.png')

# %%
plots_multi = pd.DataFrame(plots_multi)
plots_bin = pd.DataFrame(plots_bin)

# %%
X_axis =np.arange(len(plots_bin))
plt.bar(X_axis+0.2,plots_multi['acc'],0.4,label='Growing Tree NN')
plt.bar(X_axis-0.2,plots_bin['acc'],0.4,label='Binary Classifier')
plt.xticks(X_axis,plots_bin['dataset'])
plt.title('Accuracy Plot for Classifiers')
plt.xlabel('Dataset')
plt.ylabel('Accuracy')
plt.ylim(0.7,0.85)
plt.legend()
plt.savefig('./graph/compare.png')
